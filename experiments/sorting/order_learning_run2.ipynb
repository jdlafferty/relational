# %% [markdown]
# # Learning Order Relations

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import itertools
np.random.seed(100)

# %% [markdown]
# ## Order Relation Model
#
#
# **Task**: Given two objects $(o_1, o_2) \in \mathcal{O} \times \mathcal{O}$, predict the relation $o_1 \prec o_2$
#
# **Model**:
# 1) Embed each object: $o_1 \mapsto e_1, o_2 \mapsto e_2$
# 2) Project the first object via $W^1$ and the second object via $W^2$, then compute inner product: $\langle W^1 e_1, W^2 e_2 \rangle$.
# 3) Return relation as sigmoid function $\text{Sigmoid}\left( \langle W^1 e_1, W^2 e_2 \rangle \right)$
#
# *Note:* Here, the objects are tokens. (i.e.: integers. so the embedding layer maps $i \mapsto e_i$ for each $i \in \{1, ..., |\mathcal{O}| \}$)

# %%
class OrderRelation(tf.keras.Model):
    def __init__(self, num_objects, embedding_dim, proj_dim, name=None):
        super().__init__(name=name)
        self.num_objects = num_objects
        self.embedding_dim = embedding_dim
        self.proj_dim = proj_dim
    
    def build(self, input_shape):

        self.embedding = layers.Embedding(input_dim=self.num_objects, output_dim=self.embedding_dim)

        normal_initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=.1, seed=1)
        self.W1 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
        self.W2 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
    
    def compute_innerprod_rel(self, inputs):
        embeddings = self.embedding(inputs)
        
        o1 = embeddings[:, 0]
        o2 = embeddings[:, 1]
        e1 = tf.matmul(o1, self.W1)
        e2 = tf.matmul(o2, self.W2)

        innerprod_rel = tf.einsum('ij,ij->i', e1, e2) # compute inner product

        return innerprod_rel

    def call(self, inputs):

        innerprod_rel = self.compute_innerprod_rel(inputs)

        return innerprod_rel

# %% [markdown]
# ## Order Relation Dataset
#
# Model is fit on all pairs of objects and their associated relations.

# %%
# create data set for learning order relatios
num_objects = 64
object_pairs = np.array(list(itertools.permutations(range(num_objects), r=2)))
object_order_relations = (object_pairs[:,0] < object_pairs[:, 1]).astype(int)

# %%
sample = np.random.choice(len(object_pairs), 10)
for object_pair, relation in zip(object_pairs[sample], object_order_relations[sample]):
    print(f'object pair: {tuple(object_pair)}; relation: {relation}')
# Out:
# object pair: (24, 33); relation: 1
# object pair: (45, 5); relation: 0
# object pair: (29, 33); relation: 1
# object pair: (62, 37); relation: 0
# object pair: (62, 21); relation: 0
# object pair: (1, 17); relation: 1
# object pair: (63, 47); relation: 0
# object pair: (30, 41); relation: 1
# object pair: (5, 36); relation: 1
# object pair: (31, 19); relation: 0

# %% [markdown]
# ## Fit Relation Model

# %%
embedding_dim = 16
proj_dim = 8

order_relation = OrderRelation(num_objects, embedding_dim, proj_dim, name='order_relation')
order_relation(object_pairs); # build model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
order_relation.compile(loss='mse', optimizer=opt, metrics='binary_accuracy')

# %%
order_relation.fit(object_pairs, object_order_relations, epochs=200, batch_size=len(object_pairs))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 484ms/step - loss: 0.5000 - binary_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4904 - binary_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4239 - binary_accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2705 - binary_accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6114 - binary_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2406 - binary_accuracy: 0.5112
# Epoch 7/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2513 - binary_accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3105 - binary_accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3381 - binary_accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3404 - binary_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3249 - binary_accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2948 - binary_accuracy: 0.5687
# Epoch 13/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2526 - binary_accuracy: 0.7083
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2009 - binary_accuracy: 0.7574
# Epoch 15/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1497 - binary_accuracy: 0.8189
# Epoch 16/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1438 - binary_accuracy: 0.8713
# Epoch 17/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1881 - binary_accuracy: 0.8477
# Epoch 18/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1533 - binary_accuracy: 0.8403
# Epoch 19/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0964 - binary_accuracy: 0.8631
# Epoch 20/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0920 - binary_accuracy: 0.8859
# Epoch 21/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1143 - binary_accuracy: 0.8852
# Epoch 22/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1304 - binary_accuracy: 0.8554
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1298 - binary_accuracy: 0.8574
# Epoch 24/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1150 - binary_accuracy: 0.8948
# Epoch 25/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0961 - binary_accuracy: 0.9142
# Epoch 26/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0876 - binary_accuracy: 0.9092
# Epoch 27/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0956 - binary_accuracy: 0.8981
# Epoch 28/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1026 - binary_accuracy: 0.8886
# Epoch 29/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0929 - binary_accuracy: 0.9117
# Epoch 30/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0802 - binary_accuracy: 0.9449
# Epoch 31/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0787 - binary_accuracy: 0.9680
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0845 - binary_accuracy: 0.9581
# Epoch 33/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0885 - binary_accuracy: 0.9400
# Epoch 34/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0863 - binary_accuracy: 0.9375
# Epoch 35/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0791 - binary_accuracy: 0.9449
# Epoch 36/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0724 - binary_accuracy: 0.9444
# Epoch 37/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0717 - binary_accuracy: 0.9320
# Epoch 38/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0758 - binary_accuracy: 0.9239
# Epoch 39/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0768 - binary_accuracy: 0.9194
# Epoch 40/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0717 - binary_accuracy: 0.9241
# Epoch 41/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0671 - binary_accuracy: 0.9288
# Epoch 42/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0668 - binary_accuracy: 0.9315
# Epoch 43/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0679 - binary_accuracy: 0.9353
# Epoch 44/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0668 - binary_accuracy: 0.9452
# Epoch 45/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0632 - binary_accuracy: 0.9556
# Epoch 46/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0596 - binary_accuracy: 0.9720
# Epoch 47/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0580 - binary_accuracy: 0.9678
# Epoch 48/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0574 - binary_accuracy: 0.9660
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0552 - binary_accuracy: 0.9725
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0522 - binary_accuracy: 0.9856
# Epoch 51/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0511 - binary_accuracy: 0.9851
# Epoch 52/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0521 - binary_accuracy: 0.9762
# Epoch 53/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0530 - binary_accuracy: 0.9690
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0528 - binary_accuracy: 0.9690
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0519 - binary_accuracy: 0.9730
# Epoch 56/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0515 - binary_accuracy: 0.9757
# Epoch 57/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0517 - binary_accuracy: 0.9779
# Epoch 58/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0514 - binary_accuracy: 0.9802
# Epoch 59/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0503 - binary_accuracy: 0.9831
# Epoch 60/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0494 - binary_accuracy: 0.9816
# Epoch 61/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0494 - binary_accuracy: 0.9747
# Epoch 62/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0494 - binary_accuracy: 0.9692
# Epoch 63/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0489 - binary_accuracy: 0.9707
# Epoch 64/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0481 - binary_accuracy: 0.9769
# Epoch 65/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0477 - binary_accuracy: 0.9819
# Epoch 66/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0477 - binary_accuracy: 0.9821
# Epoch 67/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0475 - binary_accuracy: 0.9814
# Epoch 68/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0470 - binary_accuracy: 0.9809
# Epoch 69/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0466 - binary_accuracy: 0.9816
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0463 - binary_accuracy: 0.9814
# Epoch 71/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0459 - binary_accuracy: 0.9809
# Epoch 72/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0454 - binary_accuracy: 0.9812
# Epoch 73/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0448 - binary_accuracy: 0.9821
# Epoch 74/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0446 - binary_accuracy: 0.9812
# Epoch 75/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0443 - binary_accuracy: 0.9812
# Epoch 76/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0439 - binary_accuracy: 0.9812
# Epoch 77/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0433 - binary_accuracy: 0.9821
# Epoch 78/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0427 - binary_accuracy: 0.9826
# Epoch 79/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0423 - binary_accuracy: 0.9821
# Epoch 80/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0418 - binary_accuracy: 0.9831
# Epoch 81/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0412 - binary_accuracy: 0.9826
# Epoch 82/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0407 - binary_accuracy: 0.9826
# Epoch 83/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0403 - binary_accuracy: 0.9821
# Epoch 84/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0398 - binary_accuracy: 0.9819
# Epoch 85/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0392 - binary_accuracy: 0.9839
# Epoch 86/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0386 - binary_accuracy: 0.9849
# Epoch 87/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0381 - binary_accuracy: 0.9856
# Epoch 88/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0375 - binary_accuracy: 0.9871
# Epoch 89/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0368 - binary_accuracy: 0.9874
# Epoch 90/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0362 - binary_accuracy: 0.9881
# Epoch 91/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0355 - binary_accuracy: 0.9883
# Epoch 92/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0348 - binary_accuracy: 0.9888
# Epoch 93/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0341 - binary_accuracy: 0.9903
# Epoch 94/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0335 - binary_accuracy: 0.9906
# Epoch 95/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0329 - binary_accuracy: 0.9913
# Epoch 96/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0323 - binary_accuracy: 0.9923
# Epoch 97/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0318 - binary_accuracy: 0.9931
# Epoch 98/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0314 - binary_accuracy: 0.9933
# Epoch 99/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0311 - binary_accuracy: 0.9938
# Epoch 100/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0309 - binary_accuracy: 0.9948
# Epoch 101/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0308 - binary_accuracy: 0.9950
# Epoch 102/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307 - binary_accuracy: 0.9953
# Epoch 103/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0307 - binary_accuracy: 0.9960
# Epoch 104/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307 - binary_accuracy: 0.9955
# Epoch 105/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307 - binary_accuracy: 0.9955
# Epoch 106/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0307 - binary_accuracy: 0.9955
# Epoch 107/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0306 - binary_accuracy: 0.9955
# Epoch 108/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0305 - binary_accuracy: 0.9953
# Epoch 109/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0303 - binary_accuracy: 0.9953
# Epoch 110/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0301 - binary_accuracy: 0.9948
# Epoch 111/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0300 - binary_accuracy: 0.9948
# Epoch 112/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0298 - binary_accuracy: 0.9948
# Epoch 113/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0296 - binary_accuracy: 0.9950
# Epoch 114/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0294 - binary_accuracy: 0.9943
# Epoch 115/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0293 - binary_accuracy: 0.9943
# Epoch 116/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0291 - binary_accuracy: 0.9943
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0290 - binary_accuracy: 0.9940
# Epoch 118/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0288 - binary_accuracy: 0.9945
# Epoch 119/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0287 - binary_accuracy: 0.9945
# Epoch 120/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0286 - binary_accuracy: 0.9943
# Epoch 121/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0285 - binary_accuracy: 0.9943
# Epoch 122/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0284 - binary_accuracy: 0.9945
# Epoch 123/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0283 - binary_accuracy: 0.9953
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0282 - binary_accuracy: 0.9960
# Epoch 125/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0281 - binary_accuracy: 0.9960
# Epoch 126/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0280 - binary_accuracy: 0.9960
# Epoch 127/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0278 - binary_accuracy: 0.9965
# Epoch 128/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0277 - binary_accuracy: 0.9965
# Epoch 129/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0276 - binary_accuracy: 0.9965
# Epoch 130/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0275 - binary_accuracy: 0.9965
# Epoch 131/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0273 - binary_accuracy: 0.9970
# Epoch 132/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0272 - binary_accuracy: 0.9973
# Epoch 133/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0271 - binary_accuracy: 0.9978
# Epoch 134/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0270 - binary_accuracy: 0.9980
# Epoch 135/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0268 - binary_accuracy: 0.9985
# Epoch 136/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0267 - binary_accuracy: 0.9985
# Epoch 137/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0265 - binary_accuracy: 0.9985
# Epoch 138/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0263 - binary_accuracy: 0.9985
# Epoch 139/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0262 - binary_accuracy: 0.9988
# Epoch 140/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0259 - binary_accuracy: 0.9988
# Epoch 141/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0257 - binary_accuracy: 0.9988
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0255 - binary_accuracy: 0.9988
# Epoch 143/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0253 - binary_accuracy: 0.9988
# Epoch 144/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0250 - binary_accuracy: 0.9985
# Epoch 145/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0248 - binary_accuracy: 0.9985
# Epoch 146/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0246 - binary_accuracy: 0.9985
# Epoch 147/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0243 - binary_accuracy: 0.9985
# Epoch 148/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0241 - binary_accuracy: 0.9985
# Epoch 149/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0239 - binary_accuracy: 0.9985
# Epoch 150/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0237 - binary_accuracy: 0.9983
# Epoch 151/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0235 - binary_accuracy: 0.9983
# Epoch 152/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0233 - binary_accuracy: 0.9980
# Epoch 153/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0231 - binary_accuracy: 0.9978
# Epoch 154/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0230 - binary_accuracy: 0.9978
# Epoch 155/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0229 - binary_accuracy: 0.9978
# Epoch 156/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0228 - binary_accuracy: 0.9975
# Epoch 157/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0227 - binary_accuracy: 0.9973
# Epoch 158/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0227 - binary_accuracy: 0.9973
# Epoch 159/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0227 - binary_accuracy: 0.9973
# Epoch 160/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0226 - binary_accuracy: 0.9973
# Epoch 161/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 162/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 163/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 164/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 165/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 166/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 167/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 168/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0224 - binary_accuracy: 0.9975
# Epoch 169/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - binary_accuracy: 0.9975
# Epoch 170/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - binary_accuracy: 0.9975
# Epoch 171/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0222 - binary_accuracy: 0.9975
# Epoch 172/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0222 - binary_accuracy: 0.9975
# Epoch 173/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0221 - binary_accuracy: 0.9978
# Epoch 174/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0221 - binary_accuracy: 0.9978
# Epoch 175/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0220 - binary_accuracy: 0.9978
# Epoch 176/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0219 - binary_accuracy: 0.9978
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0219 - binary_accuracy: 0.9978
# Epoch 178/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0218 - binary_accuracy: 0.9978
# Epoch 179/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 180/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 181/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0216 - binary_accuracy: 0.9980
# Epoch 182/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0215 - binary_accuracy: 0.9980
# Epoch 183/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - binary_accuracy: 0.9980
# Epoch 184/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - binary_accuracy: 0.9980
# Epoch 185/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - binary_accuracy: 0.9980
# Epoch 186/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0212 - binary_accuracy: 0.9980
# Epoch 187/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0211 - binary_accuracy: 0.9980
# Epoch 188/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0210 - binary_accuracy: 0.9980
# Epoch 189/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0209 - binary_accuracy: 0.9975
# Epoch 190/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0208 - binary_accuracy: 0.9975
# Epoch 191/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0207 - binary_accuracy: 0.9975
# Epoch 192/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0206 - binary_accuracy: 0.9975
# Epoch 193/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0205 - binary_accuracy: 0.9975
# Epoch 194/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0204 - binary_accuracy: 0.9975
# Epoch 195/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0203 - binary_accuracy: 0.9975
# Epoch 196/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0202 - binary_accuracy: 0.9975
# Epoch 197/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0200 - binary_accuracy: 0.9978
# Epoch 198/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0199 - binary_accuracy: 0.9980
# Epoch 199/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0198 - binary_accuracy: 0.9980
# Epoch 200/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0197 - binary_accuracy: 0.9980

# %%
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        order_relation_matrix[i,j] = order_relation.compute_innerprod_rel(np.array([[i,j]]))[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\langle W_1 e_i, W_2 e_j \\rangle$');

# %%
fig, ax = plt.subplots(figsize=(6,6))
order_relation_matrix_softmax = tf.nn.softmax(order_relation_matrix, axis=1).numpy()
im = ax.imshow(order_relation_matrix_softmax.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\mathrm{softmax}(\\langle W_1 e_i, W_2 e_j \\rangle)$');

# %%
#x = tf.nn.softmax(order_relation_matrix, axis=1)
x = order_relation_matrix
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x[32, :])

# %% [markdown]
# # Learn Order Relation with `SimpleAbstractor`

# %%
import sys; sys.path.append('..'); sys.path.append('../..')

from abstracters import SimpleAbstractor

# %%
class AbstractorOrderRelation(tf.keras.Model):
    def __init__(self, name=None):
        super().__init__(name=name)
    
    def build(self, input_shape):
        # note: changed activation of MHA to tanh!
        self.abstractor = SimpleAbstractor(num_layers=1, num_heads=1, dff=32, use_pos_embedding=False, mha_activation_type='tanh')
        self.dense = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.abstractor(inputs)
        x = x[:, 0]
        x = self.dense(x)

        return x

# %%
object_pairs_onehot = tf.one_hot(object_pairs, num_objects)
object_pairs_onehot.shape
# Out:
# TensorShape([4032, 2, 64])

# %%
model = AbstractorOrderRelation()
model(object_pairs_onehot)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics='binary_accuracy')
model.summary()
# Out:
# Model: "abstractor_order_relation_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relational_abstracter (Simp  multiple                 21216
#  leAbstractor)
#
#  dense_6 (Dense)             multiple                  65
#
# =================================================================
# Total params: 21,281
# Trainable params: 21,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(object_pairs_onehot, object_order_relations, epochs=500, batch_size=len(object_pairs))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.9732 - binary_accuracy: 0.5005
# Epoch 2/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.8917 - binary_accuracy: 0.5012
# Epoch 3/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.8133 - binary_accuracy: 0.5012
# Epoch 4/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7698 - binary_accuracy: 0.4928
# Epoch 5/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7295 - binary_accuracy: 0.5064
# Epoch 6/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7232 - binary_accuracy: 0.5025
# Epoch 7/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7342 - binary_accuracy: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7430 - binary_accuracy: 0.5047
# Epoch 9/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7596 - binary_accuracy: 0.5010
# Epoch 10/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7714 - binary_accuracy: 0.5017
# Epoch 11/500
# 1/1 [==============================] - 0s 128ms/step - loss: 0.7599 - binary_accuracy: 0.5094
# Epoch 12/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.7510 - binary_accuracy: 0.5037
# Epoch 13/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7388 - binary_accuracy: 0.5092
# Epoch 14/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7205 - binary_accuracy: 0.5191
# Epoch 15/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7158 - binary_accuracy: 0.5186
# Epoch 16/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7071 - binary_accuracy: 0.5250
# Epoch 17/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7108 - binary_accuracy: 0.5263
# Epoch 18/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7073 - binary_accuracy: 0.5268
# Epoch 19/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.7062 - binary_accuracy: 0.5303
# Epoch 20/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7071 - binary_accuracy: 0.5320
# Epoch 21/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6992 - binary_accuracy: 0.5432
# Epoch 22/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6988 - binary_accuracy: 0.5432
# Epoch 23/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6944 - binary_accuracy: 0.5526
# Epoch 24/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6906 - binary_accuracy: 0.5618
# Epoch 25/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6819 - binary_accuracy: 0.5791
# Epoch 26/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6747 - binary_accuracy: 0.5754
# Epoch 27/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6639 - binary_accuracy: 0.5975
# Epoch 28/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6534 - binary_accuracy: 0.6275
# Epoch 29/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6394 - binary_accuracy: 0.6446
# Epoch 30/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6273 - binary_accuracy: 0.6627
# Epoch 31/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6134 - binary_accuracy: 0.6694
# Epoch 32/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6097 - binary_accuracy: 0.6877
# Epoch 33/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6026 - binary_accuracy: 0.6935
# Epoch 34/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5900 - binary_accuracy: 0.7041
# Epoch 35/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5788 - binary_accuracy: 0.7140
# Epoch 36/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5677 - binary_accuracy: 0.7183
# Epoch 37/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5608 - binary_accuracy: 0.7210
# Epoch 38/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5511 - binary_accuracy: 0.7289
# Epoch 39/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5497 - binary_accuracy: 0.7267
# Epoch 40/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5424 - binary_accuracy: 0.7250
# Epoch 41/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5433 - binary_accuracy: 0.7259
# Epoch 42/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5418 - binary_accuracy: 0.7269
# Epoch 43/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5473 - binary_accuracy: 0.7227
# Epoch 44/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5439 - binary_accuracy: 0.7299
# Epoch 45/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5422 - binary_accuracy: 0.7180
# Epoch 46/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5435 - binary_accuracy: 0.7168
# Epoch 47/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5281 - binary_accuracy: 0.7299
# Epoch 48/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5192 - binary_accuracy: 0.7346
# Epoch 49/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5347 - binary_accuracy: 0.7175
# Epoch 50/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5174 - binary_accuracy: 0.7369
# Epoch 51/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5167 - binary_accuracy: 0.7329
# Epoch 52/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5090 - binary_accuracy: 0.7331
# Epoch 53/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5113 - binary_accuracy: 0.7279
# Epoch 54/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5111 - binary_accuracy: 0.7312
# Epoch 55/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5000 - binary_accuracy: 0.7383
# Epoch 56/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5037 - binary_accuracy: 0.7354
# Epoch 57/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4997 - binary_accuracy: 0.7398
# Epoch 58/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4942 - binary_accuracy: 0.7433
# Epoch 59/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4829 - binary_accuracy: 0.7480
# Epoch 60/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4711 - binary_accuracy: 0.7609
# Epoch 61/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4764 - binary_accuracy: 0.7577
# Epoch 62/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4542 - binary_accuracy: 0.7760
# Epoch 63/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4492 - binary_accuracy: 0.7812
# Epoch 64/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4394 - binary_accuracy: 0.7832
# Epoch 65/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4253 - binary_accuracy: 0.7927
# Epoch 66/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4058 - binary_accuracy: 0.8130
# Epoch 67/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3905 - binary_accuracy: 0.8222
# Epoch 68/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3791 - binary_accuracy: 0.8199
# Epoch 69/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3596 - binary_accuracy: 0.8356
# Epoch 70/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3492 - binary_accuracy: 0.8445
# Epoch 71/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3322 - binary_accuracy: 0.8534
# Epoch 72/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3132 - binary_accuracy: 0.8646
# Epoch 73/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2960 - binary_accuracy: 0.8757
# Epoch 74/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2806 - binary_accuracy: 0.8827
# Epoch 75/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2733 - binary_accuracy: 0.8921
# Epoch 76/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2544 - binary_accuracy: 0.9008
# Epoch 77/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2407 - binary_accuracy: 0.9127
# Epoch 78/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2351 - binary_accuracy: 0.9154
# Epoch 79/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2174 - binary_accuracy: 0.9246
# Epoch 80/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2052 - binary_accuracy: 0.9308
# Epoch 81/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2072 - binary_accuracy: 0.9301
# Epoch 82/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1895 - binary_accuracy: 0.9385
# Epoch 83/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1854 - binary_accuracy: 0.9387
# Epoch 84/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1939 - binary_accuracy: 0.9368
# Epoch 85/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1979 - binary_accuracy: 0.9365
# Epoch 86/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1713 - binary_accuracy: 0.9425
# Epoch 87/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1915 - binary_accuracy: 0.9368
# Epoch 88/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1982 - binary_accuracy: 0.9343
# Epoch 89/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1883 - binary_accuracy: 0.9377
# Epoch 90/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1746 - binary_accuracy: 0.9430
# Epoch 91/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1838 - binary_accuracy: 0.9390
# Epoch 92/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1728 - binary_accuracy: 0.9442
# Epoch 93/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1642 - binary_accuracy: 0.9442
# Epoch 94/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1546 - binary_accuracy: 0.9472
# Epoch 95/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1679 - binary_accuracy: 0.9474
# Epoch 96/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1525 - binary_accuracy: 0.9479
# Epoch 97/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1654 - binary_accuracy: 0.9467
# Epoch 98/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1650 - binary_accuracy: 0.9467
# Epoch 99/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1368 - binary_accuracy: 0.9549
# Epoch 100/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1424 - binary_accuracy: 0.9539
# Epoch 101/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1675 - binary_accuracy: 0.9469
# Epoch 102/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1494 - binary_accuracy: 0.9536
# Epoch 103/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1365 - binary_accuracy: 0.9571
# Epoch 104/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1338 - binary_accuracy: 0.9492
# Epoch 105/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1308 - binary_accuracy: 0.9591
# Epoch 106/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1320 - binary_accuracy: 0.9571
# Epoch 107/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1416 - binary_accuracy: 0.9529
# Epoch 108/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1250 - binary_accuracy: 0.9601
# Epoch 109/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1112 - binary_accuracy: 0.9623
# Epoch 110/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1248 - binary_accuracy: 0.9588
# Epoch 111/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1068 - binary_accuracy: 0.9643
# Epoch 112/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1199 - binary_accuracy: 0.9598
# Epoch 113/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1339 - binary_accuracy: 0.9566
# Epoch 114/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1079 - binary_accuracy: 0.9621
# Epoch 115/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0984 - binary_accuracy: 0.9643
# Epoch 116/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1047 - binary_accuracy: 0.9623
# Epoch 117/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1093 - binary_accuracy: 0.9603
# Epoch 118/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0914 - binary_accuracy: 0.9705
# Epoch 119/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0882 - binary_accuracy: 0.9695
# Epoch 120/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0973 - binary_accuracy: 0.9663
# Epoch 121/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0927 - binary_accuracy: 0.9645
# Epoch 122/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0839 - binary_accuracy: 0.9707
# Epoch 123/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0859 - binary_accuracy: 0.9680
# Epoch 124/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0949 - binary_accuracy: 0.9621
# Epoch 125/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0855 - binary_accuracy: 0.9678
# Epoch 126/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0768 - binary_accuracy: 0.9695
# Epoch 127/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0845 - binary_accuracy: 0.9650
# Epoch 128/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0783 - binary_accuracy: 0.9692
# Epoch 129/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0779 - binary_accuracy: 0.9688
# Epoch 130/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0787 - binary_accuracy: 0.9663
# Epoch 131/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0698 - binary_accuracy: 0.9757
# Epoch 132/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0674 - binary_accuracy: 0.9707
# Epoch 133/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0678 - binary_accuracy: 0.9732
# Epoch 134/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0782 - binary_accuracy: 0.9702
# Epoch 135/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0671 - binary_accuracy: 0.9705
# Epoch 136/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0723 - binary_accuracy: 0.9660
# Epoch 137/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0655 - binary_accuracy: 0.9720
# Epoch 138/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0753 - binary_accuracy: 0.9635
# Epoch 139/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0677 - binary_accuracy: 0.9725
# Epoch 140/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0718 - binary_accuracy: 0.9678
# Epoch 141/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0712 - binary_accuracy: 0.9675
# Epoch 142/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0733 - binary_accuracy: 0.9688
# Epoch 143/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0670 - binary_accuracy: 0.9715
# Epoch 144/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0619 - binary_accuracy: 0.9740
# Epoch 145/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0747 - binary_accuracy: 0.9655
# Epoch 146/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0709 - binary_accuracy: 0.9683
# Epoch 147/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0676 - binary_accuracy: 0.9715
# Epoch 148/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0602 - binary_accuracy: 0.9742
# Epoch 149/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0642 - binary_accuracy: 0.9732
# Epoch 150/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0715 - binary_accuracy: 0.9650
# Epoch 151/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0638 - binary_accuracy: 0.9683
# Epoch 152/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0662 - binary_accuracy: 0.9722
# Epoch 153/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0624 - binary_accuracy: 0.9722
# Epoch 154/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0710 - binary_accuracy: 0.9655
# Epoch 155/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0591 - binary_accuracy: 0.9730
# Epoch 156/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0595 - binary_accuracy: 0.9740
# Epoch 157/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0590 - binary_accuracy: 0.9722
# Epoch 158/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0571 - binary_accuracy: 0.9727
# Epoch 159/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0549 - binary_accuracy: 0.9752
# Epoch 160/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0601 - binary_accuracy: 0.9727
# Epoch 161/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0630 - binary_accuracy: 0.9720
# Epoch 162/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0701 - binary_accuracy: 0.9673
# Epoch 163/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0632 - binary_accuracy: 0.9702
# Epoch 164/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0661 - binary_accuracy: 0.9663
# Epoch 165/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0607 - binary_accuracy: 0.9722
# Epoch 166/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0637 - binary_accuracy: 0.9678
# Epoch 167/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0659 - binary_accuracy: 0.9688
# Epoch 168/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0613 - binary_accuracy: 0.9705
# Epoch 169/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0697 - binary_accuracy: 0.9663
# Epoch 170/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0585 - binary_accuracy: 0.9717
# Epoch 171/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0667 - binary_accuracy: 0.9668
# Epoch 172/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0690 - binary_accuracy: 0.9653
# Epoch 173/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0591 - binary_accuracy: 0.9697
# Epoch 174/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0586 - binary_accuracy: 0.9712
# Epoch 175/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0588 - binary_accuracy: 0.9720
# Epoch 176/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0552 - binary_accuracy: 0.9727
# Epoch 177/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0551 - binary_accuracy: 0.9717
# Epoch 178/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0595 - binary_accuracy: 0.9707
# Epoch 179/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0611 - binary_accuracy: 0.9663
# Epoch 180/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0635 - binary_accuracy: 0.9702
# Epoch 181/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0624 - binary_accuracy: 0.9715
# Epoch 182/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0569 - binary_accuracy: 0.9707
# Epoch 183/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0558 - binary_accuracy: 0.9732
# Epoch 184/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0612 - binary_accuracy: 0.9673
# Epoch 185/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0517 - binary_accuracy: 0.9747
# Epoch 186/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0634 - binary_accuracy: 0.9692
# Epoch 187/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0599 - binary_accuracy: 0.9697
# Epoch 188/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0550 - binary_accuracy: 0.9732
# Epoch 189/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0542 - binary_accuracy: 0.9720
# Epoch 190/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0587 - binary_accuracy: 0.9732
# Epoch 191/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0562 - binary_accuracy: 0.9737
# Epoch 192/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0658 - binary_accuracy: 0.9673
# Epoch 193/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0582 - binary_accuracy: 0.9715
# Epoch 194/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0507 - binary_accuracy: 0.9779
# Epoch 195/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0618 - binary_accuracy: 0.9695
# Epoch 196/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0614 - binary_accuracy: 0.9678
# Epoch 197/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0554 - binary_accuracy: 0.9720
# Epoch 198/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0570 - binary_accuracy: 0.9737
# Epoch 199/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0503 - binary_accuracy: 0.9759
# Epoch 200/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0563 - binary_accuracy: 0.9727
# Epoch 201/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0626 - binary_accuracy: 0.9692
# Epoch 202/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0618 - binary_accuracy: 0.9660
# Epoch 203/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0580 - binary_accuracy: 0.9690
# Epoch 204/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0617 - binary_accuracy: 0.9688
# Epoch 205/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0606 - binary_accuracy: 0.9673
# Epoch 206/500
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0621 - binary_accuracy: 0.9675
# Epoch 207/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0625 - binary_accuracy: 0.9665
# Epoch 208/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0592 - binary_accuracy: 0.9692
# Epoch 209/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0513 - binary_accuracy: 0.9745
# Epoch 210/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0538 - binary_accuracy: 0.9712
# Epoch 211/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0536 - binary_accuracy: 0.9737
# Epoch 212/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0576 - binary_accuracy: 0.9702
# Epoch 213/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0582 - binary_accuracy: 0.9732
# Epoch 214/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0562 - binary_accuracy: 0.9715
# Epoch 215/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0552 - binary_accuracy: 0.9722
# Epoch 216/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0583 - binary_accuracy: 0.9707
# Epoch 217/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0538 - binary_accuracy: 0.9735
# Epoch 218/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0577 - binary_accuracy: 0.9707
# Epoch 219/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0548 - binary_accuracy: 0.9690
# Epoch 220/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0455 - binary_accuracy: 0.9794
# Epoch 221/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0600 - binary_accuracy: 0.9678
# Epoch 222/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0544 - binary_accuracy: 0.9735
# Epoch 223/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0661 - binary_accuracy: 0.9685
# Epoch 224/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0589 - binary_accuracy: 0.9720
# Epoch 225/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0584 - binary_accuracy: 0.9683
# Epoch 226/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0514 - binary_accuracy: 0.9727
# Epoch 227/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0589 - binary_accuracy: 0.9683
# Epoch 228/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0545 - binary_accuracy: 0.9725
# Epoch 229/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0591 - binary_accuracy: 0.9722
# Epoch 230/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0566 - binary_accuracy: 0.9725
# Epoch 231/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0559 - binary_accuracy: 0.9722
# Epoch 232/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0593 - binary_accuracy: 0.9712
# Epoch 233/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0559 - binary_accuracy: 0.9697
# Epoch 234/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0609 - binary_accuracy: 0.9683
# Epoch 235/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0586 - binary_accuracy: 0.9720
# Epoch 236/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0538 - binary_accuracy: 0.9725
# Epoch 237/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0549 - binary_accuracy: 0.9722
# Epoch 238/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0571 - binary_accuracy: 0.9700
# Epoch 239/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0516 - binary_accuracy: 0.9725
# Epoch 240/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0584 - binary_accuracy: 0.9680
# Epoch 241/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0583 - binary_accuracy: 0.9690
# Epoch 242/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0562 - binary_accuracy: 0.9695
# Epoch 243/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0582 - binary_accuracy: 0.9710
# Epoch 244/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0516 - binary_accuracy: 0.9759
# Epoch 245/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0592 - binary_accuracy: 0.9715
# Epoch 246/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0636 - binary_accuracy: 0.9685
# Epoch 247/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0547 - binary_accuracy: 0.9732
# Epoch 248/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0503 - binary_accuracy: 0.9730
# Epoch 249/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0540 - binary_accuracy: 0.9710
# Epoch 250/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0584 - binary_accuracy: 0.9665
# Epoch 251/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0526 - binary_accuracy: 0.9735
# Epoch 252/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0528 - binary_accuracy: 0.9732
# Epoch 253/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0526 - binary_accuracy: 0.9742
# Epoch 254/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0531 - binary_accuracy: 0.9700
# Epoch 255/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0516 - binary_accuracy: 0.9717
# Epoch 256/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0618 - binary_accuracy: 0.9670
# Epoch 257/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0523 - binary_accuracy: 0.9752
# Epoch 258/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0588 - binary_accuracy: 0.9710
# Epoch 259/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0575 - binary_accuracy: 0.9725
# Epoch 260/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0650 - binary_accuracy: 0.9643
# Epoch 261/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0641 - binary_accuracy: 0.9675
# Epoch 262/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0532 - binary_accuracy: 0.9730
# Epoch 263/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0594 - binary_accuracy: 0.9697
# Epoch 264/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0572 - binary_accuracy: 0.9727
# Epoch 265/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0525 - binary_accuracy: 0.9732
# Epoch 266/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0501 - binary_accuracy: 0.9737
# Epoch 267/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0552 - binary_accuracy: 0.9717
# Epoch 268/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0580 - binary_accuracy: 0.9702
# Epoch 269/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0592 - binary_accuracy: 0.9675
# Epoch 270/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0610 - binary_accuracy: 0.9683
# Epoch 271/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0623 - binary_accuracy: 0.9668
# Epoch 272/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0520 - binary_accuracy: 0.9730
# Epoch 273/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0582 - binary_accuracy: 0.9727
# Epoch 274/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0512 - binary_accuracy: 0.9737
# Epoch 275/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0603 - binary_accuracy: 0.9705
# Epoch 276/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0524 - binary_accuracy: 0.9735
# Epoch 277/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0660 - binary_accuracy: 0.9678
# Epoch 278/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0457 - binary_accuracy: 0.9732
# Epoch 279/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0570 - binary_accuracy: 0.9700
# Epoch 280/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0533 - binary_accuracy: 0.9740
# Epoch 281/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0594 - binary_accuracy: 0.9685
# Epoch 282/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0529 - binary_accuracy: 0.9730
# Epoch 283/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0578 - binary_accuracy: 0.9680
# Epoch 284/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0528 - binary_accuracy: 0.9712
# Epoch 285/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0531 - binary_accuracy: 0.9727
# Epoch 286/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0610 - binary_accuracy: 0.9678
# Epoch 287/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0493 - binary_accuracy: 0.9750
# Epoch 288/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0589 - binary_accuracy: 0.9712
# Epoch 289/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0536 - binary_accuracy: 0.9710
# Epoch 290/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0538 - binary_accuracy: 0.9727
# Epoch 291/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0478 - binary_accuracy: 0.9762
# Epoch 292/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0476 - binary_accuracy: 0.9762
# Epoch 293/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0619 - binary_accuracy: 0.9678
# Epoch 294/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0557 - binary_accuracy: 0.9710
# Epoch 295/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0520 - binary_accuracy: 0.9717
# Epoch 296/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0571 - binary_accuracy: 0.9700
# Epoch 297/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0482 - binary_accuracy: 0.9737
# Epoch 298/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0575 - binary_accuracy: 0.9680
# Epoch 299/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0567 - binary_accuracy: 0.9712
# Epoch 300/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0499 - binary_accuracy: 0.9754
# Epoch 301/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0521 - binary_accuracy: 0.9732
# Epoch 302/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0572 - binary_accuracy: 0.9692
# Epoch 303/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0539 - binary_accuracy: 0.9725
# Epoch 304/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0559 - binary_accuracy: 0.9725
# Epoch 305/500
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0539 - binary_accuracy: 0.9710
# Epoch 306/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0545 - binary_accuracy: 0.9720
# Epoch 307/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0543 - binary_accuracy: 0.9715
# Epoch 308/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0545 - binary_accuracy: 0.9688
# Epoch 309/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0609 - binary_accuracy: 0.9685
# Epoch 310/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0536 - binary_accuracy: 0.9735
# Epoch 311/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0640 - binary_accuracy: 0.9685
# Epoch 312/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0527 - binary_accuracy: 0.9722
# Epoch 313/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0596 - binary_accuracy: 0.9668
# Epoch 314/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0470 - binary_accuracy: 0.9745
# Epoch 315/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0494 - binary_accuracy: 0.9757
# Epoch 316/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0569 - binary_accuracy: 0.9688
# Epoch 317/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0492 - binary_accuracy: 0.9747
# Epoch 318/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0574 - binary_accuracy: 0.9692
# Epoch 319/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0545 - binary_accuracy: 0.9717
# Epoch 320/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0558 - binary_accuracy: 0.9725
# Epoch 321/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0546 - binary_accuracy: 0.9725
# Epoch 322/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0540 - binary_accuracy: 0.9712
# Epoch 323/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0548 - binary_accuracy: 0.9717
# Epoch 324/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0471 - binary_accuracy: 0.9759
# Epoch 325/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0553 - binary_accuracy: 0.9717
# Epoch 326/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0524 - binary_accuracy: 0.9722
# Epoch 327/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0587 - binary_accuracy: 0.9692
# Epoch 328/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0597 - binary_accuracy: 0.9717
# Epoch 329/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0574 - binary_accuracy: 0.9702
# Epoch 330/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0567 - binary_accuracy: 0.9722
# Epoch 331/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0516 - binary_accuracy: 0.9722
# Epoch 332/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0597 - binary_accuracy: 0.9702
# Epoch 333/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0543 - binary_accuracy: 0.9717
# Epoch 334/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0630 - binary_accuracy: 0.9673
# Epoch 335/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0557 - binary_accuracy: 0.9688
# Epoch 336/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0516 - binary_accuracy: 0.9747
# Epoch 337/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0578 - binary_accuracy: 0.9695
# Epoch 338/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0505 - binary_accuracy: 0.9737
# Epoch 339/500
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0605 - binary_accuracy: 0.9680
# Epoch 340/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0533 - binary_accuracy: 0.9730
# Epoch 341/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0597 - binary_accuracy: 0.9692
# Epoch 342/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0543 - binary_accuracy: 0.9717
# Epoch 343/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0504 - binary_accuracy: 0.9735
# Epoch 344/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0575 - binary_accuracy: 0.9683
# Epoch 345/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0573 - binary_accuracy: 0.9692
# Epoch 346/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0583 - binary_accuracy: 0.9670
# Epoch 347/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0528 - binary_accuracy: 0.9757
# Epoch 348/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0535 - binary_accuracy: 0.9715
# Epoch 349/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0562 - binary_accuracy: 0.9712
# Epoch 350/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0585 - binary_accuracy: 0.9690
# Epoch 351/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0473 - binary_accuracy: 0.9769
# Epoch 352/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0515 - binary_accuracy: 0.9725
# Epoch 353/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0530 - binary_accuracy: 0.9705
# Epoch 354/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0491 - binary_accuracy: 0.9754
# Epoch 355/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0554 - binary_accuracy: 0.9712
# Epoch 356/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0565 - binary_accuracy: 0.9707
# Epoch 357/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0527 - binary_accuracy: 0.9725
# Epoch 358/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0645 - binary_accuracy: 0.9668
# Epoch 359/500
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0553 - binary_accuracy: 0.9725
# Epoch 360/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0552 - binary_accuracy: 0.9695
# Epoch 361/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0672 - binary_accuracy: 0.9648
# Epoch 362/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0583 - binary_accuracy: 0.9673
# Epoch 363/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0554 - binary_accuracy: 0.9712
# Epoch 364/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0539 - binary_accuracy: 0.9705
# Epoch 365/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0511 - binary_accuracy: 0.9750
# Epoch 366/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0568 - binary_accuracy: 0.9702
# Epoch 367/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0501 - binary_accuracy: 0.9752
# Epoch 368/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0545 - binary_accuracy: 0.9700
# Epoch 369/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0502 - binary_accuracy: 0.9757
# Epoch 370/500
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0484 - binary_accuracy: 0.9759
# Epoch 371/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0554 - binary_accuracy: 0.9707
# Epoch 372/500
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0548 - binary_accuracy: 0.9702
# Epoch 373/500
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0542 - binary_accuracy: 0.9735
# Epoch 374/500
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0514 - binary_accuracy: 0.9722
# Epoch 375/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0544 - binary_accuracy: 0.9710
# Epoch 376/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0485 - binary_accuracy: 0.9752
# Epoch 377/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0636 - binary_accuracy: 0.9665
# Epoch 378/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0507 - binary_accuracy: 0.9735
# Epoch 379/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0557 - binary_accuracy: 0.9707
# Epoch 380/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0527 - binary_accuracy: 0.9737
# Epoch 381/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0568 - binary_accuracy: 0.9697
# Epoch 382/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0579 - binary_accuracy: 0.9710
# Epoch 383/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0548 - binary_accuracy: 0.9702
# Epoch 384/500
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0507 - binary_accuracy: 0.9740
# Epoch 385/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0611 - binary_accuracy: 0.9660
# Epoch 386/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0606 - binary_accuracy: 0.9710
# Epoch 387/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0554 - binary_accuracy: 0.9717
# Epoch 388/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0547 - binary_accuracy: 0.9717
# Epoch 389/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0546 - binary_accuracy: 0.9695
# Epoch 390/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0523 - binary_accuracy: 0.9737
# Epoch 391/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0566 - binary_accuracy: 0.9680
# Epoch 392/500
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0609 - binary_accuracy: 0.9663
# Epoch 393/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0569 - binary_accuracy: 0.9680
# Epoch 394/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0484 - binary_accuracy: 0.9737
# Epoch 395/500
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0557 - binary_accuracy: 0.9697
# Epoch 396/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0566 - binary_accuracy: 0.9705
# Epoch 397/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0547 - binary_accuracy: 0.9695
# Epoch 398/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0530 - binary_accuracy: 0.9697
# Epoch 399/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0540 - binary_accuracy: 0.9745
# Epoch 400/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0543 - binary_accuracy: 0.9692
# Epoch 401/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0524 - binary_accuracy: 0.9715
# Epoch 402/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0604 - binary_accuracy: 0.9670
# Epoch 403/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0520 - binary_accuracy: 0.9710
# Epoch 404/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0569 - binary_accuracy: 0.9722
# Epoch 405/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0590 - binary_accuracy: 0.9685
# Epoch 406/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0549 - binary_accuracy: 0.9747
# Epoch 407/500
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0502 - binary_accuracy: 0.9745
# Epoch 408/500
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0510 - binary_accuracy: 0.9700
# Epoch 409/500
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0539 - binary_accuracy: 0.9722
# Epoch 410/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0558 - binary_accuracy: 0.9712
# Epoch 411/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0585 - binary_accuracy: 0.9717
# Epoch 412/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0560 - binary_accuracy: 0.9688
# Epoch 413/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0552 - binary_accuracy: 0.9740
# Epoch 414/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0530 - binary_accuracy: 0.9727
# Epoch 415/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0514 - binary_accuracy: 0.9730
# Epoch 416/500
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0550 - binary_accuracy: 0.9722
# Epoch 417/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0529 - binary_accuracy: 0.9727
# Epoch 418/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0536 - binary_accuracy: 0.9710
# Epoch 419/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0625 - binary_accuracy: 0.9660
# Epoch 420/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0507 - binary_accuracy: 0.9737
# Epoch 421/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0513 - binary_accuracy: 0.9752
# Epoch 422/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0552 - binary_accuracy: 0.9722
# Epoch 423/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0600 - binary_accuracy: 0.9673
# Epoch 424/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0593 - binary_accuracy: 0.9678
# Epoch 425/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0539 - binary_accuracy: 0.9715
# Epoch 426/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0505 - binary_accuracy: 0.9762
# Epoch 427/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0583 - binary_accuracy: 0.9702
# Epoch 428/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0494 - binary_accuracy: 0.9757
# Epoch 429/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0470 - binary_accuracy: 0.9754
# Epoch 430/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0556 - binary_accuracy: 0.9710
# Epoch 431/500
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0566 - binary_accuracy: 0.9715
# Epoch 432/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0537 - binary_accuracy: 0.9720
# Epoch 433/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0572 - binary_accuracy: 0.9690
# Epoch 434/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0512 - binary_accuracy: 0.9745
# Epoch 435/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0517 - binary_accuracy: 0.9725
# Epoch 436/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0526 - binary_accuracy: 0.9722
# Epoch 437/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0564 - binary_accuracy: 0.9707
# Epoch 438/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0550 - binary_accuracy: 0.9730
# Epoch 439/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0560 - binary_accuracy: 0.9712
# Epoch 440/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0529 - binary_accuracy: 0.9720
# Epoch 441/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0495 - binary_accuracy: 0.9747
# Epoch 442/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0551 - binary_accuracy: 0.9730
# Epoch 443/500
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0597 - binary_accuracy: 0.9685
# Epoch 444/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0556 - binary_accuracy: 0.9707
# Epoch 445/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0575 - binary_accuracy: 0.9702
# Epoch 446/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0510 - binary_accuracy: 0.9754
# Epoch 447/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0514 - binary_accuracy: 0.9715
# Epoch 448/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0618 - binary_accuracy: 0.9670
# Epoch 449/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0533 - binary_accuracy: 0.9722
# Epoch 450/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0560 - binary_accuracy: 0.9715
# Epoch 451/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0592 - binary_accuracy: 0.9692
# Epoch 452/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0555 - binary_accuracy: 0.9720
# Epoch 453/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0483 - binary_accuracy: 0.9722
# Epoch 454/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0506 - binary_accuracy: 0.9720
# Epoch 455/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0517 - binary_accuracy: 0.9730
# Epoch 456/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0526 - binary_accuracy: 0.9715
# Epoch 457/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0615 - binary_accuracy: 0.9663
# Epoch 458/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0529 - binary_accuracy: 0.9722
# Epoch 459/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0511 - binary_accuracy: 0.9717
# Epoch 460/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0536 - binary_accuracy: 0.9715
# Epoch 461/500
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0485 - binary_accuracy: 0.9767
# Epoch 462/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0598 - binary_accuracy: 0.9710
# Epoch 463/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0575 - binary_accuracy: 0.9707
# Epoch 464/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0544 - binary_accuracy: 0.9740
# Epoch 465/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0506 - binary_accuracy: 0.9772
# Epoch 466/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0513 - binary_accuracy: 0.9715
# Epoch 467/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0519 - binary_accuracy: 0.9735
# Epoch 468/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0579 - binary_accuracy: 0.9678
# Epoch 469/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0646 - binary_accuracy: 0.9660
# Epoch 470/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0549 - binary_accuracy: 0.9695
# Epoch 471/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0507 - binary_accuracy: 0.9732
# Epoch 472/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0592 - binary_accuracy: 0.9668
# Epoch 473/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0468 - binary_accuracy: 0.9764
# Epoch 474/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0555 - binary_accuracy: 0.9722
# Epoch 475/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0551 - binary_accuracy: 0.9715
# Epoch 476/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0535 - binary_accuracy: 0.9712
# Epoch 477/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0531 - binary_accuracy: 0.9730
# Epoch 478/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0558 - binary_accuracy: 0.9695
# Epoch 479/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0525 - binary_accuracy: 0.9727
# Epoch 480/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0499 - binary_accuracy: 0.9717
# Epoch 481/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0552 - binary_accuracy: 0.9710
# Epoch 482/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0550 - binary_accuracy: 0.9702
# Epoch 483/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0532 - binary_accuracy: 0.9705
# Epoch 484/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0532 - binary_accuracy: 0.9742
# Epoch 485/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0551 - binary_accuracy: 0.9717
# Epoch 486/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0548 - binary_accuracy: 0.9717
# Epoch 487/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0502 - binary_accuracy: 0.9754
# Epoch 488/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0546 - binary_accuracy: 0.9707
# Epoch 489/500
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0619 - binary_accuracy: 0.9673
# Epoch 490/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0535 - binary_accuracy: 0.9725
# Epoch 491/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0593 - binary_accuracy: 0.9683
# Epoch 492/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0544 - binary_accuracy: 0.9697
# Epoch 493/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0551 - binary_accuracy: 0.9690
# Epoch 494/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0514 - binary_accuracy: 0.9762
# Epoch 495/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0534 - binary_accuracy: 0.9725
# Epoch 496/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0566 - binary_accuracy: 0.9707
# Epoch 497/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0503 - binary_accuracy: 0.9737
# Epoch 498/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0517 - binary_accuracy: 0.9740
# Epoch 499/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0546 - binary_accuracy: 0.9727
# Epoch 500/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0520 - binary_accuracy: 0.9707

# %%
# extract relational cross-attention layer
relational_crossattention = model.abstractor.abstracter_layers[0].relational_crossattention.mha

# %%
# plot final model outputs for each pair of objects 
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        inputs = tf.one_hot(np.array([[i,j]]), num_objects)
        order_relation_matrix[i,j] = model(inputs)[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a pair of objects

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_pair = tf.one_hot(np.array([[i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_pair, key=object_pair, 
            value=object_pair, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[0][1]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a triplet of objects
# here, we fix the first object and vary second two, then we plot the relations of the other two objects
# with linear/sigmoid/tanh activation, adding objects does not affect the relations between existing objcets
# i.e.: this is exactly the same plot as the above (unlike with softmax activation)

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_triple = tf.one_hot(np.array([[16, i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_triple, key=object_triple, 
            value=object_triple, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[1][2]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 30
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(attention_scores)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')

# %%
objects = tf.expand_dims(tf.one_hot(np.arange(num_objects), num_objects), axis=0)

# %%
# now, compute the relations between all pairs directly 
# by passing all the objects to the relational cross-attention simultaneously
# the results are now interpretable, unlike with softmax!
# again, exact same plot as above; relation depends only on pair

attention_output, attention_scores = relational_crossattention(query=objects, key=objects, value=objects, return_attention_scores=True)
attention_scores = np.squeeze(attention_scores)
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(attention_scores.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 16
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(attention_scores)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')
