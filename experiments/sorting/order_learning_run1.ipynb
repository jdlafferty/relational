# %% [markdown]
# # Learning Order Relations

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import itertools
np.random.seed(42)

# %% [markdown]
# ## Order Relation Model
#
#
# **Task**: Given two objects $(o_1, o_2) \in \mathcal{O} \times \mathcal{O}$, predict the relation $o_1 \prec o_2$
#
# **Model**:
# 1) Embed each object: $o_1 \mapsto e_1, o_2 \mapsto e_2$
# 2) Project the first object via $W^1$ and the second object via $W^2$, then compute inner product: $\langle W^1 e_1, W^2 e_2 \rangle$.
# 3) Return relation as sigmoid function $\text{Sigmoid}\left( \langle W^1 e_1, W^2 e_2 \rangle \right)$
#
# *Note:* Here, the objects are tokens. (i.e.: integers. so the embedding layer maps $i \mapsto e_i$ for each $i \in \{1, ..., |\mathcal{O}| \}$)

# %%
class OrderRelation(tf.keras.Model):
    def __init__(self, num_objects, embedding_dim, proj_dim, name=None):
        super().__init__(name=name)
        self.num_objects = num_objects
        self.embedding_dim = embedding_dim
        self.proj_dim = proj_dim
    
    def build(self, input_shape):

        self.embedding = layers.Embedding(input_dim=self.num_objects, output_dim=self.embedding_dim)

        normal_initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=.1, seed=1)
        self.W1 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
        self.W2 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
    
    def compute_innerprod_rel(self, inputs):
        embeddings = self.embedding(inputs)
        
        o1 = embeddings[:, 0]
        o2 = embeddings[:, 1]
        e1 = tf.matmul(o1, self.W1)
        e2 = tf.matmul(o2, self.W2)

        innerprod_rel = tf.einsum('ij,ij->i', e1, e2) # compute inner product

        return innerprod_rel

    def call(self, inputs):

        innerprod_rel = self.compute_innerprod_rel(inputs)

        return innerprod_rel

# %% [markdown]
# ## Order Relation Dataset
#
# Model is fit on all pairs of objects and their associated relations.

# %%
# create data set for learning order relatios
num_objects = 64
object_pairs = np.array(list(itertools.permutations(range(num_objects), r=2)))
object_order_relations = (object_pairs[:,0] < object_pairs[:, 1]).astype(int)

# %%
sample = np.random.choice(len(object_pairs), 10)
for object_pair, relation in zip(object_pairs[sample], object_order_relations[sample]):
    print(f'object pair: {tuple(object_pair)}; relation: {relation}')
# Out:
# object pair: (50, 24); relation: 0
# object pair: (55, 42); relation: 0
# object pair: (13, 42); relation: 1
# object pair: (20, 35); relation: 1
# object pair: (17, 60); relation: 1
# object pair: (17, 25); relation: 1
# object pair: (59, 55); relation: 0
# object pair: (49, 5); relation: 0
# object pair: (26, 0); relation: 0
# object pair: (34, 27); relation: 0

# %% [markdown]
# ## Fit Relation Model

# %%
embedding_dim = 16
proj_dim = 8

order_relation = OrderRelation(num_objects, embedding_dim, proj_dim, name='order_relation')
order_relation(object_pairs); # build model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
order_relation.compile(loss='mse', optimizer=opt, metrics='binary_accuracy')

# %%
order_relation.fit(object_pairs, object_order_relations, epochs=200, batch_size=len(object_pairs))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 512ms/step - loss: 0.5000 - binary_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4893 - binary_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4199 - binary_accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2676 - binary_accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7113 - binary_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2682 - binary_accuracy: 0.5000
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2785 - binary_accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3511 - binary_accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3956 - binary_accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4167 - binary_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4233 - binary_accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4191 - binary_accuracy: 0.5000
# Epoch 13/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4042 - binary_accuracy: 0.5000
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3760 - binary_accuracy: 0.5000
# Epoch 15/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3312 - binary_accuracy: 0.5000
# Epoch 16/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2696 - binary_accuracy: 0.5000
# Epoch 17/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2040 - binary_accuracy: 0.6235
# Epoch 18/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1787 - binary_accuracy: 0.7267
# Epoch 19/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2222 - binary_accuracy: 0.5642
# Epoch 20/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2091 - binary_accuracy: 0.6002
# Epoch 21/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1408 - binary_accuracy: 0.7827
# Epoch 22/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0978 - binary_accuracy: 0.9105
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0970 - binary_accuracy: 0.8981
# Epoch 24/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1161 - binary_accuracy: 0.8415
# Epoch 25/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1364 - binary_accuracy: 0.8239
# Epoch 26/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1478 - binary_accuracy: 0.8271
# Epoch 27/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1448 - binary_accuracy: 0.8418
# Epoch 28/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1288 - binary_accuracy: 0.8700
# Epoch 29/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1078 - binary_accuracy: 0.8934
# Epoch 30/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0918 - binary_accuracy: 0.8958
# Epoch 31/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0864 - binary_accuracy: 0.8862
# Epoch 32/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0893 - binary_accuracy: 0.8790
# Epoch 33/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0922 - binary_accuracy: 0.8686
# Epoch 34/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0908 - binary_accuracy: 0.8718
# Epoch 35/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0873 - binary_accuracy: 0.8919
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0846 - binary_accuracy: 0.9184
# Epoch 37/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0828 - binary_accuracy: 0.9437
# Epoch 38/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0810 - binary_accuracy: 0.9655
# Epoch 39/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0796 - binary_accuracy: 0.9767
# Epoch 40/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0794 - binary_accuracy: 0.9725
# Epoch 41/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0809 - binary_accuracy: 0.9710
# Epoch 42/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0822 - binary_accuracy: 0.9705
# Epoch 43/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0808 - binary_accuracy: 0.9745
# Epoch 44/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0767 - binary_accuracy: 0.9774
# Epoch 45/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0720 - binary_accuracy: 0.9700
# Epoch 46/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0693 - binary_accuracy: 0.9613
# Epoch 47/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0689 - binary_accuracy: 0.9501
# Epoch 48/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0697 - binary_accuracy: 0.9400
# Epoch 49/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0704 - binary_accuracy: 0.9325
# Epoch 50/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0703 - binary_accuracy: 0.9273
# Epoch 51/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0694 - binary_accuracy: 0.9229
# Epoch 52/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0676 - binary_accuracy: 0.9249
# Epoch 53/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0653 - binary_accuracy: 0.9338
# Epoch 54/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0628 - binary_accuracy: 0.9420
# Epoch 55/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0607 - binary_accuracy: 0.9516
# Epoch 56/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0591 - binary_accuracy: 0.9608
# Epoch 57/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0575 - binary_accuracy: 0.9685
# Epoch 58/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0554 - binary_accuracy: 0.9772
# Epoch 59/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0530 - binary_accuracy: 0.9826
# Epoch 60/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0506 - binary_accuracy: 0.9841
# Epoch 61/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0487 - binary_accuracy: 0.9839
# Epoch 62/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0473 - binary_accuracy: 0.9861
# Epoch 63/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0463 - binary_accuracy: 0.9898
# Epoch 64/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0458 - binary_accuracy: 0.9923
# Epoch 65/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0461 - binary_accuracy: 0.9918
# Epoch 66/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0469 - binary_accuracy: 0.9883
# Epoch 67/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0477 - binary_accuracy: 0.9844
# Epoch 68/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0481 - binary_accuracy: 0.9829
# Epoch 69/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0479 - binary_accuracy: 0.9836
# Epoch 70/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0472 - binary_accuracy: 0.9864
# Epoch 71/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0463 - binary_accuracy: 0.9916
# Epoch 72/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0454 - binary_accuracy: 0.9936
# Epoch 73/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0447 - binary_accuracy: 0.9958
# Epoch 74/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0443 - binary_accuracy: 0.9975
# Epoch 75/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0441 - binary_accuracy: 0.9983
# Epoch 76/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0438 - binary_accuracy: 0.9985
# Epoch 77/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0436 - binary_accuracy: 0.9988
# Epoch 78/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0436 - binary_accuracy: 0.9988
# Epoch 79/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0436 - binary_accuracy: 0.9970
# Epoch 80/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0436 - binary_accuracy: 0.9960
# Epoch 81/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0434 - binary_accuracy: 0.9965
# Epoch 82/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0432 - binary_accuracy: 0.9963
# Epoch 83/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0428 - binary_accuracy: 0.9968
# Epoch 84/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0424 - binary_accuracy: 0.9975
# Epoch 85/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0418 - binary_accuracy: 0.9985
# Epoch 86/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0412 - binary_accuracy: 0.9968
# Epoch 87/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0406 - binary_accuracy: 0.9960
# Epoch 88/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0400 - binary_accuracy: 0.9958
# Epoch 89/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0394 - binary_accuracy: 0.9958
# Epoch 90/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0388 - binary_accuracy: 0.9953
# Epoch 91/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0381 - binary_accuracy: 0.9950
# Epoch 92/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0375 - binary_accuracy: 0.9953
# Epoch 93/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0368 - binary_accuracy: 0.9950
# Epoch 94/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0360 - binary_accuracy: 0.9950
# Epoch 95/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0353 - binary_accuracy: 0.9953
# Epoch 96/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0345 - binary_accuracy: 0.9960
# Epoch 97/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0337 - binary_accuracy: 0.9965
# Epoch 98/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0330 - binary_accuracy: 0.9960
# Epoch 99/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0324 - binary_accuracy: 0.9963
# Epoch 100/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0318 - binary_accuracy: 0.9958
# Epoch 101/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0314 - binary_accuracy: 0.9955
# Epoch 102/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0312 - binary_accuracy: 0.9955
# Epoch 103/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0310 - binary_accuracy: 0.9953
# Epoch 104/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0310 - binary_accuracy: 0.9950
# Epoch 105/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0310 - binary_accuracy: 0.9945
# Epoch 106/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0311 - binary_accuracy: 0.9943
# Epoch 107/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0311 - binary_accuracy: 0.9940
# Epoch 108/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0310 - binary_accuracy: 0.9938
# Epoch 109/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0309 - binary_accuracy: 0.9931
# Epoch 110/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0307 - binary_accuracy: 0.9926
# Epoch 111/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0305 - binary_accuracy: 0.9928
# Epoch 112/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0303 - binary_accuracy: 0.9926
# Epoch 113/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0302 - binary_accuracy: 0.9921
# Epoch 114/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0300 - binary_accuracy: 0.9916
# Epoch 115/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0298 - binary_accuracy: 0.9911
# Epoch 116/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0297 - binary_accuracy: 0.9906
# Epoch 117/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0295 - binary_accuracy: 0.9906
# Epoch 118/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0294 - binary_accuracy: 0.9906
# Epoch 119/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0292 - binary_accuracy: 0.9908
# Epoch 120/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0290 - binary_accuracy: 0.9908
# Epoch 121/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0288 - binary_accuracy: 0.9911
# Epoch 122/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0287 - binary_accuracy: 0.9913
# Epoch 123/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0285 - binary_accuracy: 0.9916
# Epoch 124/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0283 - binary_accuracy: 0.9916
# Epoch 125/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0282 - binary_accuracy: 0.9916
# Epoch 126/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0280 - binary_accuracy: 0.9921
# Epoch 127/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0278 - binary_accuracy: 0.9923
# Epoch 128/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0277 - binary_accuracy: 0.9928
# Epoch 129/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0275 - binary_accuracy: 0.9933
# Epoch 130/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0274 - binary_accuracy: 0.9936
# Epoch 131/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0272 - binary_accuracy: 0.9936
# Epoch 132/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0271 - binary_accuracy: 0.9943
# Epoch 133/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0269 - binary_accuracy: 0.9943
# Epoch 134/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0267 - binary_accuracy: 0.9945
# Epoch 135/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0266 - binary_accuracy: 0.9950
# Epoch 136/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0264 - binary_accuracy: 0.9953
# Epoch 137/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0262 - binary_accuracy: 0.9955
# Epoch 138/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0261 - binary_accuracy: 0.9955
# Epoch 139/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0259 - binary_accuracy: 0.9963
# Epoch 140/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0258 - binary_accuracy: 0.9963
# Epoch 141/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0256 - binary_accuracy: 0.9965
# Epoch 142/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0255 - binary_accuracy: 0.9968
# Epoch 143/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0253 - binary_accuracy: 0.9970
# Epoch 144/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0252 - binary_accuracy: 0.9970
# Epoch 145/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0250 - binary_accuracy: 0.9970
# Epoch 146/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0248 - binary_accuracy: 0.9970
# Epoch 147/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0247 - binary_accuracy: 0.9975
# Epoch 148/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0245 - binary_accuracy: 0.9975
# Epoch 149/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0243 - binary_accuracy: 0.9973
# Epoch 150/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0242 - binary_accuracy: 0.9978
# Epoch 151/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0240 - binary_accuracy: 0.9980
# Epoch 152/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0239 - binary_accuracy: 0.9980
# Epoch 153/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0237 - binary_accuracy: 0.9978
# Epoch 154/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0236 - binary_accuracy: 0.9978
# Epoch 155/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0235 - binary_accuracy: 0.9975
# Epoch 156/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0234 - binary_accuracy: 0.9973
# Epoch 157/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0233 - binary_accuracy: 0.9973
# Epoch 158/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0232 - binary_accuracy: 0.9970
# Epoch 159/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0231 - binary_accuracy: 0.9968
# Epoch 160/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0230 - binary_accuracy: 0.9970
# Epoch 161/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0229 - binary_accuracy: 0.9970
# Epoch 162/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0229 - binary_accuracy: 0.9970
# Epoch 163/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0228 - binary_accuracy: 0.9970
# Epoch 164/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0227 - binary_accuracy: 0.9970
# Epoch 165/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0227 - binary_accuracy: 0.9970
# Epoch 166/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 167/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 168/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 169/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 170/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0225 - binary_accuracy: 0.9973
# Epoch 171/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 172/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 173/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 174/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0223 - binary_accuracy: 0.9973
# Epoch 175/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0223 - binary_accuracy: 0.9975
# Epoch 176/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - binary_accuracy: 0.9980
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0222 - binary_accuracy: 0.9980
# Epoch 178/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0222 - binary_accuracy: 0.9980
# Epoch 179/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0221 - binary_accuracy: 0.9980
# Epoch 180/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0221 - binary_accuracy: 0.9980
# Epoch 181/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0221 - binary_accuracy: 0.9980
# Epoch 182/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0220 - binary_accuracy: 0.9980
# Epoch 183/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0220 - binary_accuracy: 0.9980
# Epoch 184/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0219 - binary_accuracy: 0.9980
# Epoch 185/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0219 - binary_accuracy: 0.9980
# Epoch 186/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0219 - binary_accuracy: 0.9980
# Epoch 187/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0218 - binary_accuracy: 0.9980
# Epoch 188/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0218 - binary_accuracy: 0.9980
# Epoch 189/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 190/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 191/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0216 - binary_accuracy: 0.9978
# Epoch 192/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0215 - binary_accuracy: 0.9978
# Epoch 193/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0215 - binary_accuracy: 0.9978
# Epoch 194/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0214 - binary_accuracy: 0.9978
# Epoch 195/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0214 - binary_accuracy: 0.9978
# Epoch 196/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - binary_accuracy: 0.9978
# Epoch 197/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0212 - binary_accuracy: 0.9978
# Epoch 198/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0212 - binary_accuracy: 0.9978
# Epoch 199/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0211 - binary_accuracy: 0.9978
# Epoch 200/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0210 - binary_accuracy: 0.9978

# %%
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        order_relation_matrix[i,j] = order_relation.compute_innerprod_rel(np.array([[i,j]]))[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\langle W_1 e_i, W_2 e_j \\rangle$');

# %%
fig, ax = plt.subplots(figsize=(6,6))
order_relation_matrix_softmax = tf.nn.softmax(order_relation_matrix, axis=1).numpy()
im = ax.imshow(order_relation_matrix_softmax.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\mathrm{softmax}(\\langle W_1 e_i, W_2 e_j \\rangle)$');

# %%
#x = tf.nn.softmax(order_relation_matrix, axis=1)
x = order_relation_matrix
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x[32, :])

# %% [markdown]
# # Learn Order Relation with `SimpleAbstractor`

# %%
import sys; sys.path.append('..'); sys.path.append('../..')

from abstracters import SimpleAbstractor

# %%
class AbstractorOrderRelation(tf.keras.Model):
    def __init__(self, name=None):
        super().__init__(name=name)
    
    def build(self, input_shape):
        # note: changed activation of MHA to tanh!
        self.abstractor = SimpleAbstractor(num_layers=1, num_heads=1, dff=32, use_pos_embedding=False, mha_activation_type='tanh')
        self.dense = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.abstractor(inputs)
        x = x[:, 0]
        x = self.dense(x)

        return x

# %%
object_pairs_onehot = tf.one_hot(object_pairs, num_objects)
object_pairs_onehot.shape
# Out:
# TensorShape([4032, 2, 64])

# %%
model = AbstractorOrderRelation()
model(object_pairs_onehot)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics='binary_accuracy')
model.summary()
# Out:
# Model: "abstractor_order_relation_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relational_abstracter (Simp  multiple                 21216
#  leAbstractor)
#
#  dense_3 (Dense)             multiple                  65
#
# =================================================================
# Total params: 21,281
# Trainable params: 21,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(object_pairs_onehot, object_order_relations, epochs=500, batch_size=len(object_pairs))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.8386 - binary_accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7650 - binary_accuracy: 0.4975
# Epoch 3/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.7295 - binary_accuracy: 0.4963
# Epoch 4/500
# 1/1 [==============================] - 0s 148ms/step - loss: 0.7190 - binary_accuracy: 0.5005
# Epoch 5/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.7329 - binary_accuracy: 0.4965
# Epoch 6/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.7432 - binary_accuracy: 0.4983
# Epoch 7/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.7433 - binary_accuracy: 0.5084
# Epoch 8/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.7397 - binary_accuracy: 0.5129
# Epoch 9/500
# 1/1 [==============================] - 0s 104ms/step - loss: 0.7406 - binary_accuracy: 0.5007
# Epoch 10/500
# 1/1 [==============================] - 0s 104ms/step - loss: 0.7227 - binary_accuracy: 0.5027
# Epoch 11/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.7101 - binary_accuracy: 0.5246
# Epoch 12/500
# 1/1 [==============================] - 0s 115ms/step - loss: 0.7137 - binary_accuracy: 0.4968
# Epoch 13/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.7106 - binary_accuracy: 0.5169
# Epoch 14/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.7119 - binary_accuracy: 0.5124
# Epoch 15/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.7107 - binary_accuracy: 0.5255
# Epoch 16/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.7171 - binary_accuracy: 0.5154
# Epoch 17/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.7134 - binary_accuracy: 0.5231
# Epoch 18/500
# 1/1 [==============================] - 0s 93ms/step - loss: 0.7137 - binary_accuracy: 0.5184
# Epoch 19/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.7102 - binary_accuracy: 0.5171
# Epoch 20/500
# 1/1 [==============================] - 0s 127ms/step - loss: 0.7033 - binary_accuracy: 0.5372
# Epoch 21/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6907 - binary_accuracy: 0.5432
# Epoch 22/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6840 - binary_accuracy: 0.5588
# Epoch 23/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6820 - binary_accuracy: 0.5737
# Epoch 24/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.6740 - binary_accuracy: 0.5806
# Epoch 25/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6673 - binary_accuracy: 0.5980
# Epoch 26/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6672 - binary_accuracy: 0.6017
# Epoch 27/500
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6643 - binary_accuracy: 0.6032
# Epoch 28/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6495 - binary_accuracy: 0.6337
# Epoch 29/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6339 - binary_accuracy: 0.6545
# Epoch 30/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6251 - binary_accuracy: 0.6756
# Epoch 31/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6164 - binary_accuracy: 0.6721
# Epoch 32/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6070 - binary_accuracy: 0.6937
# Epoch 33/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5950 - binary_accuracy: 0.7071
# Epoch 34/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5794 - binary_accuracy: 0.7235
# Epoch 35/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5785 - binary_accuracy: 0.7175
# Epoch 36/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5681 - binary_accuracy: 0.7247
# Epoch 37/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5687 - binary_accuracy: 0.7202
# Epoch 38/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5580 - binary_accuracy: 0.7257
# Epoch 39/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5519 - binary_accuracy: 0.7331
# Epoch 40/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5521 - binary_accuracy: 0.7173
# Epoch 41/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5440 - binary_accuracy: 0.7319
# Epoch 42/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.5505 - binary_accuracy: 0.7274
# Epoch 43/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.5465 - binary_accuracy: 0.7287
# Epoch 44/500
# 1/1 [==============================] - 0s 108ms/step - loss: 0.5495 - binary_accuracy: 0.7237
# Epoch 45/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.5447 - binary_accuracy: 0.7245
# Epoch 46/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5300 - binary_accuracy: 0.7279
# Epoch 47/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5347 - binary_accuracy: 0.7264
# Epoch 48/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5385 - binary_accuracy: 0.7185
# Epoch 49/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.5321 - binary_accuracy: 0.7242
# Epoch 50/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5347 - binary_accuracy: 0.7173
# Epoch 51/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5288 - binary_accuracy: 0.7207
# Epoch 52/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5242 - binary_accuracy: 0.7250
# Epoch 53/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5297 - binary_accuracy: 0.7195
# Epoch 54/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5335 - binary_accuracy: 0.7103
# Epoch 55/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5308 - binary_accuracy: 0.7103
# Epoch 56/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5323 - binary_accuracy: 0.7108
# Epoch 57/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5248 - binary_accuracy: 0.7143
# Epoch 58/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5275 - binary_accuracy: 0.7180
# Epoch 59/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5303 - binary_accuracy: 0.7106
# Epoch 60/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5225 - binary_accuracy: 0.7116
# Epoch 61/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5298 - binary_accuracy: 0.7068
# Epoch 62/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5205 - binary_accuracy: 0.7125
# Epoch 63/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5273 - binary_accuracy: 0.7101
# Epoch 64/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5234 - binary_accuracy: 0.7192
# Epoch 65/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5238 - binary_accuracy: 0.7155
# Epoch 66/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.5188 - binary_accuracy: 0.7220
# Epoch 67/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.5147 - binary_accuracy: 0.7242
# Epoch 68/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.5159 - binary_accuracy: 0.7237
# Epoch 69/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.5179 - binary_accuracy: 0.7215
# Epoch 70/500
# 1/1 [==============================] - 0s 113ms/step - loss: 0.5179 - binary_accuracy: 0.7237
# Epoch 71/500
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5138 - binary_accuracy: 0.7257
# Epoch 72/500
# 1/1 [==============================] - 0s 106ms/step - loss: 0.5058 - binary_accuracy: 0.7237
# Epoch 73/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.5119 - binary_accuracy: 0.7200
# Epoch 74/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.5082 - binary_accuracy: 0.7321
# Epoch 75/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5080 - binary_accuracy: 0.7259
# Epoch 76/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4980 - binary_accuracy: 0.7376
# Epoch 77/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4973 - binary_accuracy: 0.7346
# Epoch 78/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4851 - binary_accuracy: 0.7488
# Epoch 79/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4889 - binary_accuracy: 0.7393
# Epoch 80/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4782 - binary_accuracy: 0.7488
# Epoch 81/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4718 - binary_accuracy: 0.7619
# Epoch 82/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4663 - binary_accuracy: 0.7547
# Epoch 83/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4464 - binary_accuracy: 0.7755
# Epoch 84/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4350 - binary_accuracy: 0.7812
# Epoch 85/500
# 1/1 [==============================] - 0s 97ms/step - loss: 0.4263 - binary_accuracy: 0.7882
# Epoch 86/500
# 1/1 [==============================] - 0s 104ms/step - loss: 0.4132 - binary_accuracy: 0.7959
# Epoch 87/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.3948 - binary_accuracy: 0.8105
# Epoch 88/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3843 - binary_accuracy: 0.8242
# Epoch 89/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3614 - binary_accuracy: 0.8311
# Epoch 90/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.3428 - binary_accuracy: 0.8517
# Epoch 91/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.3175 - binary_accuracy: 0.8658
# Epoch 92/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.3032 - binary_accuracy: 0.8743
# Epoch 93/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2858 - binary_accuracy: 0.8881
# Epoch 94/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.2683 - binary_accuracy: 0.8956
# Epoch 95/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2588 - binary_accuracy: 0.9035
# Epoch 96/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2400 - binary_accuracy: 0.9164
# Epoch 97/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2170 - binary_accuracy: 0.9306
# Epoch 98/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2217 - binary_accuracy: 0.9283
# Epoch 99/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2056 - binary_accuracy: 0.9296
# Epoch 100/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.2119 - binary_accuracy: 0.9281
# Epoch 101/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.2069 - binary_accuracy: 0.9313
# Epoch 102/500
# 1/1 [==============================] - 0s 109ms/step - loss: 0.2133 - binary_accuracy: 0.9221
# Epoch 103/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.2082 - binary_accuracy: 0.9325
# Epoch 104/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2143 - binary_accuracy: 0.9236
# Epoch 105/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1983 - binary_accuracy: 0.9303
# Epoch 106/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1874 - binary_accuracy: 0.9313
# Epoch 107/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1928 - binary_accuracy: 0.9380
# Epoch 108/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.1971 - binary_accuracy: 0.9340
# Epoch 109/500
# 1/1 [==============================] - 0s 100ms/step - loss: 0.1734 - binary_accuracy: 0.9420
# Epoch 110/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1995 - binary_accuracy: 0.9375
# Epoch 111/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1696 - binary_accuracy: 0.9457
# Epoch 112/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1680 - binary_accuracy: 0.9469
# Epoch 113/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1653 - binary_accuracy: 0.9479
# Epoch 114/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1718 - binary_accuracy: 0.9452
# Epoch 115/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1547 - binary_accuracy: 0.9536
# Epoch 116/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1588 - binary_accuracy: 0.9529
# Epoch 117/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1547 - binary_accuracy: 0.9549
# Epoch 118/500
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1619 - binary_accuracy: 0.9489
# Epoch 119/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1608 - binary_accuracy: 0.9484
# Epoch 120/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1597 - binary_accuracy: 0.9492
# Epoch 121/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1495 - binary_accuracy: 0.9511
# Epoch 122/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1507 - binary_accuracy: 0.9576
# Epoch 123/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1369 - binary_accuracy: 0.9568
# Epoch 124/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1348 - binary_accuracy: 0.9554
# Epoch 125/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1424 - binary_accuracy: 0.9551
# Epoch 126/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1344 - binary_accuracy: 0.9578
# Epoch 127/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1381 - binary_accuracy: 0.9566
# Epoch 128/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1273 - binary_accuracy: 0.9586
# Epoch 129/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1115 - binary_accuracy: 0.9678
# Epoch 130/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1140 - binary_accuracy: 0.9618
# Epoch 131/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1175 - binary_accuracy: 0.9563
# Epoch 132/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1167 - binary_accuracy: 0.9596
# Epoch 133/500
# 1/1 [==============================] - 0s 108ms/step - loss: 0.1098 - binary_accuracy: 0.9635
# Epoch 134/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0977 - binary_accuracy: 0.9678
# Epoch 135/500
# 1/1 [==============================] - 0s 136ms/step - loss: 0.1057 - binary_accuracy: 0.9601
# Epoch 136/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1112 - binary_accuracy: 0.9635
# Epoch 137/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0931 - binary_accuracy: 0.9658
# Epoch 138/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1072 - binary_accuracy: 0.9653
# Epoch 139/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0926 - binary_accuracy: 0.9643
# Epoch 140/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0877 - binary_accuracy: 0.9675
# Epoch 141/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0917 - binary_accuracy: 0.9673
# Epoch 142/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0829 - binary_accuracy: 0.9658
# Epoch 143/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0908 - binary_accuracy: 0.9645
# Epoch 144/500
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0808 - binary_accuracy: 0.9643
# Epoch 145/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0874 - binary_accuracy: 0.9640
# Epoch 146/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0704 - binary_accuracy: 0.9747
# Epoch 147/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0810 - binary_accuracy: 0.9658
# Epoch 148/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0747 - binary_accuracy: 0.9688
# Epoch 149/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0759 - binary_accuracy: 0.9680
# Epoch 150/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0809 - binary_accuracy: 0.9613
# Epoch 151/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0748 - binary_accuracy: 0.9697
# Epoch 152/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0764 - binary_accuracy: 0.9685
# Epoch 153/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0778 - binary_accuracy: 0.9680
# Epoch 154/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0782 - binary_accuracy: 0.9670
# Epoch 155/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0744 - binary_accuracy: 0.9712
# Epoch 156/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0708 - binary_accuracy: 0.9683
# Epoch 157/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0682 - binary_accuracy: 0.9722
# Epoch 158/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0703 - binary_accuracy: 0.9697
# Epoch 159/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0694 - binary_accuracy: 0.9683
# Epoch 160/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0686 - binary_accuracy: 0.9705
# Epoch 161/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0751 - binary_accuracy: 0.9683
# Epoch 162/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0602 - binary_accuracy: 0.9740
# Epoch 163/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0617 - binary_accuracy: 0.9705
# Epoch 164/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0699 - binary_accuracy: 0.9705
# Epoch 165/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0538 - binary_accuracy: 0.9772
# Epoch 166/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0630 - binary_accuracy: 0.9712
# Epoch 167/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0663 - binary_accuracy: 0.9735
# Epoch 168/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0727 - binary_accuracy: 0.9680
# Epoch 169/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0609 - binary_accuracy: 0.9735
# Epoch 170/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0714 - binary_accuracy: 0.9668
# Epoch 171/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0635 - binary_accuracy: 0.9705
# Epoch 172/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0509 - binary_accuracy: 0.9752
# Epoch 173/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0587 - binary_accuracy: 0.9700
# Epoch 174/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0556 - binary_accuracy: 0.9737
# Epoch 175/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0702 - binary_accuracy: 0.9643
# Epoch 176/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0619 - binary_accuracy: 0.9727
# Epoch 177/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0648 - binary_accuracy: 0.9690
# Epoch 178/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0632 - binary_accuracy: 0.9705
# Epoch 179/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0629 - binary_accuracy: 0.9705
# Epoch 180/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0567 - binary_accuracy: 0.9725
# Epoch 181/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0666 - binary_accuracy: 0.9695
# Epoch 182/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0679 - binary_accuracy: 0.9648
# Epoch 183/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0557 - binary_accuracy: 0.9747
# Epoch 184/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0545 - binary_accuracy: 0.9735
# Epoch 185/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0513 - binary_accuracy: 0.9752
# Epoch 186/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0569 - binary_accuracy: 0.9745
# Epoch 187/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0538 - binary_accuracy: 0.9737
# Epoch 188/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0547 - binary_accuracy: 0.9737
# Epoch 189/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0562 - binary_accuracy: 0.9710
# Epoch 190/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0604 - binary_accuracy: 0.9678
# Epoch 191/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0668 - binary_accuracy: 0.9655
# Epoch 192/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0610 - binary_accuracy: 0.9685
# Epoch 193/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0600 - binary_accuracy: 0.9735
# Epoch 194/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0735 - binary_accuracy: 0.9653
# Epoch 195/500
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0584 - binary_accuracy: 0.9735
# Epoch 196/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0508 - binary_accuracy: 0.9762
# Epoch 197/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0548 - binary_accuracy: 0.9759
# Epoch 198/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0580 - binary_accuracy: 0.9702
# Epoch 199/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0579 - binary_accuracy: 0.9730
# Epoch 200/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0650 - binary_accuracy: 0.9665
# Epoch 201/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0578 - binary_accuracy: 0.9697
# Epoch 202/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0633 - binary_accuracy: 0.9665
# Epoch 203/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0620 - binary_accuracy: 0.9675
# Epoch 204/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0622 - binary_accuracy: 0.9688
# Epoch 205/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0614 - binary_accuracy: 0.9683
# Epoch 206/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0552 - binary_accuracy: 0.9722
# Epoch 207/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0592 - binary_accuracy: 0.9697
# Epoch 208/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0620 - binary_accuracy: 0.9653
# Epoch 209/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0593 - binary_accuracy: 0.9700
# Epoch 210/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0538 - binary_accuracy: 0.9712
# Epoch 211/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0624 - binary_accuracy: 0.9710
# Epoch 212/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0639 - binary_accuracy: 0.9697
# Epoch 213/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0587 - binary_accuracy: 0.9702
# Epoch 214/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0656 - binary_accuracy: 0.9648
# Epoch 215/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0625 - binary_accuracy: 0.9692
# Epoch 216/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0645 - binary_accuracy: 0.9660
# Epoch 217/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0474 - binary_accuracy: 0.9767
# Epoch 218/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0589 - binary_accuracy: 0.9715
# Epoch 219/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0554 - binary_accuracy: 0.9732
# Epoch 220/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0587 - binary_accuracy: 0.9707
# Epoch 221/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0557 - binary_accuracy: 0.9732
# Epoch 222/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0602 - binary_accuracy: 0.9697
# Epoch 223/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0544 - binary_accuracy: 0.9707
# Epoch 224/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0582 - binary_accuracy: 0.9675
# Epoch 225/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0623 - binary_accuracy: 0.9725
# Epoch 226/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0526 - binary_accuracy: 0.9717
# Epoch 227/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0621 - binary_accuracy: 0.9685
# Epoch 228/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0586 - binary_accuracy: 0.9702
# Epoch 229/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0591 - binary_accuracy: 0.9700
# Epoch 230/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0560 - binary_accuracy: 0.9722
# Epoch 231/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0518 - binary_accuracy: 0.9745
# Epoch 232/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0615 - binary_accuracy: 0.9705
# Epoch 233/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0587 - binary_accuracy: 0.9692
# Epoch 234/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0577 - binary_accuracy: 0.9722
# Epoch 235/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0597 - binary_accuracy: 0.9680
# Epoch 236/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0565 - binary_accuracy: 0.9702
# Epoch 237/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0587 - binary_accuracy: 0.9720
# Epoch 238/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0635 - binary_accuracy: 0.9685
# Epoch 239/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0540 - binary_accuracy: 0.9717
# Epoch 240/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0578 - binary_accuracy: 0.9732
# Epoch 241/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0577 - binary_accuracy: 0.9702
# Epoch 242/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0555 - binary_accuracy: 0.9710
# Epoch 243/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0537 - binary_accuracy: 0.9727
# Epoch 244/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0544 - binary_accuracy: 0.9717
# Epoch 245/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0536 - binary_accuracy: 0.9695
# Epoch 246/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0548 - binary_accuracy: 0.9715
# Epoch 247/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0537 - binary_accuracy: 0.9732
# Epoch 248/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0537 - binary_accuracy: 0.9735
# Epoch 249/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0495 - binary_accuracy: 0.9772
# Epoch 250/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0557 - binary_accuracy: 0.9717
# Epoch 251/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0479 - binary_accuracy: 0.9779
# Epoch 252/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0544 - binary_accuracy: 0.9715
# Epoch 253/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0530 - binary_accuracy: 0.9727
# Epoch 254/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0587 - binary_accuracy: 0.9665
# Epoch 255/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0578 - binary_accuracy: 0.9710
# Epoch 256/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0534 - binary_accuracy: 0.9715
# Epoch 257/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0630 - binary_accuracy: 0.9695
# Epoch 258/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0582 - binary_accuracy: 0.9680
# Epoch 259/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0504 - binary_accuracy: 0.9747
# Epoch 260/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0552 - binary_accuracy: 0.9695
# Epoch 261/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0564 - binary_accuracy: 0.9690
# Epoch 262/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0538 - binary_accuracy: 0.9735
# Epoch 263/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0556 - binary_accuracy: 0.9710
# Epoch 264/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0552 - binary_accuracy: 0.9702
# Epoch 265/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0615 - binary_accuracy: 0.9660
# Epoch 266/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0516 - binary_accuracy: 0.9722
# Epoch 267/500
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0567 - binary_accuracy: 0.9705
# Epoch 268/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0546 - binary_accuracy: 0.9715
# Epoch 269/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0544 - binary_accuracy: 0.9710
# Epoch 270/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0592 - binary_accuracy: 0.9683
# Epoch 271/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0575 - binary_accuracy: 0.9680
# Epoch 272/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0561 - binary_accuracy: 0.9722
# Epoch 273/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0602 - binary_accuracy: 0.9650
# Epoch 274/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0581 - binary_accuracy: 0.9715
# Epoch 275/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0592 - binary_accuracy: 0.9712
# Epoch 276/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0556 - binary_accuracy: 0.9725
# Epoch 277/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0534 - binary_accuracy: 0.9710
# Epoch 278/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0536 - binary_accuracy: 0.9720
# Epoch 279/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0588 - binary_accuracy: 0.9720
# Epoch 280/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0534 - binary_accuracy: 0.9740
# Epoch 281/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0518 - binary_accuracy: 0.9732
# Epoch 282/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0590 - binary_accuracy: 0.9692
# Epoch 283/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0482 - binary_accuracy: 0.9764
# Epoch 284/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0609 - binary_accuracy: 0.9690
# Epoch 285/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0569 - binary_accuracy: 0.9695
# Epoch 286/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0503 - binary_accuracy: 0.9735
# Epoch 287/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0534 - binary_accuracy: 0.9715
# Epoch 288/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0523 - binary_accuracy: 0.9732
# Epoch 289/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0505 - binary_accuracy: 0.9752
# Epoch 290/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0474 - binary_accuracy: 0.9737
# Epoch 291/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0521 - binary_accuracy: 0.9722
# Epoch 292/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0449 - binary_accuracy: 0.9779
# Epoch 293/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0504 - binary_accuracy: 0.9735
# Epoch 294/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0482 - binary_accuracy: 0.9735
# Epoch 295/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0551 - binary_accuracy: 0.9722
# Epoch 296/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0556 - binary_accuracy: 0.9710
# Epoch 297/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0543 - binary_accuracy: 0.9722
# Epoch 298/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0533 - binary_accuracy: 0.9732
# Epoch 299/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0555 - binary_accuracy: 0.9707
# Epoch 300/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0592 - binary_accuracy: 0.9683
# Epoch 301/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0566 - binary_accuracy: 0.9697
# Epoch 302/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0529 - binary_accuracy: 0.9732
# Epoch 303/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0530 - binary_accuracy: 0.9735
# Epoch 304/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0528 - binary_accuracy: 0.9725
# Epoch 305/500
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0542 - binary_accuracy: 0.9697
# Epoch 306/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0511 - binary_accuracy: 0.9722
# Epoch 307/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0501 - binary_accuracy: 0.9750
# Epoch 308/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0530 - binary_accuracy: 0.9735
# Epoch 309/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0509 - binary_accuracy: 0.9747
# Epoch 310/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0560 - binary_accuracy: 0.9712
# Epoch 311/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0569 - binary_accuracy: 0.9707
# Epoch 312/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0547 - binary_accuracy: 0.9727
# Epoch 313/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0527 - binary_accuracy: 0.9740
# Epoch 314/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0546 - binary_accuracy: 0.9712
# Epoch 315/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0560 - binary_accuracy: 0.9720
# Epoch 316/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0521 - binary_accuracy: 0.9742
# Epoch 317/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0497 - binary_accuracy: 0.9757
# Epoch 318/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0553 - binary_accuracy: 0.9697
# Epoch 319/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0564 - binary_accuracy: 0.9697
# Epoch 320/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0556 - binary_accuracy: 0.9702
# Epoch 321/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0524 - binary_accuracy: 0.9715
# Epoch 322/500
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0523 - binary_accuracy: 0.9715
# Epoch 323/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0535 - binary_accuracy: 0.9722
# Epoch 324/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0542 - binary_accuracy: 0.9707
# Epoch 325/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0525 - binary_accuracy: 0.9735
# Epoch 326/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0529 - binary_accuracy: 0.9745
# Epoch 327/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0520 - binary_accuracy: 0.9750
# Epoch 328/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0577 - binary_accuracy: 0.9688
# Epoch 329/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0487 - binary_accuracy: 0.9732
# Epoch 330/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0571 - binary_accuracy: 0.9692
# Epoch 331/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0585 - binary_accuracy: 0.9697
# Epoch 332/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0541 - binary_accuracy: 0.9717
# Epoch 333/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0501 - binary_accuracy: 0.9737
# Epoch 334/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0591 - binary_accuracy: 0.9692
# Epoch 335/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0586 - binary_accuracy: 0.9712
# Epoch 336/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0541 - binary_accuracy: 0.9692
# Epoch 337/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0474 - binary_accuracy: 0.9722
# Epoch 338/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0534 - binary_accuracy: 0.9710
# Epoch 339/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0482 - binary_accuracy: 0.9750
# Epoch 340/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0525 - binary_accuracy: 0.9700
# Epoch 341/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0558 - binary_accuracy: 0.9722
# Epoch 342/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0579 - binary_accuracy: 0.9737
# Epoch 343/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0513 - binary_accuracy: 0.9742
# Epoch 344/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0574 - binary_accuracy: 0.9702
# Epoch 345/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0560 - binary_accuracy: 0.9670
# Epoch 346/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0562 - binary_accuracy: 0.9717
# Epoch 347/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0594 - binary_accuracy: 0.9668
# Epoch 348/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0534 - binary_accuracy: 0.9695
# Epoch 349/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0506 - binary_accuracy: 0.9740
# Epoch 350/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0502 - binary_accuracy: 0.9712
# Epoch 351/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0532 - binary_accuracy: 0.9730
# Epoch 352/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0490 - binary_accuracy: 0.9732
# Epoch 353/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0579 - binary_accuracy: 0.9707
# Epoch 354/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0502 - binary_accuracy: 0.9740
# Epoch 355/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0498 - binary_accuracy: 0.9735
# Epoch 356/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0568 - binary_accuracy: 0.9673
# Epoch 357/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0515 - binary_accuracy: 0.9730
# Epoch 358/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0535 - binary_accuracy: 0.9740
# Epoch 359/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0584 - binary_accuracy: 0.9690
# Epoch 360/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0476 - binary_accuracy: 0.9752
# Epoch 361/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0500 - binary_accuracy: 0.9740
# Epoch 362/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0510 - binary_accuracy: 0.9712
# Epoch 363/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0532 - binary_accuracy: 0.9715
# Epoch 364/500
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0479 - binary_accuracy: 0.9742
# Epoch 365/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0586 - binary_accuracy: 0.9683
# Epoch 366/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0510 - binary_accuracy: 0.9725
# Epoch 367/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0516 - binary_accuracy: 0.9715
# Epoch 368/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0562 - binary_accuracy: 0.9695
# Epoch 369/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0495 - binary_accuracy: 0.9740
# Epoch 370/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0460 - binary_accuracy: 0.9764
# Epoch 371/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0598 - binary_accuracy: 0.9653
# Epoch 372/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0491 - binary_accuracy: 0.9722
# Epoch 373/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0524 - binary_accuracy: 0.9740
# Epoch 374/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0515 - binary_accuracy: 0.9712
# Epoch 375/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0610 - binary_accuracy: 0.9675
# Epoch 376/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0559 - binary_accuracy: 0.9700
# Epoch 377/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0534 - binary_accuracy: 0.9725
# Epoch 378/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0536 - binary_accuracy: 0.9725
# Epoch 379/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0509 - binary_accuracy: 0.9745
# Epoch 380/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0465 - binary_accuracy: 0.9772
# Epoch 381/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0574 - binary_accuracy: 0.9695
# Epoch 382/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0525 - binary_accuracy: 0.9737
# Epoch 383/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0547 - binary_accuracy: 0.9710
# Epoch 384/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0602 - binary_accuracy: 0.9665
# Epoch 385/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0554 - binary_accuracy: 0.9695
# Epoch 386/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0563 - binary_accuracy: 0.9702
# Epoch 387/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0570 - binary_accuracy: 0.9702
# Epoch 388/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0543 - binary_accuracy: 0.9700
# Epoch 389/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0529 - binary_accuracy: 0.9720
# Epoch 390/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0490 - binary_accuracy: 0.9745
# Epoch 391/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0462 - binary_accuracy: 0.9740
# Epoch 392/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0590 - binary_accuracy: 0.9702
# Epoch 393/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0535 - binary_accuracy: 0.9720
# Epoch 394/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0531 - binary_accuracy: 0.9720
# Epoch 395/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0500 - binary_accuracy: 0.9732
# Epoch 396/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0513 - binary_accuracy: 0.9720
# Epoch 397/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0570 - binary_accuracy: 0.9685
# Epoch 398/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0560 - binary_accuracy: 0.9720
# Epoch 399/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0484 - binary_accuracy: 0.9745
# Epoch 400/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0581 - binary_accuracy: 0.9695
# Epoch 401/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0565 - binary_accuracy: 0.9710
# Epoch 402/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0548 - binary_accuracy: 0.9710
# Epoch 403/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0530 - binary_accuracy: 0.9730
# Epoch 404/500
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0513 - binary_accuracy: 0.9742
# Epoch 405/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0559 - binary_accuracy: 0.9742
# Epoch 406/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0584 - binary_accuracy: 0.9715
# Epoch 407/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0562 - binary_accuracy: 0.9722
# Epoch 408/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0594 - binary_accuracy: 0.9645
# Epoch 409/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0545 - binary_accuracy: 0.9697
# Epoch 410/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0564 - binary_accuracy: 0.9715
# Epoch 411/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0551 - binary_accuracy: 0.9715
# Epoch 412/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0508 - binary_accuracy: 0.9737
# Epoch 413/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0479 - binary_accuracy: 0.9747
# Epoch 414/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0547 - binary_accuracy: 0.9678
# Epoch 415/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0563 - binary_accuracy: 0.9683
# Epoch 416/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0430 - binary_accuracy: 0.9782
# Epoch 417/500
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0546 - binary_accuracy: 0.9720
# Epoch 418/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0524 - binary_accuracy: 0.9697
# Epoch 419/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0479 - binary_accuracy: 0.9732
# Epoch 420/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0540 - binary_accuracy: 0.9725
# Epoch 421/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0566 - binary_accuracy: 0.9715
# Epoch 422/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0523 - binary_accuracy: 0.9742
# Epoch 423/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0464 - binary_accuracy: 0.9732
# Epoch 424/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0536 - binary_accuracy: 0.9722
# Epoch 425/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0554 - binary_accuracy: 0.9700
# Epoch 426/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0561 - binary_accuracy: 0.9715
# Epoch 427/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0498 - binary_accuracy: 0.9720
# Epoch 428/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0495 - binary_accuracy: 0.9715
# Epoch 429/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0504 - binary_accuracy: 0.9737
# Epoch 430/500
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0591 - binary_accuracy: 0.9648
# Epoch 431/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0512 - binary_accuracy: 0.9732
# Epoch 432/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0519 - binary_accuracy: 0.9715
# Epoch 433/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0462 - binary_accuracy: 0.9767
# Epoch 434/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0501 - binary_accuracy: 0.9715
# Epoch 435/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0533 - binary_accuracy: 0.9715
# Epoch 436/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0533 - binary_accuracy: 0.9717
# Epoch 437/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0586 - binary_accuracy: 0.9695
# Epoch 438/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0551 - binary_accuracy: 0.9730
# Epoch 439/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0533 - binary_accuracy: 0.9720
# Epoch 440/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0554 - binary_accuracy: 0.9710
# Epoch 441/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0489 - binary_accuracy: 0.9779
# Epoch 442/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0572 - binary_accuracy: 0.9705
# Epoch 443/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0505 - binary_accuracy: 0.9735
# Epoch 444/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0518 - binary_accuracy: 0.9735
# Epoch 445/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0475 - binary_accuracy: 0.9757
# Epoch 446/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0566 - binary_accuracy: 0.9702
# Epoch 447/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0541 - binary_accuracy: 0.9705
# Epoch 448/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0549 - binary_accuracy: 0.9717
# Epoch 449/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0469 - binary_accuracy: 0.9759
# Epoch 450/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0565 - binary_accuracy: 0.9712
# Epoch 451/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0549 - binary_accuracy: 0.9717
# Epoch 452/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0480 - binary_accuracy: 0.9715
# Epoch 453/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0483 - binary_accuracy: 0.9745
# Epoch 454/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0554 - binary_accuracy: 0.9690
# Epoch 455/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0542 - binary_accuracy: 0.9717
# Epoch 456/500
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0547 - binary_accuracy: 0.9715
# Epoch 457/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0570 - binary_accuracy: 0.9690
# Epoch 458/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0573 - binary_accuracy: 0.9697
# Epoch 459/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0533 - binary_accuracy: 0.9720
# Epoch 460/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0542 - binary_accuracy: 0.9727
# Epoch 461/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0552 - binary_accuracy: 0.9710
# Epoch 462/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0534 - binary_accuracy: 0.9717
# Epoch 463/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0564 - binary_accuracy: 0.9675
# Epoch 464/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0565 - binary_accuracy: 0.9717
# Epoch 465/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0524 - binary_accuracy: 0.9737
# Epoch 466/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0511 - binary_accuracy: 0.9707
# Epoch 467/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0479 - binary_accuracy: 0.9747
# Epoch 468/500
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0583 - binary_accuracy: 0.9720
# Epoch 469/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0451 - binary_accuracy: 0.9767
# Epoch 470/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0521 - binary_accuracy: 0.9705
# Epoch 471/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0558 - binary_accuracy: 0.9717
# Epoch 472/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0574 - binary_accuracy: 0.9673
# Epoch 473/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0608 - binary_accuracy: 0.9663
# Epoch 474/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0486 - binary_accuracy: 0.9757
# Epoch 475/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0534 - binary_accuracy: 0.9720
# Epoch 476/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0555 - binary_accuracy: 0.9712
# Epoch 477/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0558 - binary_accuracy: 0.9695
# Epoch 478/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0539 - binary_accuracy: 0.9705
# Epoch 479/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0543 - binary_accuracy: 0.9730
# Epoch 480/500
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0593 - binary_accuracy: 0.9685
# Epoch 481/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0505 - binary_accuracy: 0.9759
# Epoch 482/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0505 - binary_accuracy: 0.9715
# Epoch 483/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0531 - binary_accuracy: 0.9715
# Epoch 484/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0591 - binary_accuracy: 0.9688
# Epoch 485/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0506 - binary_accuracy: 0.9757
# Epoch 486/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0584 - binary_accuracy: 0.9688
# Epoch 487/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0491 - binary_accuracy: 0.9764
# Epoch 488/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0529 - binary_accuracy: 0.9732
# Epoch 489/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0531 - binary_accuracy: 0.9715
# Epoch 490/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0558 - binary_accuracy: 0.9717
# Epoch 491/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0554 - binary_accuracy: 0.9710
# Epoch 492/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0486 - binary_accuracy: 0.9750
# Epoch 493/500
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0466 - binary_accuracy: 0.9772
# Epoch 494/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0531 - binary_accuracy: 0.9740
# Epoch 495/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0505 - binary_accuracy: 0.9725
# Epoch 496/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0587 - binary_accuracy: 0.9670
# Epoch 497/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0592 - binary_accuracy: 0.9705
# Epoch 498/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0514 - binary_accuracy: 0.9737
# Epoch 499/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0525 - binary_accuracy: 0.9742
# Epoch 500/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0524 - binary_accuracy: 0.9705

# %%
# extract relational cross-attention layer
relational_crossattention = model.abstractor.abstracter_layers[0].relational_crossattention.mha

# %%
# plot final model outputs for each pair of objects 
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        inputs = tf.one_hot(np.array([[i,j]]), num_objects)
        order_relation_matrix[i,j] = model(inputs)[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a pair of objects

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_pair = tf.one_hot(np.array([[i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_pair, key=object_pair, 
            value=object_pair, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[0][1]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a triplet of objects
# here, we fix the first object and vary second two, then we plot the relations of the other two objects
# with linear/sigmoid/tanh activation, adding objects does not affect the relations between existing objcets
# i.e.: this is exactly the same plot as the above (unlike with softmax activation)

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_triple = tf.one_hot(np.array([[16, i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_triple, key=object_triple, 
            value=object_triple, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[1][2]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 30
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(attention_scores)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')

# %%
objects = tf.expand_dims(tf.one_hot(np.arange(num_objects), num_objects), axis=0)

# %%
# now, compute the relations between all pairs directly 
# by passing all the objects to the relational cross-attention simultaneously
# the results are now interpretable, unlike with softmax!
# again, exact same plot as above; relation depends only on pair

attention_output, attention_scores = relational_crossattention(query=objects, key=objects, value=objects, return_attention_scores=True)
attention_scores = np.squeeze(attention_scores)
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(attention_scores.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 16
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(attention_scores)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')
