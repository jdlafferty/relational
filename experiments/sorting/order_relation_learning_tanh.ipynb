# %% [markdown]
# # Learning Order Relations

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import itertools
np.random.seed(119)

# %% [markdown]
# ## Order Relation Model
#
#
# **Task**: Given two objects $(o_1, o_2) \in \mathcal{O} \times \mathcal{O}$, predict the relation $o_1 \prec o_2$
#
# **Model**:
# 1) Embed each object: $o_1 \mapsto e_1, o_2 \mapsto e_2$
# 2) Project the first object via $W^1$ and the second object via $W^2$, then compute inner product: $\langle W^1 e_1, W^2 e_2 \rangle$.
# 3) Return relation as sigmoid function $\text{Sigmoid}\left( \langle W^1 e_1, W^2 e_2 \rangle \right)$
#
# *Note:* Here, the objects are tokens. (i.e.: integers. so the embedding layer maps $i \mapsto e_i$ for each $i \in \{1, ..., |\mathcal{O}| \}$)

# %%
class OrderRelation(tf.keras.Model):
    def __init__(self, num_objects, embedding_dim, proj_dim, name=None):
        super().__init__(name=name)
        self.num_objects = num_objects
        self.embedding_dim = embedding_dim
        self.proj_dim = proj_dim
    
    def build(self, input_shape):

        self.embedding = layers.Embedding(input_dim=self.num_objects, output_dim=self.embedding_dim)

        normal_initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=.1, seed=1)
        self.W1 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
        self.W2 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
    
    def compute_innerprod_rel(self, inputs):
        embeddings = self.embedding(inputs)
        
        o1 = embeddings[:, 0]
        o2 = embeddings[:, 1]
        e1 = tf.matmul(o1, self.W1)
        e2 = tf.matmul(o2, self.W2)

        innerprod_rel = tf.einsum('ij,ij->i', e1, e2) # compute inner product

        return innerprod_rel

    def call(self, inputs):

        innerprod_rel = self.compute_innerprod_rel(inputs)

        return innerprod_rel

# %% [markdown]
# ## Order Relation Dataset
#
# Model is fit on all pairs of objects and their associated relations.

# %%
# create data set for learning order relatios
num_objects = 64
object_pairs = np.array(list(itertools.permutations(range(num_objects), r=2)))
object_order_relations = (object_pairs[:,0] < object_pairs[:, 1]).astype(int)

# %%
sample = np.random.choice(len(object_pairs), 10)
for object_pair, relation in zip(object_pairs[sample], object_order_relations[sample]):
    print(f'object pair: {tuple(object_pair)}; relation: {relation}')
# Out:
# object pair: (39, 42); relation: 1
# object pair: (39, 9); relation: 0
# object pair: (55, 25); relation: 0
# object pair: (0, 27); relation: 1
# object pair: (35, 25); relation: 0
# object pair: (5, 31); relation: 1
# object pair: (61, 36); relation: 0
# object pair: (0, 37); relation: 1
# object pair: (49, 29); relation: 0
# object pair: (22, 29); relation: 1

# %% [markdown]
# ## Fit Relation Model

# %%
embedding_dim = 16
proj_dim = 8

order_relation = OrderRelation(num_objects, embedding_dim, proj_dim, name='order_relation')
order_relation(object_pairs); # build model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
order_relation.compile(loss='mse', optimizer=opt, metrics='binary_accuracy')

# %%
order_relation.fit(object_pairs, object_order_relations, epochs=200, batch_size=len(object_pairs))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 490ms/step - loss: 0.5000 - binary_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4891 - binary_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4191 - binary_accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2627 - binary_accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6176 - binary_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2312 - binary_accuracy: 0.5191
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2381 - binary_accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2973 - binary_accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3285 - binary_accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3349 - binary_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3244 - binary_accuracy: 0.5025
# Epoch 12/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3042 - binary_accuracy: 0.6245
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2803 - binary_accuracy: 0.6860
# Epoch 14/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2462 - binary_accuracy: 0.7356
# Epoch 15/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1912 - binary_accuracy: 0.7835
# Epoch 16/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1347 - binary_accuracy: 0.8626
# Epoch 17/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1179 - binary_accuracy: 0.8849
# Epoch 18/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1462 - binary_accuracy: 0.8405
# Epoch 19/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1502 - binary_accuracy: 0.8115
# Epoch 20/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1212 - binary_accuracy: 0.8175
# Epoch 21/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1109 - binary_accuracy: 0.8504
# Epoch 22/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1240 - binary_accuracy: 0.8800
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1392 - binary_accuracy: 0.8562
# Epoch 24/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1433 - binary_accuracy: 0.8150
# Epoch 25/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1330 - binary_accuracy: 0.8301
# Epoch 26/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1121 - binary_accuracy: 0.8780
# Epoch 27/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0905 - binary_accuracy: 0.9375
# Epoch 28/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0827 - binary_accuracy: 0.9511
# Epoch 29/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0933 - binary_accuracy: 0.9328
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1024 - binary_accuracy: 0.9320
# Epoch 31/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0934 - binary_accuracy: 0.9506
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0804 - binary_accuracy: 0.9717
# Epoch 33/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0776 - binary_accuracy: 0.9633
# Epoch 34/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0822 - binary_accuracy: 0.9397
# Epoch 35/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0859 - binary_accuracy: 0.9335
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0845 - binary_accuracy: 0.9370
# Epoch 37/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0790 - binary_accuracy: 0.9452
# Epoch 38/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0741 - binary_accuracy: 0.9377
# Epoch 39/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0737 - binary_accuracy: 0.9224
# Epoch 40/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0759 - binary_accuracy: 0.9142
# Epoch 41/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0738 - binary_accuracy: 0.9184
# Epoch 42/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0666 - binary_accuracy: 0.9315
# Epoch 43/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0606 - binary_accuracy: 0.9536
# Epoch 44/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0593 - binary_accuracy: 0.9670
# Epoch 45/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0604 - binary_accuracy: 0.9635
# Epoch 46/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0603 - binary_accuracy: 0.9591
# Epoch 47/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0580 - binary_accuracy: 0.9650
# Epoch 48/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0548 - binary_accuracy: 0.9772
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0529 - binary_accuracy: 0.9839
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0523 - binary_accuracy: 0.9841
# Epoch 51/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0514 - binary_accuracy: 0.9836
# Epoch 52/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0501 - binary_accuracy: 0.9816
# Epoch 53/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0499 - binary_accuracy: 0.9769
# Epoch 54/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0511 - binary_accuracy: 0.9702
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0523 - binary_accuracy: 0.9633
# Epoch 56/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0522 - binary_accuracy: 0.9628
# Epoch 57/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0506 - binary_accuracy: 0.9663
# Epoch 58/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0488 - binary_accuracy: 0.9722
# Epoch 59/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0478 - binary_accuracy: 0.9787
# Epoch 60/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0475 - binary_accuracy: 0.9849
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0472 - binary_accuracy: 0.9888
# Epoch 62/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0466 - binary_accuracy: 0.9893
# Epoch 63/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0463 - binary_accuracy: 0.9874
# Epoch 64/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0462 - binary_accuracy: 0.9834
# Epoch 65/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0460 - binary_accuracy: 0.9836
# Epoch 66/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0455 - binary_accuracy: 0.9864
# Epoch 67/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0448 - binary_accuracy: 0.9906
# Epoch 68/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0444 - binary_accuracy: 0.9908
# Epoch 69/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0443 - binary_accuracy: 0.9878
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0442 - binary_accuracy: 0.9849
# Epoch 71/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0437 - binary_accuracy: 0.9871
# Epoch 72/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0432 - binary_accuracy: 0.9906
# Epoch 73/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0428 - binary_accuracy: 0.9940
# Epoch 74/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0426 - binary_accuracy: 0.9943
# Epoch 75/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0423 - binary_accuracy: 0.9928
# Epoch 76/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0419 - binary_accuracy: 0.9931
# Epoch 77/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0417 - binary_accuracy: 0.9918
# Epoch 78/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0414 - binary_accuracy: 0.9916
# Epoch 79/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0409 - binary_accuracy: 0.9911
# Epoch 80/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0404 - binary_accuracy: 0.9931
# Epoch 81/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0399 - binary_accuracy: 0.9938
# Epoch 82/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0394 - binary_accuracy: 0.9936
# Epoch 83/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0390 - binary_accuracy: 0.9931
# Epoch 84/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0385 - binary_accuracy: 0.9928
# Epoch 85/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0378 - binary_accuracy: 0.9916
# Epoch 86/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0372 - binary_accuracy: 0.9898
# Epoch 87/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0366 - binary_accuracy: 0.9893
# Epoch 88/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0359 - binary_accuracy: 0.9901
# Epoch 89/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0353 - binary_accuracy: 0.9901
# Epoch 90/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0347 - binary_accuracy: 0.9901
# Epoch 91/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0341 - binary_accuracy: 0.9896
# Epoch 92/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0335 - binary_accuracy: 0.9891
# Epoch 93/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0329 - binary_accuracy: 0.9891
# Epoch 94/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0324 - binary_accuracy: 0.9888
# Epoch 95/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0320 - binary_accuracy: 0.9888
# Epoch 96/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0316 - binary_accuracy: 0.9891
# Epoch 97/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0313 - binary_accuracy: 0.9901
# Epoch 98/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0310 - binary_accuracy: 0.9911
# Epoch 99/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0308 - binary_accuracy: 0.9933
# Epoch 100/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0307 - binary_accuracy: 0.9938
# Epoch 101/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0307 - binary_accuracy: 0.9940
# Epoch 102/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0307 - binary_accuracy: 0.9943
# Epoch 103/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307 - binary_accuracy: 0.9943
# Epoch 104/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307 - binary_accuracy: 0.9943
# Epoch 105/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0306 - binary_accuracy: 0.9945
# Epoch 106/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0305 - binary_accuracy: 0.9945
# Epoch 107/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0303 - binary_accuracy: 0.9945
# Epoch 108/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0302 - binary_accuracy: 0.9948
# Epoch 109/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0300 - binary_accuracy: 0.9948
# Epoch 110/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0298 - binary_accuracy: 0.9943
# Epoch 111/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0296 - binary_accuracy: 0.9938
# Epoch 112/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0294 - binary_accuracy: 0.9931
# Epoch 113/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0293 - binary_accuracy: 0.9936
# Epoch 114/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0291 - binary_accuracy: 0.9936
# Epoch 115/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0289 - binary_accuracy: 0.9938
# Epoch 116/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0287 - binary_accuracy: 0.9943
# Epoch 117/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0286 - binary_accuracy: 0.9945
# Epoch 118/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0284 - binary_accuracy: 0.9958
# Epoch 119/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0283 - binary_accuracy: 0.9968
# Epoch 120/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0282 - binary_accuracy: 0.9970
# Epoch 121/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0281 - binary_accuracy: 0.9970
# Epoch 122/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0280 - binary_accuracy: 0.9970
# Epoch 123/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0279 - binary_accuracy: 0.9970
# Epoch 124/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0278 - binary_accuracy: 0.9970
# Epoch 125/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0277 - binary_accuracy: 0.9975
# Epoch 126/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0276 - binary_accuracy: 0.9978
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0275 - binary_accuracy: 0.9975
# Epoch 128/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0274 - binary_accuracy: 0.9973
# Epoch 129/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0273 - binary_accuracy: 0.9975
# Epoch 130/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0271 - binary_accuracy: 0.9978
# Epoch 131/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0270 - binary_accuracy: 0.9980
# Epoch 132/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0268 - binary_accuracy: 0.9978
# Epoch 133/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0267 - binary_accuracy: 0.9978
# Epoch 134/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0265 - binary_accuracy: 0.9980
# Epoch 135/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0263 - binary_accuracy: 0.9980
# Epoch 136/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0261 - binary_accuracy: 0.9985
# Epoch 137/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0258 - binary_accuracy: 0.9988
# Epoch 138/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0256 - binary_accuracy: 0.9990
# Epoch 139/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0253 - binary_accuracy: 0.9990
# Epoch 140/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0250 - binary_accuracy: 0.9990
# Epoch 141/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - binary_accuracy: 0.9990
# Epoch 142/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0245 - binary_accuracy: 0.9990
# Epoch 143/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0242 - binary_accuracy: 0.9990
# Epoch 144/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0239 - binary_accuracy: 0.9990
# Epoch 145/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0236 - binary_accuracy: 0.9990
# Epoch 146/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0234 - binary_accuracy: 0.9990
# Epoch 147/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0232 - binary_accuracy: 0.9988
# Epoch 148/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0230 - binary_accuracy: 0.9985
# Epoch 149/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0228 - binary_accuracy: 0.9980
# Epoch 150/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0227 - binary_accuracy: 0.9980
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0226 - binary_accuracy: 0.9978
# Epoch 152/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0225 - binary_accuracy: 0.9978
# Epoch 153/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9978
# Epoch 154/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9975
# Epoch 155/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0225 - binary_accuracy: 0.9973
# Epoch 156/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 157/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0224 - binary_accuracy: 0.9970
# Epoch 158/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0224 - binary_accuracy: 0.9970
# Epoch 159/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0224 - binary_accuracy: 0.9968
# Epoch 160/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0223 - binary_accuracy: 0.9970
# Epoch 161/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0223 - binary_accuracy: 0.9973
# Epoch 162/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0222 - binary_accuracy: 0.9970
# Epoch 163/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0221 - binary_accuracy: 0.9970
# Epoch 164/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0221 - binary_accuracy: 0.9970
# Epoch 165/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0220 - binary_accuracy: 0.9973
# Epoch 166/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0219 - binary_accuracy: 0.9973
# Epoch 167/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0219 - binary_accuracy: 0.9973
# Epoch 168/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0218 - binary_accuracy: 0.9973
# Epoch 169/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0217 - binary_accuracy: 0.9973
# Epoch 170/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0217 - binary_accuracy: 0.9975
# Epoch 171/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0216 - binary_accuracy: 0.9973
# Epoch 172/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0215 - binary_accuracy: 0.9975
# Epoch 173/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0215 - binary_accuracy: 0.9975
# Epoch 174/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0214 - binary_accuracy: 0.9975
# Epoch 175/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0213 - binary_accuracy: 0.9975
# Epoch 176/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - binary_accuracy: 0.9970
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0212 - binary_accuracy: 0.9970
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0211 - binary_accuracy: 0.9970
# Epoch 179/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0210 - binary_accuracy: 0.9968
# Epoch 180/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0209 - binary_accuracy: 0.9968
# Epoch 181/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0209 - binary_accuracy: 0.9968
# Epoch 182/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0208 - binary_accuracy: 0.9963
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0207 - binary_accuracy: 0.9963
# Epoch 184/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0206 - binary_accuracy: 0.9960
# Epoch 185/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0205 - binary_accuracy: 0.9960
# Epoch 186/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0204 - binary_accuracy: 0.9960
# Epoch 187/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0202 - binary_accuracy: 0.9960
# Epoch 188/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0201 - binary_accuracy: 0.9963
# Epoch 189/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0200 - binary_accuracy: 0.9965
# Epoch 190/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0199 - binary_accuracy: 0.9965
# Epoch 191/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0197 - binary_accuracy: 0.9965
# Epoch 192/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0196 - binary_accuracy: 0.9965
# Epoch 193/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0194 - binary_accuracy: 0.9973
# Epoch 194/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0193 - binary_accuracy: 0.9975
# Epoch 195/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0191 - binary_accuracy: 0.9975
# Epoch 196/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0190 - binary_accuracy: 0.9975
# Epoch 197/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0188 - binary_accuracy: 0.9975
# Epoch 198/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0186 - binary_accuracy: 0.9980
# Epoch 199/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0185 - binary_accuracy: 0.9985
# Epoch 200/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0183 - binary_accuracy: 0.9985

# %%
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        order_relation_matrix[i,j] = order_relation.compute_innerprod_rel(np.array([[i,j]]))[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\langle W_1 e_i, W_2 e_j \\rangle$');

# %%
fig, ax = plt.subplots(figsize=(6,6))
order_relation_matrix_softmax = tf.nn.softmax(order_relation_matrix, axis=1).numpy()
im = ax.imshow(order_relation_matrix_softmax.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\mathrm{softmax}(\\langle W_1 e_i, W_2 e_j \\rangle)$');

# %%
#x = tf.nn.softmax(order_relation_matrix, axis=1)
x = order_relation_matrix
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x[32, :])

# %% [markdown]
# # Learn Order Relation with `SimpleAbstractor`

# %%
import sys; sys.path.append('..'); sys.path.append('../..')

from abstracters import SimpleAbstractor

# %%
class AbstractorOrderRelation(tf.keras.Model):
    def __init__(self, name=None):
        super().__init__(name=name)
    
    def build(self, input_shape):
        # note: changed activation of MHA to tanh!
        self.abstractor = SimpleAbstractor(num_layers=1, num_heads=1, dff=32, use_pos_embedding=False, mha_activation_type='tanh')
        self.dense = layers.Dense(1, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(0.5))

    def call(self, inputs):
        x = self.abstractor(inputs)
        x = x[:, 0]
        x = self.dense(x)

        return x

# %%
object_pairs_onehot = tf.one_hot(object_pairs, num_objects)
object_pairs_onehot.shape
# Out:
# TensorShape([4032, 2, 64])

# %%
model = AbstractorOrderRelation()
model(object_pairs_onehot)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics='binary_accuracy')
model.summary()
# Out:
# Model: "abstractor_order_relation_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relational_abstracter (Simp  multiple                 21216
#  leAbstractor)
#
#  dense_15 (Dense)            multiple                  65
#
# =================================================================
# Total params: 21,281
# Trainable params: 21,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(object_pairs_onehot, object_order_relations, epochs=500, batch_size=len(object_pairs))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 1.9694 - binary_accuracy: 0.4985
# Epoch 2/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8836 - binary_accuracy: 0.5037
# Epoch 3/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8366 - binary_accuracy: 0.4908
# Epoch 4/500
# 1/1 [==============================] - 0s 61ms/step - loss: 1.8037 - binary_accuracy: 0.4970
# Epoch 5/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7946 - binary_accuracy: 0.4881
# Epoch 6/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7825 - binary_accuracy: 0.5074
# Epoch 7/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7987 - binary_accuracy: 0.4963
# Epoch 8/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7834 - binary_accuracy: 0.5107
# Epoch 9/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7763 - binary_accuracy: 0.5017
# Epoch 10/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7564 - binary_accuracy: 0.5052
# Epoch 11/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7407 - binary_accuracy: 0.5007
# Epoch 12/500
# 1/1 [==============================] - 0s 74ms/step - loss: 1.7319 - binary_accuracy: 0.5035
# Epoch 13/500
# 1/1 [==============================] - 0s 64ms/step - loss: 1.7098 - binary_accuracy: 0.4988
# Epoch 14/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.6984 - binary_accuracy: 0.5107
# Epoch 15/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6850 - binary_accuracy: 0.5171
# Epoch 16/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6771 - binary_accuracy: 0.5136
# Epoch 17/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6655 - binary_accuracy: 0.5250
# Epoch 18/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.6622 - binary_accuracy: 0.5131
# Epoch 19/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6573 - binary_accuracy: 0.5045
# Epoch 20/500
# 1/1 [==============================] - 0s 60ms/step - loss: 1.6390 - binary_accuracy: 0.5260
# Epoch 21/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6268 - binary_accuracy: 0.5303
# Epoch 22/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.6085 - binary_accuracy: 0.5394
# Epoch 23/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5954 - binary_accuracy: 0.5541
# Epoch 24/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5805 - binary_accuracy: 0.5781
# Epoch 25/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5588 - binary_accuracy: 0.5826
# Epoch 26/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5467 - binary_accuracy: 0.6004
# Epoch 27/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5260 - binary_accuracy: 0.6166
# Epoch 28/500
# 1/1 [==============================] - 0s 61ms/step - loss: 1.5161 - binary_accuracy: 0.6225
# Epoch 29/500
# 1/1 [==============================] - 0s 60ms/step - loss: 1.5001 - binary_accuracy: 0.6362
# Epoch 30/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.4819 - binary_accuracy: 0.6595
# Epoch 31/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.4674 - binary_accuracy: 0.6684
# Epoch 32/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4471 - binary_accuracy: 0.6915
# Epoch 33/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4277 - binary_accuracy: 0.6982
# Epoch 34/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.4088 - binary_accuracy: 0.7071
# Epoch 35/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3926 - binary_accuracy: 0.7180
# Epoch 36/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3735 - binary_accuracy: 0.7232
# Epoch 37/500
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3504 - binary_accuracy: 0.7316
# Epoch 38/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3292 - binary_accuracy: 0.7398
# Epoch 39/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3237 - binary_accuracy: 0.7319
# Epoch 40/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3121 - binary_accuracy: 0.7334
# Epoch 41/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2911 - binary_accuracy: 0.7421
# Epoch 42/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2795 - binary_accuracy: 0.7418
# Epoch 43/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.2604 - binary_accuracy: 0.7495
# Epoch 44/500
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2464 - binary_accuracy: 0.7572
# Epoch 45/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2308 - binary_accuracy: 0.7540
# Epoch 46/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2121 - binary_accuracy: 0.7674
# Epoch 47/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1986 - binary_accuracy: 0.7721
# Epoch 48/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1807 - binary_accuracy: 0.7755
# Epoch 49/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1612 - binary_accuracy: 0.7845
# Epoch 50/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.1373 - binary_accuracy: 0.8001
# Epoch 51/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1205 - binary_accuracy: 0.8046
# Epoch 52/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0988 - binary_accuracy: 0.8209
# Epoch 53/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0784 - binary_accuracy: 0.8232
# Epoch 54/500
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0492 - binary_accuracy: 0.8393
# Epoch 55/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0383 - binary_accuracy: 0.8455
# Epoch 56/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.0092 - binary_accuracy: 0.8564
# Epoch 57/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.9869 - binary_accuracy: 0.8638
# Epoch 58/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.9725 - binary_accuracy: 0.8673
# Epoch 59/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.9465 - binary_accuracy: 0.8807
# Epoch 60/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.9155 - binary_accuracy: 0.8953
# Epoch 61/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.8987 - binary_accuracy: 0.9020
# Epoch 62/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.8863 - binary_accuracy: 0.9043
# Epoch 63/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8708 - binary_accuracy: 0.9152
# Epoch 64/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.8534 - binary_accuracy: 0.9187
# Epoch 65/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8421 - binary_accuracy: 0.9219
# Epoch 66/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.8165 - binary_accuracy: 0.9323
# Epoch 67/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.8082 - binary_accuracy: 0.9291
# Epoch 68/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7936 - binary_accuracy: 0.9340
# Epoch 69/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7825 - binary_accuracy: 0.9360
# Epoch 70/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7804 - binary_accuracy: 0.9345
# Epoch 71/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7554 - binary_accuracy: 0.9375
# Epoch 72/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7714 - binary_accuracy: 0.9291
# Epoch 73/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7494 - binary_accuracy: 0.9370
# Epoch 74/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7539 - binary_accuracy: 0.9303
# Epoch 75/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7352 - binary_accuracy: 0.9410
# Epoch 76/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7411 - binary_accuracy: 0.9281
# Epoch 77/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7261 - binary_accuracy: 0.9350
# Epoch 78/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7066 - binary_accuracy: 0.9430
# Epoch 79/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7077 - binary_accuracy: 0.9387
# Epoch 80/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6929 - binary_accuracy: 0.9452
# Epoch 81/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6867 - binary_accuracy: 0.9472
# Epoch 82/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6694 - binary_accuracy: 0.9541
# Epoch 83/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6645 - binary_accuracy: 0.9546
# Epoch 84/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6479 - binary_accuracy: 0.9581
# Epoch 85/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6497 - binary_accuracy: 0.9524
# Epoch 86/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6530 - binary_accuracy: 0.9546
# Epoch 87/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6369 - binary_accuracy: 0.9519
# Epoch 88/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6411 - binary_accuracy: 0.9511
# Epoch 89/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6259 - binary_accuracy: 0.9556
# Epoch 90/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6245 - binary_accuracy: 0.9516
# Epoch 91/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6140 - binary_accuracy: 0.9578
# Epoch 92/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6033 - binary_accuracy: 0.9524
# Epoch 93/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6013 - binary_accuracy: 0.9554
# Epoch 94/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5981 - binary_accuracy: 0.9539
# Epoch 95/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5961 - binary_accuracy: 0.9516
# Epoch 96/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5862 - binary_accuracy: 0.9568
# Epoch 97/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5660 - binary_accuracy: 0.9613
# Epoch 98/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5666 - binary_accuracy: 0.9571
# Epoch 99/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5565 - binary_accuracy: 0.9583
# Epoch 100/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5482 - binary_accuracy: 0.9603
# Epoch 101/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5552 - binary_accuracy: 0.9519
# Epoch 102/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5269 - binary_accuracy: 0.9655
# Epoch 103/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5342 - binary_accuracy: 0.9606
# Epoch 104/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253 - binary_accuracy: 0.9643
# Epoch 105/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5226 - binary_accuracy: 0.9613
# Epoch 106/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5128 - binary_accuracy: 0.9640
# Epoch 107/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4995 - binary_accuracy: 0.9640
# Epoch 108/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5034 - binary_accuracy: 0.9640
# Epoch 109/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4906 - binary_accuracy: 0.9690
# Epoch 110/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4809 - binary_accuracy: 0.9670
# Epoch 111/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4824 - binary_accuracy: 0.9663
# Epoch 112/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4795 - binary_accuracy: 0.9648
# Epoch 113/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4713 - binary_accuracy: 0.9678
# Epoch 114/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4613 - binary_accuracy: 0.9670
# Epoch 115/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4678 - binary_accuracy: 0.9653
# Epoch 116/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4674 - binary_accuracy: 0.9640
# Epoch 117/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4561 - binary_accuracy: 0.9658
# Epoch 118/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4427 - binary_accuracy: 0.9685
# Epoch 119/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4442 - binary_accuracy: 0.9678
# Epoch 120/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4297 - binary_accuracy: 0.9705
# Epoch 121/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4299 - binary_accuracy: 0.9688
# Epoch 122/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4321 - binary_accuracy: 0.9640
# Epoch 123/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4310 - binary_accuracy: 0.9668
# Epoch 124/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4271 - binary_accuracy: 0.9640
# Epoch 125/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4219 - binary_accuracy: 0.9670
# Epoch 126/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4244 - binary_accuracy: 0.9608
# Epoch 127/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4069 - binary_accuracy: 0.9683
# Epoch 128/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4073 - binary_accuracy: 0.9683
# Epoch 129/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4044 - binary_accuracy: 0.9710
# Epoch 130/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3918 - binary_accuracy: 0.9692
# Epoch 131/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4043 - binary_accuracy: 0.9625
# Epoch 132/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3918 - binary_accuracy: 0.9685
# Epoch 133/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3750 - binary_accuracy: 0.9730
# Epoch 134/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3794 - binary_accuracy: 0.9692
# Epoch 135/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3817 - binary_accuracy: 0.9707
# Epoch 136/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3815 - binary_accuracy: 0.9648
# Epoch 137/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3711 - binary_accuracy: 0.9712
# Epoch 138/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3733 - binary_accuracy: 0.9673
# Epoch 139/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3622 - binary_accuracy: 0.9715
# Epoch 140/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3626 - binary_accuracy: 0.9685
# Epoch 141/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3632 - binary_accuracy: 0.9675
# Epoch 142/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3572 - binary_accuracy: 0.9692
# Epoch 143/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3665 - binary_accuracy: 0.9611
# Epoch 144/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3454 - binary_accuracy: 0.9725
# Epoch 145/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3389 - binary_accuracy: 0.9717
# Epoch 146/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3437 - binary_accuracy: 0.9680
# Epoch 147/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3475 - binary_accuracy: 0.9685
# Epoch 148/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3368 - binary_accuracy: 0.9685
# Epoch 149/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3302 - binary_accuracy: 0.9670
# Epoch 150/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3336 - binary_accuracy: 0.9668
# Epoch 151/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.3288 - binary_accuracy: 0.9688
# Epoch 152/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3303 - binary_accuracy: 0.9663
# Epoch 153/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3212 - binary_accuracy: 0.9678
# Epoch 154/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3252 - binary_accuracy: 0.9658
# Epoch 155/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3272 - binary_accuracy: 0.9668
# Epoch 156/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3158 - binary_accuracy: 0.9685
# Epoch 157/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3134 - binary_accuracy: 0.9702
# Epoch 158/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3093 - binary_accuracy: 0.9692
# Epoch 159/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3068 - binary_accuracy: 0.9715
# Epoch 160/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2932 - binary_accuracy: 0.9752
# Epoch 161/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3008 - binary_accuracy: 0.9722
# Epoch 162/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3026 - binary_accuracy: 0.9668
# Epoch 163/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3062 - binary_accuracy: 0.9640
# Epoch 164/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2957 - binary_accuracy: 0.9695
# Epoch 165/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3012 - binary_accuracy: 0.9633
# Epoch 166/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2970 - binary_accuracy: 0.9668
# Epoch 167/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2841 - binary_accuracy: 0.9700
# Epoch 168/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2796 - binary_accuracy: 0.9727
# Epoch 169/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2807 - binary_accuracy: 0.9722
# Epoch 170/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2848 - binary_accuracy: 0.9695
# Epoch 171/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2718 - binary_accuracy: 0.9745
# Epoch 172/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2770 - binary_accuracy: 0.9722
# Epoch 173/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2770 - binary_accuracy: 0.9700
# Epoch 174/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2683 - binary_accuracy: 0.9710
# Epoch 175/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2717 - binary_accuracy: 0.9710
# Epoch 176/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2676 - binary_accuracy: 0.9712
# Epoch 177/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2671 - binary_accuracy: 0.9727
# Epoch 178/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2664 - binary_accuracy: 0.9650
# Epoch 179/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2584 - binary_accuracy: 0.9732
# Epoch 180/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2509 - binary_accuracy: 0.9735
# Epoch 181/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2603 - binary_accuracy: 0.9692
# Epoch 182/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2514 - binary_accuracy: 0.9710
# Epoch 183/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2503 - binary_accuracy: 0.9722
# Epoch 184/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2532 - binary_accuracy: 0.9712
# Epoch 185/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2539 - binary_accuracy: 0.9685
# Epoch 186/500
# 1/1 [==============================] - 0s 144ms/step - loss: 0.2475 - binary_accuracy: 0.9700
# Epoch 187/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2467 - binary_accuracy: 0.9680
# Epoch 188/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2436 - binary_accuracy: 0.9688
# Epoch 189/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2390 - binary_accuracy: 0.9747
# Epoch 190/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2386 - binary_accuracy: 0.9730
# Epoch 191/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2375 - binary_accuracy: 0.9735
# Epoch 192/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2373 - binary_accuracy: 0.9720
# Epoch 193/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2412 - binary_accuracy: 0.9707
# Epoch 194/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2348 - binary_accuracy: 0.9712
# Epoch 195/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2360 - binary_accuracy: 0.9730
# Epoch 196/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2290 - binary_accuracy: 0.9720
# Epoch 197/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2243 - binary_accuracy: 0.9754
# Epoch 198/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2270 - binary_accuracy: 0.9747
# Epoch 199/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2334 - binary_accuracy: 0.9685
# Epoch 200/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2330 - binary_accuracy: 0.9665
# Epoch 201/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2266 - binary_accuracy: 0.9695
# Epoch 202/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2236 - binary_accuracy: 0.9705
# Epoch 203/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2237 - binary_accuracy: 0.9710
# Epoch 204/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2202 - binary_accuracy: 0.9725
# Epoch 205/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2165 - binary_accuracy: 0.9730
# Epoch 206/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2146 - binary_accuracy: 0.9725
# Epoch 207/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2149 - binary_accuracy: 0.9707
# Epoch 208/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2128 - binary_accuracy: 0.9720
# Epoch 209/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2093 - binary_accuracy: 0.9740
# Epoch 210/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2088 - binary_accuracy: 0.9759
# Epoch 211/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2143 - binary_accuracy: 0.9697
# Epoch 212/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2060 - binary_accuracy: 0.9745
# Epoch 213/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2097 - binary_accuracy: 0.9722
# Epoch 214/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2164 - binary_accuracy: 0.9673
# Epoch 215/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2119 - binary_accuracy: 0.9710
# Epoch 216/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2080 - binary_accuracy: 0.9705
# Epoch 217/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2042 - binary_accuracy: 0.9727
# Epoch 218/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2057 - binary_accuracy: 0.9712
# Epoch 219/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2015 - binary_accuracy: 0.9727
# Epoch 220/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2014 - binary_accuracy: 0.9730
# Epoch 221/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1954 - binary_accuracy: 0.9747
# Epoch 222/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1990 - binary_accuracy: 0.9707
# Epoch 223/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1999 - binary_accuracy: 0.9715
# Epoch 224/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1953 - binary_accuracy: 0.9742
# Epoch 225/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1936 - binary_accuracy: 0.9735
# Epoch 226/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1932 - binary_accuracy: 0.9750
# Epoch 227/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2026 - binary_accuracy: 0.9638
# Epoch 228/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1904 - binary_accuracy: 0.9727
# Epoch 229/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1992 - binary_accuracy: 0.9645
# Epoch 230/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1950 - binary_accuracy: 0.9695
# Epoch 231/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1909 - binary_accuracy: 0.9710
# Epoch 232/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1862 - binary_accuracy: 0.9772
# Epoch 233/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1876 - binary_accuracy: 0.9757
# Epoch 234/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1966 - binary_accuracy: 0.9683
# Epoch 235/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1897 - binary_accuracy: 0.9722
# Epoch 236/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1852 - binary_accuracy: 0.9750
# Epoch 237/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1895 - binary_accuracy: 0.9695
# Epoch 238/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1901 - binary_accuracy: 0.9695
# Epoch 239/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1864 - binary_accuracy: 0.9715
# Epoch 240/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1930 - binary_accuracy: 0.9683
# Epoch 241/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1774 - binary_accuracy: 0.9762
# Epoch 242/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1849 - binary_accuracy: 0.9747
# Epoch 243/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1866 - binary_accuracy: 0.9725
# Epoch 244/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1802 - binary_accuracy: 0.9740
# Epoch 245/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1861 - binary_accuracy: 0.9717
# Epoch 246/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1763 - binary_accuracy: 0.9732
# Epoch 247/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1851 - binary_accuracy: 0.9695
# Epoch 248/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1766 - binary_accuracy: 0.9752
# Epoch 249/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1787 - binary_accuracy: 0.9745
# Epoch 250/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1816 - binary_accuracy: 0.9702
# Epoch 251/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1764 - binary_accuracy: 0.9730
# Epoch 252/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1756 - binary_accuracy: 0.9735
# Epoch 253/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1816 - binary_accuracy: 0.9707
# Epoch 254/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1840 - binary_accuracy: 0.9675
# Epoch 255/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1805 - binary_accuracy: 0.9705
# Epoch 256/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1799 - binary_accuracy: 0.9690
# Epoch 257/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1758 - binary_accuracy: 0.9722
# Epoch 258/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1811 - binary_accuracy: 0.9670
# Epoch 259/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1793 - binary_accuracy: 0.9668
# Epoch 260/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1770 - binary_accuracy: 0.9730
# Epoch 261/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1764 - binary_accuracy: 0.9712
# Epoch 262/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1719 - binary_accuracy: 0.9737
# Epoch 263/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1745 - binary_accuracy: 0.9715
# Epoch 264/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1750 - binary_accuracy: 0.9692
# Epoch 265/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1716 - binary_accuracy: 0.9745
# Epoch 266/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1764 - binary_accuracy: 0.9695
# Epoch 267/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1718 - binary_accuracy: 0.9740
# Epoch 268/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1721 - binary_accuracy: 0.9727
# Epoch 269/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1713 - binary_accuracy: 0.9737
# Epoch 270/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1759 - binary_accuracy: 0.9688
# Epoch 271/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1783 - binary_accuracy: 0.9695
# Epoch 272/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1767 - binary_accuracy: 0.9710
# Epoch 273/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1747 - binary_accuracy: 0.9695
# Epoch 274/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1759 - binary_accuracy: 0.9680
# Epoch 275/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1744 - binary_accuracy: 0.9695
# Epoch 276/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1692 - binary_accuracy: 0.9730
# Epoch 277/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1707 - binary_accuracy: 0.9717
# Epoch 278/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1709 - binary_accuracy: 0.9727
# Epoch 279/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1685 - binary_accuracy: 0.9740
# Epoch 280/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1691 - binary_accuracy: 0.9725
# Epoch 281/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1707 - binary_accuracy: 0.9692
# Epoch 282/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1681 - binary_accuracy: 0.9727
# Epoch 283/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1710 - binary_accuracy: 0.9675
# Epoch 284/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1619 - binary_accuracy: 0.9762
# Epoch 285/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1643 - binary_accuracy: 0.9745
# Epoch 286/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1646 - binary_accuracy: 0.9745
# Epoch 287/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1694 - binary_accuracy: 0.9725
# Epoch 288/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1698 - binary_accuracy: 0.9712
# Epoch 289/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1697 - binary_accuracy: 0.9720
# Epoch 290/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1691 - binary_accuracy: 0.9692
# Epoch 291/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1674 - binary_accuracy: 0.9725
# Epoch 292/500
# 1/1 [==============================] - 0s 142ms/step - loss: 0.1683 - binary_accuracy: 0.9717
# Epoch 293/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1646 - binary_accuracy: 0.9732
# Epoch 294/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1678 - binary_accuracy: 0.9727
# Epoch 295/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1674 - binary_accuracy: 0.9712
# Epoch 296/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1637 - binary_accuracy: 0.9732
# Epoch 297/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1709 - binary_accuracy: 0.9688
# Epoch 298/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1678 - binary_accuracy: 0.9707
# Epoch 299/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1662 - binary_accuracy: 0.9715
# Epoch 300/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1654 - binary_accuracy: 0.9735
# Epoch 301/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1674 - binary_accuracy: 0.9742
# Epoch 302/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1673 - binary_accuracy: 0.9720
# Epoch 303/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1664 - binary_accuracy: 0.9712
# Epoch 304/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1636 - binary_accuracy: 0.9720
# Epoch 305/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1688 - binary_accuracy: 0.9675
# Epoch 306/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1730 - binary_accuracy: 0.9658
# Epoch 307/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1704 - binary_accuracy: 0.9690
# Epoch 308/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1641 - binary_accuracy: 0.9735
# Epoch 309/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1606 - binary_accuracy: 0.9759
# Epoch 310/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1608 - binary_accuracy: 0.9747
# Epoch 311/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1644 - binary_accuracy: 0.9705
# Epoch 312/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1603 - binary_accuracy: 0.9747
# Epoch 313/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1599 - binary_accuracy: 0.9750
# Epoch 314/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1608 - binary_accuracy: 0.9759
# Epoch 315/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1710 - binary_accuracy: 0.9668
# Epoch 316/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1568 - binary_accuracy: 0.9757
# Epoch 317/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1596 - binary_accuracy: 0.9727
# Epoch 318/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1599 - binary_accuracy: 0.9732
# Epoch 319/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1559 - binary_accuracy: 0.9797
# Epoch 320/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1633 - binary_accuracy: 0.9742
# Epoch 321/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1572 - binary_accuracy: 0.9752
# Epoch 322/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1678 - binary_accuracy: 0.9685
# Epoch 323/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1583 - binary_accuracy: 0.9767
# Epoch 324/500
# 1/1 [==============================] - 0s 122ms/step - loss: 0.1583 - binary_accuracy: 0.9740
# Epoch 325/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1667 - binary_accuracy: 0.9695
# Epoch 326/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1605 - binary_accuracy: 0.9732
# Epoch 327/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1622 - binary_accuracy: 0.9712
# Epoch 328/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1654 - binary_accuracy: 0.9700
# Epoch 329/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1695 - binary_accuracy: 0.9670
# Epoch 330/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1642 - binary_accuracy: 0.9715
# Epoch 331/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1646 - binary_accuracy: 0.9700
# Epoch 332/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1672 - binary_accuracy: 0.9675
# Epoch 333/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1571 - binary_accuracy: 0.9735
# Epoch 334/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1638 - binary_accuracy: 0.9717
# Epoch 335/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1608 - binary_accuracy: 0.9700
# Epoch 336/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1547 - binary_accuracy: 0.9754
# Epoch 337/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1641 - binary_accuracy: 0.9695
# Epoch 338/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1601 - binary_accuracy: 0.9720
# Epoch 339/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1562 - binary_accuracy: 0.9747
# Epoch 340/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1636 - binary_accuracy: 0.9697
# Epoch 341/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1613 - binary_accuracy: 0.9712
# Epoch 342/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1601 - binary_accuracy: 0.9727
# Epoch 343/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1606 - binary_accuracy: 0.9717
# Epoch 344/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1571 - binary_accuracy: 0.9750
# Epoch 345/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1690 - binary_accuracy: 0.9678
# Epoch 346/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1506 - binary_accuracy: 0.9802
# Epoch 347/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1631 - binary_accuracy: 0.9688
# Epoch 348/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1536 - binary_accuracy: 0.9750
# Epoch 349/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1516 - binary_accuracy: 0.9779
# Epoch 350/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1659 - binary_accuracy: 0.9645
# Epoch 351/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1615 - binary_accuracy: 0.9715
# Epoch 352/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1682 - binary_accuracy: 0.9663
# Epoch 353/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1568 - binary_accuracy: 0.9705
# Epoch 354/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1542 - binary_accuracy: 0.9735
# Epoch 355/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1564 - binary_accuracy: 0.9757
# Epoch 356/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1558 - binary_accuracy: 0.9745
# Epoch 357/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1638 - binary_accuracy: 0.9673
# Epoch 358/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1633 - binary_accuracy: 0.9710
# Epoch 359/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1564 - binary_accuracy: 0.9712
# Epoch 360/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1563 - binary_accuracy: 0.9717
# Epoch 361/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1597 - binary_accuracy: 0.9690
# Epoch 362/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1545 - binary_accuracy: 0.9745
# Epoch 363/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1585 - binary_accuracy: 0.9727
# Epoch 364/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1560 - binary_accuracy: 0.9725
# Epoch 365/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1584 - binary_accuracy: 0.9722
# Epoch 366/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1555 - binary_accuracy: 0.9745
# Epoch 367/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1531 - binary_accuracy: 0.9730
# Epoch 368/500
# 1/1 [==============================] - 0s 141ms/step - loss: 0.1564 - binary_accuracy: 0.9717
# Epoch 369/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1580 - binary_accuracy: 0.9710
# Epoch 370/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1570 - binary_accuracy: 0.9720
# Epoch 371/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1543 - binary_accuracy: 0.9727
# Epoch 372/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1537 - binary_accuracy: 0.9757
# Epoch 373/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1613 - binary_accuracy: 0.9697
# Epoch 374/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1570 - binary_accuracy: 0.9685
# Epoch 375/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1624 - binary_accuracy: 0.9700
# Epoch 376/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1580 - binary_accuracy: 0.9715
# Epoch 377/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1540 - binary_accuracy: 0.9712
# Epoch 378/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1529 - binary_accuracy: 0.9740
# Epoch 379/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1542 - binary_accuracy: 0.9747
# Epoch 380/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1580 - binary_accuracy: 0.9710
# Epoch 381/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1539 - binary_accuracy: 0.9710
# Epoch 382/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1538 - binary_accuracy: 0.9732
# Epoch 383/500
# 1/1 [==============================] - 0s 139ms/step - loss: 0.1564 - binary_accuracy: 0.9715
# Epoch 384/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1565 - binary_accuracy: 0.9707
# Epoch 385/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1570 - binary_accuracy: 0.9717
# Epoch 386/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1534 - binary_accuracy: 0.9717
# Epoch 387/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1519 - binary_accuracy: 0.9705
# Epoch 388/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1618 - binary_accuracy: 0.9653
# Epoch 389/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1501 - binary_accuracy: 0.9735
# Epoch 390/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1488 - binary_accuracy: 0.9764
# Epoch 391/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1528 - binary_accuracy: 0.9725
# Epoch 392/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1569 - binary_accuracy: 0.9660
# Epoch 393/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1508 - binary_accuracy: 0.9735
# Epoch 394/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1574 - binary_accuracy: 0.9678
# Epoch 395/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1505 - binary_accuracy: 0.9740
# Epoch 396/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1460 - binary_accuracy: 0.9742
# Epoch 397/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1520 - binary_accuracy: 0.9720
# Epoch 398/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1540 - binary_accuracy: 0.9712
# Epoch 399/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1454 - binary_accuracy: 0.9764
# Epoch 400/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1574 - binary_accuracy: 0.9668
# Epoch 401/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1533 - binary_accuracy: 0.9705
# Epoch 402/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1509 - binary_accuracy: 0.9712
# Epoch 403/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1553 - binary_accuracy: 0.9720
# Epoch 404/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1458 - binary_accuracy: 0.9750
# Epoch 405/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1484 - binary_accuracy: 0.9732
# Epoch 406/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1579 - binary_accuracy: 0.9665
# Epoch 407/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1537 - binary_accuracy: 0.9685
# Epoch 408/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1464 - binary_accuracy: 0.9747
# Epoch 409/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1486 - binary_accuracy: 0.9735
# Epoch 410/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1549 - binary_accuracy: 0.9692
# Epoch 411/500
# 1/1 [==============================] - 0s 138ms/step - loss: 0.1471 - binary_accuracy: 0.9732
# Epoch 412/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1519 - binary_accuracy: 0.9707
# Epoch 413/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1514 - binary_accuracy: 0.9710
# Epoch 414/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1520 - binary_accuracy: 0.9697
# Epoch 415/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1514 - binary_accuracy: 0.9735
# Epoch 416/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1524 - binary_accuracy: 0.9695
# Epoch 417/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1527 - binary_accuracy: 0.9683
# Epoch 418/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1511 - binary_accuracy: 0.9685
# Epoch 419/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1404 - binary_accuracy: 0.9754
# Epoch 420/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1433 - binary_accuracy: 0.9722
# Epoch 421/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1489 - binary_accuracy: 0.9702
# Epoch 422/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1422 - binary_accuracy: 0.9742
# Epoch 423/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1454 - binary_accuracy: 0.9725
# Epoch 424/500
# 1/1 [==============================] - 0s 136ms/step - loss: 0.1442 - binary_accuracy: 0.9747
# Epoch 425/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1459 - binary_accuracy: 0.9737
# Epoch 426/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1454 - binary_accuracy: 0.9702
# Epoch 427/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1456 - binary_accuracy: 0.9737
# Epoch 428/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1432 - binary_accuracy: 0.9737
# Epoch 429/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1492 - binary_accuracy: 0.9725
# Epoch 430/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1419 - binary_accuracy: 0.9737
# Epoch 431/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1500 - binary_accuracy: 0.9678
# Epoch 432/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1462 - binary_accuracy: 0.9710
# Epoch 433/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1440 - binary_accuracy: 0.9737
# Epoch 434/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1453 - binary_accuracy: 0.9735
# Epoch 435/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1431 - binary_accuracy: 0.9740
# Epoch 436/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1442 - binary_accuracy: 0.9715
# Epoch 437/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1437 - binary_accuracy: 0.9732
# Epoch 438/500
# 1/1 [==============================] - 0s 140ms/step - loss: 0.1427 - binary_accuracy: 0.9727
# Epoch 439/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1420 - binary_accuracy: 0.9750
# Epoch 440/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1436 - binary_accuracy: 0.9732
# Epoch 441/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1457 - binary_accuracy: 0.9707
# Epoch 442/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1470 - binary_accuracy: 0.9688
# Epoch 443/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1429 - binary_accuracy: 0.9727
# Epoch 444/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1388 - binary_accuracy: 0.9762
# Epoch 445/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1415 - binary_accuracy: 0.9745
# Epoch 446/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1364 - binary_accuracy: 0.9769
# Epoch 447/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1442 - binary_accuracy: 0.9725
# Epoch 448/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1417 - binary_accuracy: 0.9705
# Epoch 449/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1416 - binary_accuracy: 0.9707
# Epoch 450/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1369 - binary_accuracy: 0.9750
# Epoch 451/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1449 - binary_accuracy: 0.9692
# Epoch 452/500
# 1/1 [==============================] - 0s 145ms/step - loss: 0.1371 - binary_accuracy: 0.9750
# Epoch 453/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1432 - binary_accuracy: 0.9675
# Epoch 454/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1389 - binary_accuracy: 0.9717
# Epoch 455/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1424 - binary_accuracy: 0.9715
# Epoch 456/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1372 - binary_accuracy: 0.9752
# Epoch 457/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1465 - binary_accuracy: 0.9633
# Epoch 458/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1349 - binary_accuracy: 0.9750
# Epoch 459/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1452 - binary_accuracy: 0.9697
# Epoch 460/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1338 - binary_accuracy: 0.9754
# Epoch 461/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1378 - binary_accuracy: 0.9727
# Epoch 462/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1431 - binary_accuracy: 0.9692
# Epoch 463/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1417 - binary_accuracy: 0.9692
# Epoch 464/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1396 - binary_accuracy: 0.9732
# Epoch 465/500
# 1/1 [==============================] - 0s 123ms/step - loss: 0.1469 - binary_accuracy: 0.9688
# Epoch 466/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1377 - binary_accuracy: 0.9730
# Epoch 467/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1343 - binary_accuracy: 0.9747
# Epoch 468/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1451 - binary_accuracy: 0.9673
# Epoch 469/500
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1433 - binary_accuracy: 0.9668
# Epoch 470/500
# 1/1 [==============================] - 0s 125ms/step - loss: 0.1434 - binary_accuracy: 0.9683
# Epoch 471/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1364 - binary_accuracy: 0.9730
# Epoch 472/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1370 - binary_accuracy: 0.9730
# Epoch 473/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1371 - binary_accuracy: 0.9722
# Epoch 474/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1366 - binary_accuracy: 0.9720
# Epoch 475/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1394 - binary_accuracy: 0.9712
# Epoch 476/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1318 - binary_accuracy: 0.9757
# Epoch 477/500
# 1/1 [==============================] - 0s 135ms/step - loss: 0.1365 - binary_accuracy: 0.9725
# Epoch 478/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1401 - binary_accuracy: 0.9650
# Epoch 479/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1352 - binary_accuracy: 0.9722
# Epoch 480/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1362 - binary_accuracy: 0.9720
# Epoch 481/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1289 - binary_accuracy: 0.9787
# Epoch 482/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1304 - binary_accuracy: 0.9747
# Epoch 483/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1354 - binary_accuracy: 0.9705
# Epoch 484/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1317 - binary_accuracy: 0.9750
# Epoch 485/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1365 - binary_accuracy: 0.9700
# Epoch 486/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1350 - binary_accuracy: 0.9735
# Epoch 487/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1388 - binary_accuracy: 0.9707
# Epoch 488/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1300 - binary_accuracy: 0.9745
# Epoch 489/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1367 - binary_accuracy: 0.9712
# Epoch 490/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1351 - binary_accuracy: 0.9717
# Epoch 491/500
# 1/1 [==============================] - 0s 136ms/step - loss: 0.1332 - binary_accuracy: 0.9705
# Epoch 492/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1349 - binary_accuracy: 0.9722
# Epoch 493/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1352 - binary_accuracy: 0.9715
# Epoch 494/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1291 - binary_accuracy: 0.9742
# Epoch 495/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1306 - binary_accuracy: 0.9730
# Epoch 496/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1316 - binary_accuracy: 0.9710
# Epoch 497/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1338 - binary_accuracy: 0.9702
# Epoch 498/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1311 - binary_accuracy: 0.9712
# Epoch 499/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1298 - binary_accuracy: 0.9732
# Epoch 500/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1274 - binary_accuracy: 0.9750

# %%
# extract relational cross-attention layer
relational_crossattention = model.abstractor.abstracter_layers[0].relational_crossattention.mha

# %%
# plot final model outputs for each pair of objects 
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        inputs = tf.one_hot(np.array([[i,j]]), num_objects)
        order_relation_matrix[i,j] = model(inputs)[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a pair of objects

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_pair = tf.one_hot(np.array([[i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_pair, key=object_pair, 
            value=object_pair, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[0][1]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)#, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a triplet of objects
# here, we fix the first object and vary second two, then we plot the relations of the other two objects
# with linear/sigmoid/tanh activation, adding objects does not affect the relations between existing objcets
# i.e.: this is exactly the same plot as the above (unlike with softmax activation)

conditional_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_triple = tf.one_hot(np.array([[16, i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_triple, key=object_triple, 
            value=object_triple, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[1][2]
        conditional_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(conditional_relation_matrix.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T - conditional_relation_matrix.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 30
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(order_relation_matrix[i,:], label='pairs')
plt.plot(conditional_relation_matrix[i,:], label='triples')
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')
plt.legend()

# %%
objects = tf.expand_dims(tf.one_hot(np.arange(num_objects), num_objects), axis=0)

# %%
# now, compute the relations between all pairs directly 
# by passing all the objects to the relational cross-attention simultaneously
# the results are now interpretable, unlike with softmax!
# again, exact same plot as above; relation depends only on pair

attention_output, attention_scores = relational_crossattention(query=objects, key=objects, value=objects, return_attention_scores=True)
attention_scores = np.squeeze(attention_scores)
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(attention_scores.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 32
attention_scores_i = attention_scores[i,:]
plt.figure(figsize=(8,5))
plt.plot(range(len(attention_scores_i)), attention_scores_i)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores_i), ymax=np.max(attention_scores_i), linestyle='dotted', color='gray')
