# %% [markdown]
# # Learning Order Relations

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import itertools
np.random.seed(119)

# %% [markdown]
# ## Order Relation Model
#
#
# **Task**: Given two objects $(o_1, o_2) \in \mathcal{O} \times \mathcal{O}$, predict the relation $o_1 \prec o_2$
#
# **Model**:
# 1) Embed each object: $o_1 \mapsto e_1, o_2 \mapsto e_2$
# 2) Project the first object via $W^1$ and the second object via $W^2$, then compute inner product: $\langle W^1 e_1, W^2 e_2 \rangle$.
# 3) Return relation as sigmoid function $\text{Sigmoid}\left( \langle W^1 e_1, W^2 e_2 \rangle \right)$
#
# *Note:* Here, the objects are tokens. (i.e.: integers. so the embedding layer maps $i \mapsto e_i$ for each $i \in \{1, ..., |\mathcal{O}| \}$)

# %%
class OrderRelation(tf.keras.Model):
    def __init__(self, num_objects, embedding_dim, proj_dim, name=None):
        super().__init__(name=name)
        self.num_objects = num_objects
        self.embedding_dim = embedding_dim
        self.proj_dim = proj_dim
    
    def build(self, input_shape):

        self.embedding = layers.Embedding(input_dim=self.num_objects, output_dim=self.embedding_dim)

        normal_initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=.1, seed=1)
        self.W1 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
        self.W2 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
    
    def compute_innerprod_rel(self, inputs):
        embeddings = self.embedding(inputs)
        
        o1 = embeddings[:, 0]
        o2 = embeddings[:, 1]
        e1 = tf.matmul(o1, self.W1)
        e2 = tf.matmul(o2, self.W2)

        innerprod_rel = tf.einsum('ij,ij->i', e1, e2) # compute inner product

        return innerprod_rel

    def call(self, inputs):

        innerprod_rel = self.compute_innerprod_rel(inputs)

        return innerprod_rel

# %% [markdown]
# ## Order Relation Dataset
#
# Model is fit on all pairs of objects and their associated relations.

# %%
# create data set for learning order relatios
num_objects = 64
object_pairs = np.array(list(itertools.permutations(range(num_objects), r=2)))
object_order_relations = (object_pairs[:,0] < object_pairs[:, 1]).astype(int)

# %%
sample = np.random.choice(len(object_pairs), 10)
for object_pair, relation in zip(object_pairs[sample], object_order_relations[sample]):
    print(f'object pair: {tuple(object_pair)}; relation: {relation}')
# Out:
# object pair: (39, 42); relation: 1
# object pair: (39, 9); relation: 0
# object pair: (55, 25); relation: 0
# object pair: (0, 27); relation: 1
# object pair: (35, 25); relation: 0
# object pair: (5, 31); relation: 1
# object pair: (61, 36); relation: 0
# object pair: (0, 37); relation: 1
# object pair: (49, 29); relation: 0
# object pair: (22, 29); relation: 1

# %% [markdown]
# ## Fit Relation Model

# %%
embedding_dim = 16
proj_dim = 8

order_relation = OrderRelation(num_objects, embedding_dim, proj_dim, name='order_relation')
order_relation(object_pairs); # build model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
order_relation.compile(loss='mse', optimizer=opt, metrics='binary_accuracy')

# %%
order_relation.fit(object_pairs, object_order_relations, epochs=200, batch_size=len(object_pairs))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 610ms/step - loss: 0.5000 - binary_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4927 - binary_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4354 - binary_accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2899 - binary_accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4870 - binary_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2543 - binary_accuracy: 0.5002
# Epoch 7/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2796 - binary_accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3308 - binary_accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3539 - binary_accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3518 - binary_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3270 - binary_accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2801 - binary_accuracy: 0.5000
# Epoch 13/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2238 - binary_accuracy: 0.5556
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2075 - binary_accuracy: 0.6280
# Epoch 15/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2368 - binary_accuracy: 0.5273
# Epoch 16/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1865 - binary_accuracy: 0.6272
# Epoch 17/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1199 - binary_accuracy: 0.8966
# Epoch 18/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1043 - binary_accuracy: 0.8914
# Epoch 19/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1130 - binary_accuracy: 0.8326
# Epoch 20/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1285 - binary_accuracy: 0.8326
# Epoch 21/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1463 - binary_accuracy: 0.8559
# Epoch 22/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1477 - binary_accuracy: 0.8827
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1246 - binary_accuracy: 0.8891
# Epoch 24/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0979 - binary_accuracy: 0.8911
# Epoch 25/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0852 - binary_accuracy: 0.8889
# Epoch 26/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0857 - binary_accuracy: 0.8842
# Epoch 27/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0904 - binary_accuracy: 0.8777
# Epoch 28/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0927 - binary_accuracy: 0.8859
# Epoch 29/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0907 - binary_accuracy: 0.9020
# Epoch 30/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0858 - binary_accuracy: 0.9226
# Epoch 31/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0812 - binary_accuracy: 0.9392
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0802 - binary_accuracy: 0.9402
# Epoch 33/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0832 - binary_accuracy: 0.9449
# Epoch 34/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0860 - binary_accuracy: 0.9559
# Epoch 35/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0836 - binary_accuracy: 0.9678
# Epoch 36/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0771 - binary_accuracy: 0.9779
# Epoch 37/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0711 - binary_accuracy: 0.9777
# Epoch 38/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0684 - binary_accuracy: 0.9618
# Epoch 39/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0682 - binary_accuracy: 0.9464
# Epoch 40/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0679 - binary_accuracy: 0.9402
# Epoch 41/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0660 - binary_accuracy: 0.9422
# Epoch 42/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0624 - binary_accuracy: 0.9499
# Epoch 43/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0585 - binary_accuracy: 0.9616
# Epoch 44/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0557 - binary_accuracy: 0.9683
# Epoch 45/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0546 - binary_accuracy: 0.9722
# Epoch 46/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0545 - binary_accuracy: 0.9737
# Epoch 47/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0540 - binary_accuracy: 0.9762
# Epoch 48/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0532 - binary_accuracy: 0.9720
# Epoch 49/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0530 - binary_accuracy: 0.9663
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0533 - binary_accuracy: 0.9650
# Epoch 51/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0536 - binary_accuracy: 0.9660
# Epoch 52/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0535 - binary_accuracy: 0.9670
# Epoch 53/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0529 - binary_accuracy: 0.9660
# Epoch 54/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0525 - binary_accuracy: 0.9655
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0525 - binary_accuracy: 0.9658
# Epoch 56/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0523 - binary_accuracy: 0.9688
# Epoch 57/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0512 - binary_accuracy: 0.9727
# Epoch 58/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0497 - binary_accuracy: 0.9764
# Epoch 59/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0487 - binary_accuracy: 0.9782
# Epoch 60/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0486 - binary_accuracy: 0.9777
# Epoch 61/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0489 - binary_accuracy: 0.9797
# Epoch 62/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0488 - binary_accuracy: 0.9824
# Epoch 63/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0483 - binary_accuracy: 0.9856
# Epoch 64/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0478 - binary_accuracy: 0.9888
# Epoch 65/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0477 - binary_accuracy: 0.9898
# Epoch 66/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0477 - binary_accuracy: 0.9891
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0475 - binary_accuracy: 0.9883
# Epoch 68/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0469 - binary_accuracy: 0.9886
# Epoch 69/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0462 - binary_accuracy: 0.9896
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0458 - binary_accuracy: 0.9893
# Epoch 71/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0453 - binary_accuracy: 0.9881
# Epoch 72/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0448 - binary_accuracy: 0.9864
# Epoch 73/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0441 - binary_accuracy: 0.9861
# Epoch 74/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0434 - binary_accuracy: 0.9874
# Epoch 75/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0428 - binary_accuracy: 0.9888
# Epoch 76/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0421 - binary_accuracy: 0.9891
# Epoch 77/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0414 - binary_accuracy: 0.9886
# Epoch 78/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0406 - binary_accuracy: 0.9878
# Epoch 79/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0397 - binary_accuracy: 0.9901
# Epoch 80/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0388 - binary_accuracy: 0.9906
# Epoch 81/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0379 - binary_accuracy: 0.9921
# Epoch 82/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0370 - binary_accuracy: 0.9921
# Epoch 83/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0362 - binary_accuracy: 0.9906
# Epoch 84/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0355 - binary_accuracy: 0.9898
# Epoch 85/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0348 - binary_accuracy: 0.9908
# Epoch 86/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0341 - binary_accuracy: 0.9908
# Epoch 87/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9926
# Epoch 88/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0329 - binary_accuracy: 0.9943
# Epoch 89/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0323 - binary_accuracy: 0.9945
# Epoch 90/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0319 - binary_accuracy: 0.9945
# Epoch 91/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0316 - binary_accuracy: 0.9943
# Epoch 92/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0314 - binary_accuracy: 0.9945
# Epoch 93/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0313 - binary_accuracy: 0.9938
# Epoch 94/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0314 - binary_accuracy: 0.9913
# Epoch 95/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0314 - binary_accuracy: 0.9906
# Epoch 96/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0313 - binary_accuracy: 0.9898
# Epoch 97/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0312 - binary_accuracy: 0.9903
# Epoch 98/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0311 - binary_accuracy: 0.9893
# Epoch 99/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0310 - binary_accuracy: 0.9896
# Epoch 100/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0308 - binary_accuracy: 0.9906
# Epoch 101/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0306 - binary_accuracy: 0.9921
# Epoch 102/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0304 - binary_accuracy: 0.9921
# Epoch 103/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0302 - binary_accuracy: 0.9921
# Epoch 104/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0300 - binary_accuracy: 0.9926
# Epoch 105/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0298 - binary_accuracy: 0.9926
# Epoch 106/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0296 - binary_accuracy: 0.9928
# Epoch 107/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0294 - binary_accuracy: 0.9936
# Epoch 108/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0293 - binary_accuracy: 0.9938
# Epoch 109/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0291 - binary_accuracy: 0.9928
# Epoch 110/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0289 - binary_accuracy: 0.9928
# Epoch 111/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0288 - binary_accuracy: 0.9926
# Epoch 112/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0286 - binary_accuracy: 0.9926
# Epoch 113/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0284 - binary_accuracy: 0.9931
# Epoch 114/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0282 - binary_accuracy: 0.9931
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0280 - binary_accuracy: 0.9931
# Epoch 116/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0278 - binary_accuracy: 0.9933
# Epoch 117/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0276 - binary_accuracy: 0.9940
# Epoch 118/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0274 - binary_accuracy: 0.9938
# Epoch 119/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0272 - binary_accuracy: 0.9940
# Epoch 120/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0270 - binary_accuracy: 0.9943
# Epoch 121/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0268 - binary_accuracy: 0.9943
# Epoch 122/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0266 - binary_accuracy: 0.9948
# Epoch 123/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0263 - binary_accuracy: 0.9950
# Epoch 124/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0261 - binary_accuracy: 0.9953
# Epoch 125/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0259 - binary_accuracy: 0.9958
# Epoch 126/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0257 - binary_accuracy: 0.9960
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0256 - binary_accuracy: 0.9960
# Epoch 128/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0254 - binary_accuracy: 0.9965
# Epoch 129/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0252 - binary_accuracy: 0.9970
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0250 - binary_accuracy: 0.9973
# Epoch 131/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0249 - binary_accuracy: 0.9975
# Epoch 132/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0247 - binary_accuracy: 0.9978
# Epoch 133/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0245 - binary_accuracy: 0.9978
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0243 - binary_accuracy: 0.9978
# Epoch 135/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0242 - binary_accuracy: 0.9978
# Epoch 136/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0240 - binary_accuracy: 0.9978
# Epoch 137/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - binary_accuracy: 0.9978
# Epoch 138/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0236 - binary_accuracy: 0.9978
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - binary_accuracy: 0.9978
# Epoch 140/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0233 - binary_accuracy: 0.9978
# Epoch 141/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0231 - binary_accuracy: 0.9973
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0229 - binary_accuracy: 0.9973
# Epoch 143/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0228 - binary_accuracy: 0.9973
# Epoch 144/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0226 - binary_accuracy: 0.9973
# Epoch 145/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0225 - binary_accuracy: 0.9973
# Epoch 146/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 147/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - binary_accuracy: 0.9973
# Epoch 148/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0222 - binary_accuracy: 0.9973
# Epoch 149/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0221 - binary_accuracy: 0.9973
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0221 - binary_accuracy: 0.9973
# Epoch 151/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0220 - binary_accuracy: 0.9975
# Epoch 152/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0219 - binary_accuracy: 0.9975
# Epoch 153/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0219 - binary_accuracy: 0.9975
# Epoch 154/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0218 - binary_accuracy: 0.9980
# Epoch 155/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0218 - binary_accuracy: 0.9980
# Epoch 156/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 157/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 158/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0216 - binary_accuracy: 0.9983
# Epoch 159/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0216 - binary_accuracy: 0.9983
# Epoch 160/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0215 - binary_accuracy: 0.9983
# Epoch 161/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - binary_accuracy: 0.9983
# Epoch 162/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0214 - binary_accuracy: 0.9983
# Epoch 163/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - binary_accuracy: 0.9983
# Epoch 164/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0212 - binary_accuracy: 0.9983
# Epoch 165/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0211 - binary_accuracy: 0.9985
# Epoch 166/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0210 - binary_accuracy: 0.9985
# Epoch 167/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0209 - binary_accuracy: 0.9985
# Epoch 168/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0209 - binary_accuracy: 0.9985
# Epoch 169/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0208 - binary_accuracy: 0.9985
# Epoch 170/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0207 - binary_accuracy: 0.9985
# Epoch 171/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0206 - binary_accuracy: 0.9985
# Epoch 172/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0204 - binary_accuracy: 0.9985
# Epoch 173/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0203 - binary_accuracy: 0.9985
# Epoch 174/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0202 - binary_accuracy: 0.9985
# Epoch 175/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0201 - binary_accuracy: 0.9985
# Epoch 176/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0200 - binary_accuracy: 0.9985
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0199 - binary_accuracy: 0.9988
# Epoch 178/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0198 - binary_accuracy: 0.9990
# Epoch 179/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0196 - binary_accuracy: 0.9990
# Epoch 180/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0195 - binary_accuracy: 0.9990
# Epoch 181/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0194 - binary_accuracy: 0.9990
# Epoch 182/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0193 - binary_accuracy: 0.9990
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0191 - binary_accuracy: 0.9990
# Epoch 184/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0190 - binary_accuracy: 0.9990
# Epoch 185/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0188 - binary_accuracy: 0.9990
# Epoch 186/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0187 - binary_accuracy: 0.9990
# Epoch 187/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0186 - binary_accuracy: 0.9990
# Epoch 188/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0184 - binary_accuracy: 0.9990
# Epoch 189/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0183 - binary_accuracy: 0.9990
# Epoch 190/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0182 - binary_accuracy: 0.9990
# Epoch 191/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0180 - binary_accuracy: 0.9990
# Epoch 192/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0179 - binary_accuracy: 0.9990
# Epoch 193/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0178 - binary_accuracy: 0.9993
# Epoch 194/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0177 - binary_accuracy: 0.9993
# Epoch 195/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0176 - binary_accuracy: 0.9990
# Epoch 196/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0175 - binary_accuracy: 0.9990
# Epoch 197/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0174 - binary_accuracy: 0.9990
# Epoch 198/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0174 - binary_accuracy: 0.9988
# Epoch 199/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0173 - binary_accuracy: 0.9988
# Epoch 200/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0173 - binary_accuracy: 0.9988

# %%
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        order_relation_matrix[i,j] = order_relation.compute_innerprod_rel(np.array([[i,j]]))[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\langle W_1 e_i, W_2 e_j \\rangle$');

# %%
fig, ax = plt.subplots(figsize=(6,6))
order_relation_matrix_softmax = tf.nn.softmax(order_relation_matrix, axis=1).numpy()
im = ax.imshow(order_relation_matrix_softmax.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\mathrm{softmax}(\\langle W_1 e_i, W_2 e_j \\rangle)$');

# %%
#x = tf.nn.softmax(order_relation_matrix, axis=1)
x = order_relation_matrix
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x[32, :])

# %% [markdown]
# # Learn Order Relation with `SimpleAbstractor`

# %%
import sys; sys.path.append('..'); sys.path.append('../..')

from abstracters import SimpleAbstractor

# %%
class AbstractorOrderRelation(tf.keras.Model):
    def __init__(self, name=None):
        super().__init__(name=name)
    
    def build(self, input_shape):
        # note: changed activation of MHA to tanh!
        self.abstractor = SimpleAbstractor(num_layers=1, num_heads=1, dff=32, use_pos_embedding=False, mha_activation_type='tanh')
        self.dense = layers.Dense(1, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(0.5))

    def call(self, inputs):
        x = self.abstractor(inputs)
        x = x[:, 0]
        x = self.dense(x)

        return x

# %%
object_pairs_onehot = tf.one_hot(object_pairs, num_objects)
object_pairs_onehot.shape
# Out:
# TensorShape([4032, 2, 64])

# %%
model = AbstractorOrderRelation()
model(object_pairs_onehot)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics='binary_accuracy')
model.summary()
# Out:
# Model: "abstractor_order_relation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relational_abstracter (Simp  multiple                 21216
#  leAbstractor)
#
#  dense (Dense)               multiple                  65
#
# =================================================================
# Total params: 21,281
# Trainable params: 21,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(object_pairs_onehot, object_order_relations, epochs=500, batch_size=len(object_pairs))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 1.9838 - binary_accuracy: 0.4993
# Epoch 2/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.9027 - binary_accuracy: 0.5005
# Epoch 3/500
# 1/1 [==============================] - 0s 53ms/step - loss: 1.8359 - binary_accuracy: 0.4965
# Epoch 4/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7833 - binary_accuracy: 0.5020
# Epoch 5/500
# 1/1 [==============================] - 0s 52ms/step - loss: 1.7387 - binary_accuracy: 0.5032
# Epoch 6/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7151 - binary_accuracy: 0.5017
# Epoch 7/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7042 - binary_accuracy: 0.5002
# Epoch 8/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.6966 - binary_accuracy: 0.5122
# Epoch 9/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.6937 - binary_accuracy: 0.5141
# Epoch 10/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7042 - binary_accuracy: 0.4990
# Epoch 11/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7053 - binary_accuracy: 0.4958
# Epoch 12/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.6911 - binary_accuracy: 0.5099
# Epoch 13/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6817 - binary_accuracy: 0.4993
# Epoch 14/500
# 1/1 [==============================] - 0s 51ms/step - loss: 1.6632 - binary_accuracy: 0.5161
# Epoch 15/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.6574 - binary_accuracy: 0.4975
# Epoch 16/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6402 - binary_accuracy: 0.5052
# Epoch 17/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.6306 - binary_accuracy: 0.4968
# Epoch 18/500
# 1/1 [==============================] - 0s 52ms/step - loss: 1.6146 - binary_accuracy: 0.5154
# Epoch 19/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5996 - binary_accuracy: 0.5126
# Epoch 20/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5807 - binary_accuracy: 0.5481
# Epoch 21/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.5686 - binary_accuracy: 0.5476
# Epoch 22/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.5617 - binary_accuracy: 0.5466
# Epoch 23/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5519 - binary_accuracy: 0.5461
# Epoch 24/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5399 - binary_accuracy: 0.5598
# Epoch 25/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.5223 - binary_accuracy: 0.5719
# Epoch 26/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.5184 - binary_accuracy: 0.5717
# Epoch 27/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5031 - binary_accuracy: 0.5791
# Epoch 28/500
# 1/1 [==============================] - 0s 52ms/step - loss: 1.4884 - binary_accuracy: 0.6000
# Epoch 29/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4642 - binary_accuracy: 0.6203
# Epoch 30/500
# 1/1 [==============================] - 0s 52ms/step - loss: 1.4424 - binary_accuracy: 0.6562
# Epoch 31/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4296 - binary_accuracy: 0.6771
# Epoch 32/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.4102 - binary_accuracy: 0.6917
# Epoch 33/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3932 - binary_accuracy: 0.7051
# Epoch 34/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3723 - binary_accuracy: 0.7145
# Epoch 35/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3573 - binary_accuracy: 0.7158
# Epoch 36/500
# 1/1 [==============================] - 0s 52ms/step - loss: 1.3304 - binary_accuracy: 0.7421
# Epoch 37/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3183 - binary_accuracy: 0.7374
# Epoch 38/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3022 - binary_accuracy: 0.7418
# Epoch 39/500
# 1/1 [==============================] - 0s 53ms/step - loss: 1.2884 - binary_accuracy: 0.7465
# Epoch 40/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2777 - binary_accuracy: 0.7460
# Epoch 41/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.2622 - binary_accuracy: 0.7480
# Epoch 42/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2577 - binary_accuracy: 0.7468
# Epoch 43/500
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2515 - binary_accuracy: 0.7436
# Epoch 44/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2364 - binary_accuracy: 0.7517
# Epoch 45/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2254 - binary_accuracy: 0.7564
# Epoch 46/500
# 1/1 [==============================] - 0s 51ms/step - loss: 1.2124 - binary_accuracy: 0.7599
# Epoch 47/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2008 - binary_accuracy: 0.7574
# Epoch 48/500
# 1/1 [==============================] - 0s 53ms/step - loss: 1.1900 - binary_accuracy: 0.7666
# Epoch 49/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1759 - binary_accuracy: 0.7693
# Epoch 50/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1683 - binary_accuracy: 0.7676
# Epoch 51/500
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1586 - binary_accuracy: 0.7716
# Epoch 52/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.1403 - binary_accuracy: 0.7783
# Epoch 53/500
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1318 - binary_accuracy: 0.7884
# Epoch 54/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.1182 - binary_accuracy: 0.7961
# Epoch 55/500
# 1/1 [==============================] - 0s 51ms/step - loss: 1.1078 - binary_accuracy: 0.7904
# Epoch 56/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0867 - binary_accuracy: 0.8132
# Epoch 57/500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0770 - binary_accuracy: 0.8175
# Epoch 58/500
# 1/1 [==============================] - 0s 62ms/step - loss: 1.0662 - binary_accuracy: 0.8256
# Epoch 59/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0462 - binary_accuracy: 0.8343
# Epoch 60/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.0287 - binary_accuracy: 0.8373
# Epoch 61/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0195 - binary_accuracy: 0.8408
# Epoch 62/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.9970 - binary_accuracy: 0.8594
# Epoch 63/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.9726 - binary_accuracy: 0.8715
# Epoch 64/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.9501 - binary_accuracy: 0.8720
# Epoch 65/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.9321 - binary_accuracy: 0.8819
# Epoch 66/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.9013 - binary_accuracy: 0.8963
# Epoch 67/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.8816 - binary_accuracy: 0.8998
# Epoch 68/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.8572 - binary_accuracy: 0.9082
# Epoch 69/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.8373 - binary_accuracy: 0.9159
# Epoch 70/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.8121 - binary_accuracy: 0.9199
# Epoch 71/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7873 - binary_accuracy: 0.9256
# Epoch 72/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7598 - binary_accuracy: 0.9273
# Epoch 73/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7414 - binary_accuracy: 0.9365
# Epoch 74/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7214 - binary_accuracy: 0.9373
# Epoch 75/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7076 - binary_accuracy: 0.9395
# Epoch 76/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6935 - binary_accuracy: 0.9375
# Epoch 77/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6805 - binary_accuracy: 0.9422
# Epoch 78/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6619 - binary_accuracy: 0.9479
# Epoch 79/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6500 - binary_accuracy: 0.9509
# Epoch 80/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6305 - binary_accuracy: 0.9573
# Epoch 81/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6218 - binary_accuracy: 0.9583
# Epoch 82/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6123 - binary_accuracy: 0.9581
# Epoch 83/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6014 - binary_accuracy: 0.9616
# Epoch 84/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5983 - binary_accuracy: 0.9559
# Epoch 85/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5793 - binary_accuracy: 0.9665
# Epoch 86/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5685 - binary_accuracy: 0.9660
# Epoch 87/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5672 - binary_accuracy: 0.9625
# Epoch 88/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5601 - binary_accuracy: 0.9635
# Epoch 89/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5525 - binary_accuracy: 0.9611
# Epoch 90/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5390 - binary_accuracy: 0.9700
# Epoch 91/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5409 - binary_accuracy: 0.9625
# Epoch 92/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5245 - binary_accuracy: 0.9670
# Epoch 93/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5219 - binary_accuracy: 0.9678
# Epoch 94/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5129 - binary_accuracy: 0.9710
# Epoch 95/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5129 - binary_accuracy: 0.9668
# Epoch 96/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5081 - binary_accuracy: 0.9658
# Epoch 97/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4963 - binary_accuracy: 0.9722
# Epoch 98/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4877 - binary_accuracy: 0.9745
# Epoch 99/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4879 - binary_accuracy: 0.9717
# Epoch 100/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4850 - binary_accuracy: 0.9680
# Epoch 101/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4843 - binary_accuracy: 0.9678
# Epoch 102/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4763 - binary_accuracy: 0.9678
# Epoch 103/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4716 - binary_accuracy: 0.9732
# Epoch 104/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4631 - binary_accuracy: 0.9702
# Epoch 105/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4581 - binary_accuracy: 0.9707
# Epoch 106/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4607 - binary_accuracy: 0.9638
# Epoch 107/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4582 - binary_accuracy: 0.9655
# Epoch 108/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4467 - binary_accuracy: 0.9705
# Epoch 109/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4495 - binary_accuracy: 0.9660
# Epoch 110/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4360 - binary_accuracy: 0.9740
# Epoch 111/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4310 - binary_accuracy: 0.9697
# Epoch 112/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4339 - binary_accuracy: 0.9697
# Epoch 113/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4296 - binary_accuracy: 0.9685
# Epoch 114/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4300 - binary_accuracy: 0.9673
# Epoch 115/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4174 - binary_accuracy: 0.9730
# Epoch 116/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4224 - binary_accuracy: 0.9660
# Epoch 117/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4185 - binary_accuracy: 0.9658
# Epoch 118/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4042 - binary_accuracy: 0.9720
# Epoch 119/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4126 - binary_accuracy: 0.9638
# Epoch 120/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3980 - binary_accuracy: 0.9730
# Epoch 121/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4037 - binary_accuracy: 0.9663
# Epoch 122/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3950 - binary_accuracy: 0.9702
# Epoch 123/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3920 - binary_accuracy: 0.9692
# Epoch 124/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3854 - binary_accuracy: 0.9690
# Epoch 125/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3794 - binary_accuracy: 0.9735
# Epoch 126/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3735 - binary_accuracy: 0.9742
# Epoch 127/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3703 - binary_accuracy: 0.9735
# Epoch 128/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3788 - binary_accuracy: 0.9645
# Epoch 129/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3683 - binary_accuracy: 0.9707
# Epoch 130/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3714 - binary_accuracy: 0.9663
# Epoch 131/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3628 - binary_accuracy: 0.9705
# Epoch 132/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3543 - binary_accuracy: 0.9712
# Epoch 133/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3615 - binary_accuracy: 0.9663
# Epoch 134/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3453 - binary_accuracy: 0.9759
# Epoch 135/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3466 - binary_accuracy: 0.9740
# Epoch 136/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3511 - binary_accuracy: 0.9680
# Epoch 137/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3452 - binary_accuracy: 0.9683
# Epoch 138/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3351 - binary_accuracy: 0.9725
# Epoch 139/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3298 - binary_accuracy: 0.9720
# Epoch 140/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3386 - binary_accuracy: 0.9678
# Epoch 141/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3327 - binary_accuracy: 0.9695
# Epoch 142/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.3294 - binary_accuracy: 0.9702
# Epoch 143/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3223 - binary_accuracy: 0.9705
# Epoch 144/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3199 - binary_accuracy: 0.9735
# Epoch 145/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3214 - binary_accuracy: 0.9707
# Epoch 146/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3170 - binary_accuracy: 0.9732
# Epoch 147/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3150 - binary_accuracy: 0.9715
# Epoch 148/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3093 - binary_accuracy: 0.9725
# Epoch 149/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3092 - binary_accuracy: 0.9690
# Epoch 150/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3045 - binary_accuracy: 0.9725
# Epoch 151/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3024 - binary_accuracy: 0.9700
# Epoch 152/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2946 - binary_accuracy: 0.9759
# Epoch 153/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2975 - binary_accuracy: 0.9683
# Epoch 154/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2904 - binary_accuracy: 0.9732
# Epoch 155/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2870 - binary_accuracy: 0.9757
# Epoch 156/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2889 - binary_accuracy: 0.9717
# Epoch 157/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2810 - binary_accuracy: 0.9740
# Epoch 158/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2832 - binary_accuracy: 0.9730
# Epoch 159/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2826 - binary_accuracy: 0.9717
# Epoch 160/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2738 - binary_accuracy: 0.9745
# Epoch 161/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2823 - binary_accuracy: 0.9695
# Epoch 162/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2735 - binary_accuracy: 0.9732
# Epoch 163/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2716 - binary_accuracy: 0.9742
# Epoch 164/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2824 - binary_accuracy: 0.9635
# Epoch 165/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2685 - binary_accuracy: 0.9727
# Epoch 166/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2627 - binary_accuracy: 0.9745
# Epoch 167/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2653 - binary_accuracy: 0.9702
# Epoch 168/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2638 - binary_accuracy: 0.9715
# Epoch 169/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2594 - binary_accuracy: 0.9727
# Epoch 170/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2570 - binary_accuracy: 0.9742
# Epoch 171/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2516 - binary_accuracy: 0.9750
# Epoch 172/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2539 - binary_accuracy: 0.9710
# Epoch 173/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2620 - binary_accuracy: 0.9658
# Epoch 174/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2498 - binary_accuracy: 0.9710
# Epoch 175/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2471 - binary_accuracy: 0.9700
# Epoch 176/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2506 - binary_accuracy: 0.9695
# Epoch 177/500
# 1/1 [==============================] - 0s 131ms/step - loss: 0.2413 - binary_accuracy: 0.9737
# Epoch 178/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2391 - binary_accuracy: 0.9745
# Epoch 179/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2390 - binary_accuracy: 0.9732
# Epoch 180/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2396 - binary_accuracy: 0.9712
# Epoch 181/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2383 - binary_accuracy: 0.9727
# Epoch 182/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2311 - binary_accuracy: 0.9754
# Epoch 183/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2330 - binary_accuracy: 0.9740
# Epoch 184/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2368 - binary_accuracy: 0.9695
# Epoch 185/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2234 - binary_accuracy: 0.9745
# Epoch 186/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2310 - binary_accuracy: 0.9702
# Epoch 187/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2295 - binary_accuracy: 0.9692
# Epoch 188/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2300 - binary_accuracy: 0.9720
# Epoch 189/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2245 - binary_accuracy: 0.9720
# Epoch 190/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2241 - binary_accuracy: 0.9725
# Epoch 191/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2212 - binary_accuracy: 0.9727
# Epoch 192/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2191 - binary_accuracy: 0.9759
# Epoch 193/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2212 - binary_accuracy: 0.9710
# Epoch 194/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2208 - binary_accuracy: 0.9680
# Epoch 195/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2147 - binary_accuracy: 0.9762
# Epoch 196/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2155 - binary_accuracy: 0.9715
# Epoch 197/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2131 - binary_accuracy: 0.9717
# Epoch 198/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2178 - binary_accuracy: 0.9705
# Epoch 199/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2094 - binary_accuracy: 0.9720
# Epoch 200/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2093 - binary_accuracy: 0.9712
# Epoch 201/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2039 - binary_accuracy: 0.9757
# Epoch 202/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2027 - binary_accuracy: 0.9764
# Epoch 203/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2039 - binary_accuracy: 0.9732
# Epoch 204/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2075 - binary_accuracy: 0.9683
# Epoch 205/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2057 - binary_accuracy: 0.9720
# Epoch 206/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2082 - binary_accuracy: 0.9673
# Epoch 207/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2040 - binary_accuracy: 0.9695
# Epoch 208/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1988 - binary_accuracy: 0.9754
# Epoch 209/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1999 - binary_accuracy: 0.9712
# Epoch 210/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2000 - binary_accuracy: 0.9707
# Epoch 211/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2005 - binary_accuracy: 0.9695
# Epoch 212/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2014 - binary_accuracy: 0.9690
# Epoch 213/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1945 - binary_accuracy: 0.9717
# Epoch 214/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1907 - binary_accuracy: 0.9740
# Epoch 215/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1973 - binary_accuracy: 0.9705
# Epoch 216/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1908 - binary_accuracy: 0.9730
# Epoch 217/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1892 - binary_accuracy: 0.9730
# Epoch 218/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1908 - binary_accuracy: 0.9732
# Epoch 219/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1939 - binary_accuracy: 0.9715
# Epoch 220/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1871 - binary_accuracy: 0.9725
# Epoch 221/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1875 - binary_accuracy: 0.9740
# Epoch 222/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1887 - binary_accuracy: 0.9690
# Epoch 223/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1856 - binary_accuracy: 0.9725
# Epoch 224/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1868 - binary_accuracy: 0.9725
# Epoch 225/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1861 - binary_accuracy: 0.9730
# Epoch 226/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1827 - binary_accuracy: 0.9722
# Epoch 227/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1860 - binary_accuracy: 0.9690
# Epoch 228/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1833 - binary_accuracy: 0.9735
# Epoch 229/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1849 - binary_accuracy: 0.9685
# Epoch 230/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1811 - binary_accuracy: 0.9737
# Epoch 231/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1825 - binary_accuracy: 0.9705
# Epoch 232/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1822 - binary_accuracy: 0.9725
# Epoch 233/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1769 - binary_accuracy: 0.9735
# Epoch 234/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1816 - binary_accuracy: 0.9732
# Epoch 235/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1796 - binary_accuracy: 0.9730
# Epoch 236/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1838 - binary_accuracy: 0.9697
# Epoch 237/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1712 - binary_accuracy: 0.9742
# Epoch 238/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1770 - binary_accuracy: 0.9727
# Epoch 239/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1761 - binary_accuracy: 0.9730
# Epoch 240/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1786 - binary_accuracy: 0.9678
# Epoch 241/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1810 - binary_accuracy: 0.9710
# Epoch 242/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1772 - binary_accuracy: 0.9695
# Epoch 243/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1756 - binary_accuracy: 0.9720
# Epoch 244/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1763 - binary_accuracy: 0.9720
# Epoch 245/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1745 - binary_accuracy: 0.9722
# Epoch 246/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1727 - binary_accuracy: 0.9695
# Epoch 247/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1791 - binary_accuracy: 0.9648
# Epoch 248/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1756 - binary_accuracy: 0.9732
# Epoch 249/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1703 - binary_accuracy: 0.9737
# Epoch 250/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1682 - binary_accuracy: 0.9737
# Epoch 251/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1757 - binary_accuracy: 0.9715
# Epoch 252/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1673 - binary_accuracy: 0.9772
# Epoch 253/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1688 - binary_accuracy: 0.9750
# Epoch 254/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1731 - binary_accuracy: 0.9715
# Epoch 255/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1748 - binary_accuracy: 0.9690
# Epoch 256/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1780 - binary_accuracy: 0.9673
# Epoch 257/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1770 - binary_accuracy: 0.9668
# Epoch 258/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1713 - binary_accuracy: 0.9720
# Epoch 259/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1773 - binary_accuracy: 0.9680
# Epoch 260/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1687 - binary_accuracy: 0.9747
# Epoch 261/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1749 - binary_accuracy: 0.9655
# Epoch 262/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1721 - binary_accuracy: 0.9712
# Epoch 263/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1734 - binary_accuracy: 0.9692
# Epoch 264/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1719 - binary_accuracy: 0.9692
# Epoch 265/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1679 - binary_accuracy: 0.9690
# Epoch 266/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1688 - binary_accuracy: 0.9722
# Epoch 267/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1625 - binary_accuracy: 0.9769
# Epoch 268/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1691 - binary_accuracy: 0.9705
# Epoch 269/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1673 - binary_accuracy: 0.9730
# Epoch 270/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1653 - binary_accuracy: 0.9730
# Epoch 271/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1650 - binary_accuracy: 0.9715
# Epoch 272/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1653 - binary_accuracy: 0.9717
# Epoch 273/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1637 - binary_accuracy: 0.9747
# Epoch 274/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1671 - binary_accuracy: 0.9715
# Epoch 275/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1592 - binary_accuracy: 0.9752
# Epoch 276/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1646 - binary_accuracy: 0.9727
# Epoch 277/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1660 - binary_accuracy: 0.9700
# Epoch 278/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1625 - binary_accuracy: 0.9735
# Epoch 279/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1666 - binary_accuracy: 0.9697
# Epoch 280/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1665 - binary_accuracy: 0.9697
# Epoch 281/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1706 - binary_accuracy: 0.9688
# Epoch 282/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1662 - binary_accuracy: 0.9722
# Epoch 283/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1646 - binary_accuracy: 0.9705
# Epoch 284/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1648 - binary_accuracy: 0.9720
# Epoch 285/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1641 - binary_accuracy: 0.9705
# Epoch 286/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1624 - binary_accuracy: 0.9725
# Epoch 287/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1648 - binary_accuracy: 0.9702
# Epoch 288/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1626 - binary_accuracy: 0.9740
# Epoch 289/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1619 - binary_accuracy: 0.9745
# Epoch 290/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1648 - binary_accuracy: 0.9690
# Epoch 291/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1676 - binary_accuracy: 0.9683
# Epoch 292/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1622 - binary_accuracy: 0.9732
# Epoch 293/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1654 - binary_accuracy: 0.9700
# Epoch 294/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1587 - binary_accuracy: 0.9732
# Epoch 295/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1596 - binary_accuracy: 0.9710
# Epoch 296/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1597 - binary_accuracy: 0.9745
# Epoch 297/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1618 - binary_accuracy: 0.9727
# Epoch 298/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1630 - binary_accuracy: 0.9727
# Epoch 299/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1645 - binary_accuracy: 0.9697
# Epoch 300/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1560 - binary_accuracy: 0.9764
# Epoch 301/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1610 - binary_accuracy: 0.9740
# Epoch 302/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1615 - binary_accuracy: 0.9700
# Epoch 303/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1605 - binary_accuracy: 0.9715
# Epoch 304/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1650 - binary_accuracy: 0.9680
# Epoch 305/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1618 - binary_accuracy: 0.9705
# Epoch 306/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1563 - binary_accuracy: 0.9747
# Epoch 307/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1583 - binary_accuracy: 0.9747
# Epoch 308/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1652 - binary_accuracy: 0.9697
# Epoch 309/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1563 - binary_accuracy: 0.9754
# Epoch 310/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1662 - binary_accuracy: 0.9668
# Epoch 311/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1621 - binary_accuracy: 0.9700
# Epoch 312/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1564 - binary_accuracy: 0.9737
# Epoch 313/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1608 - binary_accuracy: 0.9712
# Epoch 314/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1589 - binary_accuracy: 0.9710
# Epoch 315/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1615 - binary_accuracy: 0.9710
# Epoch 316/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1620 - binary_accuracy: 0.9700
# Epoch 317/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1644 - binary_accuracy: 0.9715
# Epoch 318/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1572 - binary_accuracy: 0.9720
# Epoch 319/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1559 - binary_accuracy: 0.9730
# Epoch 320/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1613 - binary_accuracy: 0.9727
# Epoch 321/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1609 - binary_accuracy: 0.9697
# Epoch 322/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1614 - binary_accuracy: 0.9717
# Epoch 323/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1603 - binary_accuracy: 0.9697
# Epoch 324/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1558 - binary_accuracy: 0.9762
# Epoch 325/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1611 - binary_accuracy: 0.9685
# Epoch 326/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1626 - binary_accuracy: 0.9675
# Epoch 327/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1588 - binary_accuracy: 0.9705
# Epoch 328/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1542 - binary_accuracy: 0.9742
# Epoch 329/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1624 - binary_accuracy: 0.9683
# Epoch 330/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1531 - binary_accuracy: 0.9750
# Epoch 331/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1545 - binary_accuracy: 0.9725
# Epoch 332/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1536 - binary_accuracy: 0.9752
# Epoch 333/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1584 - binary_accuracy: 0.9727
# Epoch 334/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1592 - binary_accuracy: 0.9710
# Epoch 335/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1595 - binary_accuracy: 0.9712
# Epoch 336/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1576 - binary_accuracy: 0.9725
# Epoch 337/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1607 - binary_accuracy: 0.9712
# Epoch 338/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1552 - binary_accuracy: 0.9720
# Epoch 339/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1599 - binary_accuracy: 0.9695
# Epoch 340/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1549 - binary_accuracy: 0.9727
# Epoch 341/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1591 - binary_accuracy: 0.9700
# Epoch 342/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1603 - binary_accuracy: 0.9705
# Epoch 343/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1507 - binary_accuracy: 0.9745
# Epoch 344/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1554 - binary_accuracy: 0.9730
# Epoch 345/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1569 - binary_accuracy: 0.9712
# Epoch 346/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1515 - binary_accuracy: 0.9737
# Epoch 347/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1508 - binary_accuracy: 0.9772
# Epoch 348/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1464 - binary_accuracy: 0.9789
# Epoch 349/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1608 - binary_accuracy: 0.9683
# Epoch 350/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1575 - binary_accuracy: 0.9712
# Epoch 351/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1596 - binary_accuracy: 0.9678
# Epoch 352/500
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1532 - binary_accuracy: 0.9745
# Epoch 353/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1548 - binary_accuracy: 0.9702
# Epoch 354/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1546 - binary_accuracy: 0.9742
# Epoch 355/500
# 1/1 [==============================] - 0s 104ms/step - loss: 0.1526 - binary_accuracy: 0.9725
# Epoch 356/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1498 - binary_accuracy: 0.9742
# Epoch 357/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1495 - binary_accuracy: 0.9740
# Epoch 358/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1536 - binary_accuracy: 0.9707
# Epoch 359/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1532 - binary_accuracy: 0.9722
# Epoch 360/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1562 - binary_accuracy: 0.9715
# Epoch 361/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1559 - binary_accuracy: 0.9700
# Epoch 362/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1546 - binary_accuracy: 0.9712
# Epoch 363/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1503 - binary_accuracy: 0.9745
# Epoch 364/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1511 - binary_accuracy: 0.9722
# Epoch 365/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1539 - binary_accuracy: 0.9732
# Epoch 366/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1523 - binary_accuracy: 0.9722
# Epoch 367/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1521 - binary_accuracy: 0.9735
# Epoch 368/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1506 - binary_accuracy: 0.9740
# Epoch 369/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1540 - binary_accuracy: 0.9727
# Epoch 370/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1593 - binary_accuracy: 0.9688
# Epoch 371/500
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1502 - binary_accuracy: 0.9732
# Epoch 372/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1501 - binary_accuracy: 0.9747
# Epoch 373/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1534 - binary_accuracy: 0.9735
# Epoch 374/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1564 - binary_accuracy: 0.9685
# Epoch 375/500
# 1/1 [==============================] - 0s 132ms/step - loss: 0.1575 - binary_accuracy: 0.9678
# Epoch 376/500
# 1/1 [==============================] - 0s 106ms/step - loss: 0.1443 - binary_accuracy: 0.9774
# Epoch 377/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1579 - binary_accuracy: 0.9680
# Epoch 378/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1532 - binary_accuracy: 0.9717
# Epoch 379/500
# 1/1 [==============================] - 0s 127ms/step - loss: 0.1545 - binary_accuracy: 0.9695
# Epoch 380/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1558 - binary_accuracy: 0.9658
# Epoch 381/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1524 - binary_accuracy: 0.9705
# Epoch 382/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1516 - binary_accuracy: 0.9712
# Epoch 383/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1457 - binary_accuracy: 0.9737
# Epoch 384/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1484 - binary_accuracy: 0.9752
# Epoch 385/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1469 - binary_accuracy: 0.9740
# Epoch 386/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1510 - binary_accuracy: 0.9727
# Epoch 387/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1546 - binary_accuracy: 0.9685
# Epoch 388/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1466 - binary_accuracy: 0.9750
# Epoch 389/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1501 - binary_accuracy: 0.9700
# Epoch 390/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1506 - binary_accuracy: 0.9732
# Epoch 391/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1481 - binary_accuracy: 0.9737
# Epoch 392/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1476 - binary_accuracy: 0.9735
# Epoch 393/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1506 - binary_accuracy: 0.9700
# Epoch 394/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1465 - binary_accuracy: 0.9747
# Epoch 395/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1539 - binary_accuracy: 0.9702
# Epoch 396/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1566 - binary_accuracy: 0.9668
# Epoch 397/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1470 - binary_accuracy: 0.9720
# Epoch 398/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1530 - binary_accuracy: 0.9678
# Epoch 399/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1490 - binary_accuracy: 0.9712
# Epoch 400/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1532 - binary_accuracy: 0.9670
# Epoch 401/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1538 - binary_accuracy: 0.9702
# Epoch 402/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1458 - binary_accuracy: 0.9735
# Epoch 403/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1464 - binary_accuracy: 0.9715
# Epoch 404/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1453 - binary_accuracy: 0.9740
# Epoch 405/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1486 - binary_accuracy: 0.9725
# Epoch 406/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1473 - binary_accuracy: 0.9727
# Epoch 407/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1512 - binary_accuracy: 0.9710
# Epoch 408/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1432 - binary_accuracy: 0.9715
# Epoch 409/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1434 - binary_accuracy: 0.9732
# Epoch 410/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1510 - binary_accuracy: 0.9695
# Epoch 411/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.1490 - binary_accuracy: 0.9710
# Epoch 412/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1463 - binary_accuracy: 0.9725
# Epoch 413/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1421 - binary_accuracy: 0.9774
# Epoch 414/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1468 - binary_accuracy: 0.9727
# Epoch 415/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1530 - binary_accuracy: 0.9688
# Epoch 416/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1529 - binary_accuracy: 0.9658
# Epoch 417/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1515 - binary_accuracy: 0.9695
# Epoch 418/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1487 - binary_accuracy: 0.9695
# Epoch 419/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1490 - binary_accuracy: 0.9690
# Epoch 420/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1489 - binary_accuracy: 0.9675
# Epoch 421/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1473 - binary_accuracy: 0.9735
# Epoch 422/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1408 - binary_accuracy: 0.9754
# Epoch 423/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1461 - binary_accuracy: 0.9722
# Epoch 424/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1436 - binary_accuracy: 0.9742
# Epoch 425/500
# 1/1 [==============================] - 0s 162ms/step - loss: 0.1457 - binary_accuracy: 0.9722
# Epoch 426/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1449 - binary_accuracy: 0.9737
# Epoch 427/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1486 - binary_accuracy: 0.9715
# Epoch 428/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1488 - binary_accuracy: 0.9702
# Epoch 429/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1445 - binary_accuracy: 0.9727
# Epoch 430/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1456 - binary_accuracy: 0.9722
# Epoch 431/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1434 - binary_accuracy: 0.9735
# Epoch 432/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1476 - binary_accuracy: 0.9700
# Epoch 433/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1422 - binary_accuracy: 0.9717
# Epoch 434/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1456 - binary_accuracy: 0.9690
# Epoch 435/500
# 1/1 [==============================] - 0s 110ms/step - loss: 0.1435 - binary_accuracy: 0.9742
# Epoch 436/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1437 - binary_accuracy: 0.9697
# Epoch 437/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1393 - binary_accuracy: 0.9762
# Epoch 438/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1478 - binary_accuracy: 0.9695
# Epoch 439/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1453 - binary_accuracy: 0.9722
# Epoch 440/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1472 - binary_accuracy: 0.9688
# Epoch 441/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1415 - binary_accuracy: 0.9740
# Epoch 442/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1409 - binary_accuracy: 0.9727
# Epoch 443/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1421 - binary_accuracy: 0.9737
# Epoch 444/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1474 - binary_accuracy: 0.9688
# Epoch 445/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1388 - binary_accuracy: 0.9764
# Epoch 446/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1381 - binary_accuracy: 0.9742
# Epoch 447/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1455 - binary_accuracy: 0.9702
# Epoch 448/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1416 - binary_accuracy: 0.9712
# Epoch 449/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1407 - binary_accuracy: 0.9750
# Epoch 450/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1476 - binary_accuracy: 0.9680
# Epoch 451/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1385 - binary_accuracy: 0.9735
# Epoch 452/500
# 1/1 [==============================] - 0s 155ms/step - loss: 0.1417 - binary_accuracy: 0.9730
# Epoch 453/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1375 - binary_accuracy: 0.9740
# Epoch 454/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1449 - binary_accuracy: 0.9730
# Epoch 455/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1441 - binary_accuracy: 0.9710
# Epoch 456/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1461 - binary_accuracy: 0.9675
# Epoch 457/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1446 - binary_accuracy: 0.9690
# Epoch 458/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1423 - binary_accuracy: 0.9692
# Epoch 459/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1465 - binary_accuracy: 0.9673
# Epoch 460/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1376 - binary_accuracy: 0.9752
# Epoch 461/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1396 - binary_accuracy: 0.9727
# Epoch 462/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1403 - binary_accuracy: 0.9695
# Epoch 463/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1442 - binary_accuracy: 0.9692
# Epoch 464/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1337 - binary_accuracy: 0.9754
# Epoch 465/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1408 - binary_accuracy: 0.9725
# Epoch 466/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1411 - binary_accuracy: 0.9722
# Epoch 467/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1355 - binary_accuracy: 0.9764
# Epoch 468/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1379 - binary_accuracy: 0.9764
# Epoch 469/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1412 - binary_accuracy: 0.9695
# Epoch 470/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1427 - binary_accuracy: 0.9683
# Epoch 471/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1390 - binary_accuracy: 0.9710
# Epoch 472/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1441 - binary_accuracy: 0.9707
# Epoch 473/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1396 - binary_accuracy: 0.9717
# Epoch 474/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1525 - binary_accuracy: 0.9630
# Epoch 475/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1337 - binary_accuracy: 0.9784
# Epoch 476/500
# 1/1 [==============================] - 0s 159ms/step - loss: 0.1401 - binary_accuracy: 0.9705
# Epoch 477/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1417 - binary_accuracy: 0.9685
# Epoch 478/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1371 - binary_accuracy: 0.9750
# Epoch 479/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1435 - binary_accuracy: 0.9692
# Epoch 480/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1308 - binary_accuracy: 0.9767
# Epoch 481/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1403 - binary_accuracy: 0.9725
# Epoch 482/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1424 - binary_accuracy: 0.9737
# Epoch 483/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1487 - binary_accuracy: 0.9665
# Epoch 484/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1369 - binary_accuracy: 0.9730
# Epoch 485/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1405 - binary_accuracy: 0.9705
# Epoch 486/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1346 - binary_accuracy: 0.9754
# Epoch 487/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1380 - binary_accuracy: 0.9720
# Epoch 488/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1334 - binary_accuracy: 0.9745
# Epoch 489/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1382 - binary_accuracy: 0.9742
# Epoch 490/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1319 - binary_accuracy: 0.9757
# Epoch 491/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1376 - binary_accuracy: 0.9717
# Epoch 492/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1339 - binary_accuracy: 0.9745
# Epoch 493/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1354 - binary_accuracy: 0.9750
# Epoch 494/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1321 - binary_accuracy: 0.9742
# Epoch 495/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1345 - binary_accuracy: 0.9720
# Epoch 496/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1385 - binary_accuracy: 0.9692
# Epoch 497/500
# 1/1 [==============================] - 0s 152ms/step - loss: 0.1405 - binary_accuracy: 0.9697
# Epoch 498/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1341 - binary_accuracy: 0.9735
# Epoch 499/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1381 - binary_accuracy: 0.9688
# Epoch 500/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1401 - binary_accuracy: 0.9705

# %%
# extract relational cross-attention layer
relational_crossattention = model.abstractor.abstracter_layers[0].relational_crossattention.mha

# %%
# plot final model outputs for each pair of objects 
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        inputs = tf.one_hot(np.array([[i,j]]), num_objects)
        order_relation_matrix[i,j] = model(inputs)[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a pair of objects

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_pair = tf.one_hot(np.array([[i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_pair, key=object_pair, 
            value=object_pair, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[0][1]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)#, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
object_pair.shape
# Out:
# TensorShape([1, 2, 64])

# %%
# plot relational cross-attention attention score when input is a triplet of objects
# here, we fix the first object and vary second two, then we plot the relations of the other two objects
# with linear/sigmoid/tanh activation, adding objects does not affect the relations between existing objcets
# i.e.: this is exactly the same plot as the above (unlike with softmax activation)

conditional_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_triple = tf.one_hot(np.array([[16, i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_triple, key=object_triple, 
            value=object_triple, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[1][2]
        conditional_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(conditional_relation_matrix.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T - conditional_relation_matrix.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 30
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5zx))
plt.plot(order_relation_matrix[i,:], label='pairs')
plt.plot(conditional_relation_matrix[i,:], label='triples')
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')
plt.legend()

# %%
objects = tf.expand_dims(tf.one_hot(np.arange(num_objects), num_objects), axis=0)

# %%
# now, compute the relations between all pairs directly 
# by passing all the objects to the relational cross-attention simultaneously
# the results are now interpretable, unlike with softmax!
# again, exact same plot as above; relation depends only on pair

attention_output, attention_scores = relational_crossattention(query=objects, key=objects, value=objects, return_attention_scores=True)
attention_scores = np.squeeze(attention_scores)
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(attention_scores.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 32
attention_scores_i = attention_scores[i,:]
plt.figure(figsize=(8,5))
plt.plot(range(len(attention_scores_i)), attention_scores_i)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores_i), ymax=np.max(attention_scores_i), linestyle='dotted', color='gray')
