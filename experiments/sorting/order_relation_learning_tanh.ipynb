# %% [markdown]
# # Learning Order Relations

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import itertools
np.random.seed(42)

# %% [markdown]
# ## Order Relation Model
#
#
# **Task**: Given two objects $(o_1, o_2) \in \mathcal{O} \times \mathcal{O}$, predict the relation $o_1 \prec o_2$
#
# **Model**:
# 1) Embed each object: $o_1 \mapsto e_1, o_2 \mapsto e_2$
# 2) Project the first object via $W^1$ and the second object via $W^2$, then compute inner product: $\langle W^1 e_1, W^2 e_2 \rangle$.
# 3) Return relation as sigmoid function $\text{Sigmoid}\left( \langle W^1 e_1, W^2 e_2 \rangle \right)$
#
# *Note:* Here, the objects are tokens. (i.e.: integers. so the embedding layer maps $i \mapsto e_i$ for each $i \in \{1, ..., |\mathcal{O}| \}$)

# %%
class OrderRelation(tf.keras.Model):
    def __init__(self, num_objects, embedding_dim, proj_dim, name=None):
        super().__init__(name=name)
        self.num_objects = num_objects
        self.embedding_dim = embedding_dim
        self.proj_dim = proj_dim
    
    def build(self, input_shape):

        self.embedding = layers.Embedding(input_dim=self.num_objects, output_dim=self.embedding_dim)

        normal_initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=.1, seed=1)
        self.W1 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
        self.W2 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
    
    def compute_innerprod_rel(self, inputs):
        embeddings = self.embedding(inputs)
        
        o1 = embeddings[:, 0]
        o2 = embeddings[:, 1]
        e1 = tf.matmul(o1, self.W1)
        e2 = tf.matmul(o2, self.W2)

        innerprod_rel = tf.einsum('ij,ij->i', e1, e2) # compute inner product

        return innerprod_rel

    def call(self, inputs):

        innerprod_rel = self.compute_innerprod_rel(inputs)

        return innerprod_rel

# %% [markdown]
# ## Order Relation Dataset
#
# Model is fit on all pairs of objects and their associated relations.

# %%
# create data set for learning order relatios
num_objects = 64
object_pairs = np.array(list(itertools.permutations(range(num_objects), r=2)))
object_order_relations = (object_pairs[:,0] < object_pairs[:, 1]).astype(int)

# %%
sample = np.random.choice(len(object_pairs), 10)
for object_pair, relation in zip(object_pairs[sample], object_order_relations[sample]):
    print(f'object pair: {tuple(object_pair)}; relation: {relation}')
# Out:
# object pair: (50, 24); relation: 0
# object pair: (55, 42); relation: 0
# object pair: (13, 42); relation: 1
# object pair: (20, 35); relation: 1
# object pair: (17, 60); relation: 1
# object pair: (17, 25); relation: 1
# object pair: (59, 55); relation: 0
# object pair: (49, 5); relation: 0
# object pair: (26, 0); relation: 0
# object pair: (34, 27); relation: 0

# %% [markdown]
# ## Fit Relation Model

# %%
embedding_dim = 16
proj_dim = 8

order_relation = OrderRelation(num_objects, embedding_dim, proj_dim, name='order_relation')
order_relation(object_pairs); # build model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
order_relation.compile(loss='mse', optimizer=opt, metrics='binary_accuracy')

# %%
order_relation.fit(object_pairs, object_order_relations, epochs=200, batch_size=len(object_pairs))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 380ms/step - loss: 0.5000 - binary_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4868 - binary_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4001 - binary_accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2500 - binary_accuracy: 0.5193
# Epoch 5/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8391 - binary_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2652 - binary_accuracy: 0.5000
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2794 - binary_accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3648 - binary_accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4187 - binary_accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4481 - binary_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4640 - binary_accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4728 - binary_accuracy: 0.5000
# Epoch 13/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4777 - binary_accuracy: 0.5000
# Epoch 14/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4803 - binary_accuracy: 0.5000
# Epoch 15/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4815 - binary_accuracy: 0.5000
# Epoch 16/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4816 - binary_accuracy: 0.5000
# Epoch 17/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4809 - binary_accuracy: 0.5000
# Epoch 18/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4793 - binary_accuracy: 0.5000
# Epoch 19/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4768 - binary_accuracy: 0.5000
# Epoch 20/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4732 - binary_accuracy: 0.5000
# Epoch 21/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4681 - binary_accuracy: 0.5000
# Epoch 22/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4612 - binary_accuracy: 0.5000
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4515 - binary_accuracy: 0.5000
# Epoch 24/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4380 - binary_accuracy: 0.5000
# Epoch 25/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4190 - binary_accuracy: 0.5000
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3919 - binary_accuracy: 0.5000
# Epoch 27/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3529 - binary_accuracy: 0.5000
# Epoch 28/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2977 - binary_accuracy: 0.5042
# Epoch 29/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2238 - binary_accuracy: 0.5806
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1403 - binary_accuracy: 0.7723
# Epoch 31/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0913 - binary_accuracy: 0.9142
# Epoch 32/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1533 - binary_accuracy: 0.8519
# Epoch 33/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2488 - binary_accuracy: 0.8130
# Epoch 34/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1899 - binary_accuracy: 0.8467
# Epoch 35/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1005 - binary_accuracy: 0.8941
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0826 - binary_accuracy: 0.9169
# Epoch 37/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1072 - binary_accuracy: 0.8566
# Epoch 38/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1351 - binary_accuracy: 0.7946
# Epoch 39/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1502 - binary_accuracy: 0.7636
# Epoch 40/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1498 - binary_accuracy: 0.7659
# Epoch 41/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1354 - binary_accuracy: 0.8075
# Epoch 42/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1117 - binary_accuracy: 0.8700
# Epoch 43/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0872 - binary_accuracy: 0.9306
# Epoch 44/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0748 - binary_accuracy: 0.9405
# Epoch 45/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0845 - binary_accuracy: 0.9306
# Epoch 46/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1057 - binary_accuracy: 0.9092
# Epoch 47/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1098 - binary_accuracy: 0.9010
# Epoch 48/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0912 - binary_accuracy: 0.9110
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0730 - binary_accuracy: 0.9353
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0693 - binary_accuracy: 0.9598
# Epoch 51/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0758 - binary_accuracy: 0.9653
# Epoch 52/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0830 - binary_accuracy: 0.9437
# Epoch 53/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0851 - binary_accuracy: 0.9276
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0811 - binary_accuracy: 0.9315
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0731 - binary_accuracy: 0.9516
# Epoch 56/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0657 - binary_accuracy: 0.9643
# Epoch 57/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0632 - binary_accuracy: 0.9643
# Epoch 58/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0660 - binary_accuracy: 0.9539
# Epoch 59/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0687 - binary_accuracy: 0.9489
# Epoch 60/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0659 - binary_accuracy: 0.9541
# Epoch 61/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0591 - binary_accuracy: 0.9638
# Epoch 62/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0537 - binary_accuracy: 0.9742
# Epoch 63/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0522 - binary_accuracy: 0.9829
# Epoch 64/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0532 - binary_accuracy: 0.9737
# Epoch 65/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0541 - binary_accuracy: 0.9675
# Epoch 66/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0533 - binary_accuracy: 0.9692
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0511 - binary_accuracy: 0.9732
# Epoch 68/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0489 - binary_accuracy: 0.9807
# Epoch 69/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0480 - binary_accuracy: 0.9846
# Epoch 70/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0488 - binary_accuracy: 0.9849
# Epoch 71/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0498 - binary_accuracy: 0.9846
# Epoch 72/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0497 - binary_accuracy: 0.9859
# Epoch 73/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0485 - binary_accuracy: 0.9876
# Epoch 74/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0472 - binary_accuracy: 0.9856
# Epoch 75/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0470 - binary_accuracy: 0.9819
# Epoch 76/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0474 - binary_accuracy: 0.9754
# Epoch 77/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0477 - binary_accuracy: 0.9710
# Epoch 78/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0472 - binary_accuracy: 0.9725
# Epoch 79/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0462 - binary_accuracy: 0.9777
# Epoch 80/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0451 - binary_accuracy: 0.9836
# Epoch 81/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0446 - binary_accuracy: 0.9903
# Epoch 82/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0447 - binary_accuracy: 0.9913
# Epoch 83/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0448 - binary_accuracy: 0.9898
# Epoch 84/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0445 - binary_accuracy: 0.9898
# Epoch 85/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0439 - binary_accuracy: 0.9911
# Epoch 86/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0435 - binary_accuracy: 0.9933
# Epoch 87/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0434 - binary_accuracy: 0.9945
# Epoch 88/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0434 - binary_accuracy: 0.9948
# Epoch 89/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0434 - binary_accuracy: 0.9950
# Epoch 90/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0431 - binary_accuracy: 0.9953
# Epoch 91/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0428 - binary_accuracy: 0.9948
# Epoch 92/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0425 - binary_accuracy: 0.9940
# Epoch 93/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0424 - binary_accuracy: 0.9918
# Epoch 94/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0423 - binary_accuracy: 0.9911
# Epoch 95/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0421 - binary_accuracy: 0.9913
# Epoch 96/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0417 - binary_accuracy: 0.9918
# Epoch 97/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0413 - binary_accuracy: 0.9931
# Epoch 98/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0410 - binary_accuracy: 0.9945
# Epoch 99/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0409 - binary_accuracy: 0.9950
# Epoch 100/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0406 - binary_accuracy: 0.9955
# Epoch 101/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0403 - binary_accuracy: 0.9943
# Epoch 102/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0398 - binary_accuracy: 0.9921
# Epoch 103/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0394 - binary_accuracy: 0.9911
# Epoch 104/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0390 - binary_accuracy: 0.9901
# Epoch 105/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0386 - binary_accuracy: 0.9906
# Epoch 106/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0382 - binary_accuracy: 0.9903
# Epoch 107/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0377 - binary_accuracy: 0.9901
# Epoch 108/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0372 - binary_accuracy: 0.9903
# Epoch 109/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0367 - binary_accuracy: 0.9911
# Epoch 110/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0363 - binary_accuracy: 0.9913
# Epoch 111/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0358 - binary_accuracy: 0.9908
# Epoch 112/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0352 - binary_accuracy: 0.9903
# Epoch 113/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0347 - binary_accuracy: 0.9901
# Epoch 114/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0341 - binary_accuracy: 0.9901
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0336 - binary_accuracy: 0.9898
# Epoch 116/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0331 - binary_accuracy: 0.9898
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0326 - binary_accuracy: 0.9901
# Epoch 118/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0321 - binary_accuracy: 0.9906
# Epoch 119/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0317 - binary_accuracy: 0.9911
# Epoch 120/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0313 - binary_accuracy: 0.9918
# Epoch 121/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0310 - binary_accuracy: 0.9926
# Epoch 122/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307 - binary_accuracy: 0.9936
# Epoch 123/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0304 - binary_accuracy: 0.9943
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0303 - binary_accuracy: 0.9950
# Epoch 125/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0301 - binary_accuracy: 0.9950
# Epoch 126/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0300 - binary_accuracy: 0.9955
# Epoch 127/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0299 - binary_accuracy: 0.9958
# Epoch 128/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0298 - binary_accuracy: 0.9958
# Epoch 129/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0298 - binary_accuracy: 0.9958
# Epoch 130/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0297 - binary_accuracy: 0.9960
# Epoch 131/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0296 - binary_accuracy: 0.9960
# Epoch 132/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0295 - binary_accuracy: 0.9960
# Epoch 133/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0294 - binary_accuracy: 0.9960
# Epoch 134/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0293 - binary_accuracy: 0.9958
# Epoch 135/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0291 - binary_accuracy: 0.9960
# Epoch 136/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0290 - binary_accuracy: 0.9960
# Epoch 137/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0289 - binary_accuracy: 0.9960
# Epoch 138/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0288 - binary_accuracy: 0.9960
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0286 - binary_accuracy: 0.9963
# Epoch 140/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0285 - binary_accuracy: 0.9963
# Epoch 141/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0284 - binary_accuracy: 0.9960
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0282 - binary_accuracy: 0.9963
# Epoch 143/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0281 - binary_accuracy: 0.9958
# Epoch 144/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0280 - binary_accuracy: 0.9958
# Epoch 145/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0279 - binary_accuracy: 0.9955
# Epoch 146/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0278 - binary_accuracy: 0.9955
# Epoch 147/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0277 - binary_accuracy: 0.9953
# Epoch 148/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0276 - binary_accuracy: 0.9955
# Epoch 149/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0275 - binary_accuracy: 0.9953
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0274 - binary_accuracy: 0.9953
# Epoch 151/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0273 - binary_accuracy: 0.9953
# Epoch 152/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0272 - binary_accuracy: 0.9953
# Epoch 153/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0271 - binary_accuracy: 0.9953
# Epoch 154/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0270 - binary_accuracy: 0.9953
# Epoch 155/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0269 - binary_accuracy: 0.9953
# Epoch 156/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0268 - binary_accuracy: 0.9955
# Epoch 157/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0267 - binary_accuracy: 0.9958
# Epoch 158/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0265 - binary_accuracy: 0.9963
# Epoch 159/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0264 - binary_accuracy: 0.9965
# Epoch 160/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0262 - binary_accuracy: 0.9965
# Epoch 161/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0261 - binary_accuracy: 0.9968
# Epoch 162/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0259 - binary_accuracy: 0.9968
# Epoch 163/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0257 - binary_accuracy: 0.9970
# Epoch 164/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0255 - binary_accuracy: 0.9973
# Epoch 165/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0253 - binary_accuracy: 0.9978
# Epoch 166/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0251 - binary_accuracy: 0.9980
# Epoch 167/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0249 - binary_accuracy: 0.9980
# Epoch 168/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0247 - binary_accuracy: 0.9980
# Epoch 169/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0245 - binary_accuracy: 0.9980
# Epoch 170/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0243 - binary_accuracy: 0.9980
# Epoch 171/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0241 - binary_accuracy: 0.9980
# Epoch 172/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0239 - binary_accuracy: 0.9985
# Epoch 173/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0237 - binary_accuracy: 0.9985
# Epoch 174/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0236 - binary_accuracy: 0.9985
# Epoch 175/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - binary_accuracy: 0.9985
# Epoch 176/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0232 - binary_accuracy: 0.9985
# Epoch 177/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0231 - binary_accuracy: 0.9983
# Epoch 178/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0230 - binary_accuracy: 0.9983
# Epoch 179/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0229 - binary_accuracy: 0.9980
# Epoch 180/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0228 - binary_accuracy: 0.9980
# Epoch 181/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0227 - binary_accuracy: 0.9980
# Epoch 182/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0227 - binary_accuracy: 0.9980
# Epoch 183/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0227 - binary_accuracy: 0.9975
# Epoch 184/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226 - binary_accuracy: 0.9975
# Epoch 185/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226 - binary_accuracy: 0.9975
# Epoch 186/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0226 - binary_accuracy: 0.9975
# Epoch 187/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0226 - binary_accuracy: 0.9973
# Epoch 188/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 189/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0226 - binary_accuracy: 0.9970
# Epoch 190/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 191/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9970
# Epoch 192/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9973
# Epoch 193/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 194/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - binary_accuracy: 0.9978
# Epoch 195/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - binary_accuracy: 0.9978
# Epoch 196/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - binary_accuracy: 0.9978
# Epoch 197/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - binary_accuracy: 0.9978
# Epoch 198/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0222 - binary_accuracy: 0.9978
# Epoch 199/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0222 - binary_accuracy: 0.9978
# Epoch 200/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0221 - binary_accuracy: 0.9978

# %%
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        order_relation_matrix[i,j] = order_relation.compute_innerprod_rel(np.array([[i,j]]))[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\langle W_1 e_i, W_2 e_j \\rangle$');

# %%
fig, ax = plt.subplots(figsize=(6,6))
order_relation_matrix_softmax = tf.nn.softmax(order_relation_matrix, axis=1).numpy()
im = ax.imshow(order_relation_matrix_softmax.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\mathrm{softmax}(\\langle W_1 e_i, W_2 e_j \\rangle)$');

# %%
#x = tf.nn.softmax(order_relation_matrix, axis=1)
x = order_relation_matrix
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x[32, :])

# %% [markdown]
# # Learn Order Relation with `SimpleAbstractor`

# %%
import sys; sys.path.append('..'); sys.path.append('../..')

from abstracters import SimpleAbstractor

# %%
class AbstractorOrderRelation(tf.keras.Model):
    def __init__(self, name=None):
        super().__init__(name=name)
    
    def build(self, input_shape):
        # note: changed activation of MHA to tanh!
        self.abstractor = SimpleAbstractor(num_layers=1, num_heads=1, dff=32, use_pos_embedding=False, mha_activation_type='tanh')
        self.dense = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.abstractor(inputs)
        x = x[:, 0]
        x = self.dense(x)

        return x

# %%
object_pairs_onehot = tf.one_hot(object_pairs, num_objects)
object_pairs_onehot.shape
# Out:
# TensorShape([4032, 2, 64])

# %%
model = AbstractorOrderRelation()
model(object_pairs_onehot)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics='binary_accuracy')
model.summary()
# Out:
# Model: "abstractor_order_relation_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relational_abstracter (Simp  multiple                 21216
#  leAbstractor)
#
#  dense_21 (Dense)            multiple                  65
#
# =================================================================
# Total params: 21,281
# Trainable params: 21,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(object_pairs_onehot, object_order_relations, epochs=500, batch_size=len(object_pairs))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.7291 - binary_accuracy: 0.4988
# Epoch 2/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7170 - binary_accuracy: 0.5040
# Epoch 3/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.7214 - binary_accuracy: 0.5010
# Epoch 4/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.7265 - binary_accuracy: 0.4876
# Epoch 5/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7121 - binary_accuracy: 0.5087
# Epoch 6/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7108 - binary_accuracy: 0.4945
# Epoch 7/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7159 - binary_accuracy: 0.4933
# Epoch 8/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7085 - binary_accuracy: 0.5124
# Epoch 9/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7169 - binary_accuracy: 0.4886
# Epoch 10/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7117 - binary_accuracy: 0.5067
# Epoch 11/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7166 - binary_accuracy: 0.4871
# Epoch 12/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7066 - binary_accuracy: 0.5042
# Epoch 13/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7060 - binary_accuracy: 0.5069
# Epoch 14/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7096 - binary_accuracy: 0.5030
# Epoch 15/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7086 - binary_accuracy: 0.5040
# Epoch 16/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7007 - binary_accuracy: 0.5094
# Epoch 17/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7000 - binary_accuracy: 0.5193
# Epoch 18/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7009 - binary_accuracy: 0.5136
# Epoch 19/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6970 - binary_accuracy: 0.5238
# Epoch 20/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6966 - binary_accuracy: 0.5273
# Epoch 21/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6839 - binary_accuracy: 0.5595
# Epoch 22/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6840 - binary_accuracy: 0.5645
# Epoch 23/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6845 - binary_accuracy: 0.5506
# Epoch 24/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6786 - binary_accuracy: 0.5665
# Epoch 25/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6704 - binary_accuracy: 0.5856
# Epoch 26/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6629 - binary_accuracy: 0.6057
# Epoch 27/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6575 - binary_accuracy: 0.6243
# Epoch 28/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6490 - binary_accuracy: 0.6453
# Epoch 29/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6371 - binary_accuracy: 0.6729
# Epoch 30/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6241 - binary_accuracy: 0.6887
# Epoch 31/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6157 - binary_accuracy: 0.7063
# Epoch 32/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5980 - binary_accuracy: 0.7212
# Epoch 33/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5847 - binary_accuracy: 0.7299
# Epoch 34/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5739 - binary_accuracy: 0.7336
# Epoch 35/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5514 - binary_accuracy: 0.7545
# Epoch 36/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5353 - binary_accuracy: 0.7542
# Epoch 37/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5149 - binary_accuracy: 0.7574
# Epoch 38/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5050 - binary_accuracy: 0.7562
# Epoch 39/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4852 - binary_accuracy: 0.7681
# Epoch 40/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4662 - binary_accuracy: 0.7760
# Epoch 41/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4556 - binary_accuracy: 0.7768
# Epoch 42/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4429 - binary_accuracy: 0.7827
# Epoch 43/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4254 - binary_accuracy: 0.7951
# Epoch 44/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4218 - binary_accuracy: 0.7964
# Epoch 45/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4086 - binary_accuracy: 0.8026
# Epoch 46/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3847 - binary_accuracy: 0.8202
# Epoch 47/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3635 - binary_accuracy: 0.8266
# Epoch 48/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3440 - binary_accuracy: 0.8408
# Epoch 49/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3270 - binary_accuracy: 0.8485
# Epoch 50/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3133 - binary_accuracy: 0.8646
# Epoch 51/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2957 - binary_accuracy: 0.8738
# Epoch 52/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2856 - binary_accuracy: 0.8834
# Epoch 53/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2711 - binary_accuracy: 0.8916
# Epoch 54/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2638 - binary_accuracy: 0.8971
# Epoch 55/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2435 - binary_accuracy: 0.9072
# Epoch 56/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2251 - binary_accuracy: 0.9201
# Epoch 57/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2306 - binary_accuracy: 0.9167
# Epoch 58/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2181 - binary_accuracy: 0.9211
# Epoch 59/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2018 - binary_accuracy: 0.9293
# Epoch 60/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2019 - binary_accuracy: 0.9286
# Epoch 61/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2187 - binary_accuracy: 0.9189
# Epoch 62/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2032 - binary_accuracy: 0.9261
# Epoch 63/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1986 - binary_accuracy: 0.9315
# Epoch 64/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2112 - binary_accuracy: 0.9266
# Epoch 65/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1915 - binary_accuracy: 0.9311
# Epoch 66/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1908 - binary_accuracy: 0.9330
# Epoch 67/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1984 - binary_accuracy: 0.9343
# Epoch 68/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1955 - binary_accuracy: 0.9343
# Epoch 69/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1701 - binary_accuracy: 0.9430
# Epoch 70/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1819 - binary_accuracy: 0.9377
# Epoch 71/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1810 - binary_accuracy: 0.9377
# Epoch 72/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1697 - binary_accuracy: 0.9467
# Epoch 73/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1597 - binary_accuracy: 0.9501
# Epoch 74/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1691 - binary_accuracy: 0.9452
# Epoch 75/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1592 - binary_accuracy: 0.9499
# Epoch 76/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1646 - binary_accuracy: 0.9442
# Epoch 77/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1488 - binary_accuracy: 0.9521
# Epoch 78/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1396 - binary_accuracy: 0.9529
# Epoch 79/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1513 - binary_accuracy: 0.9509
# Epoch 80/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1437 - binary_accuracy: 0.9506
# Epoch 81/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1476 - binary_accuracy: 0.9511
# Epoch 82/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1442 - binary_accuracy: 0.9519
# Epoch 83/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1470 - binary_accuracy: 0.9534
# Epoch 84/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1436 - binary_accuracy: 0.9516
# Epoch 85/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1203 - binary_accuracy: 0.9563
# Epoch 86/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1309 - binary_accuracy: 0.9514
# Epoch 87/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1261 - binary_accuracy: 0.9511
# Epoch 88/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1165 - binary_accuracy: 0.9566
# Epoch 89/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1281 - binary_accuracy: 0.9541
# Epoch 90/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1175 - binary_accuracy: 0.9581
# Epoch 91/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1184 - binary_accuracy: 0.9556
# Epoch 92/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1142 - binary_accuracy: 0.9576
# Epoch 93/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1126 - binary_accuracy: 0.9583
# Epoch 94/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1058 - binary_accuracy: 0.9640
# Epoch 95/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1043 - binary_accuracy: 0.9588
# Epoch 96/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1094 - binary_accuracy: 0.9603
# Epoch 97/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1038 - binary_accuracy: 0.9596
# Epoch 98/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1098 - binary_accuracy: 0.9571
# Epoch 99/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1048 - binary_accuracy: 0.9606
# Epoch 100/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1042 - binary_accuracy: 0.9591
# Epoch 101/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0880 - binary_accuracy: 0.9635
# Epoch 102/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0861 - binary_accuracy: 0.9645
# Epoch 103/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0889 - binary_accuracy: 0.9608
# Epoch 104/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0843 - binary_accuracy: 0.9648
# Epoch 105/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0856 - binary_accuracy: 0.9695
# Epoch 106/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0882 - binary_accuracy: 0.9655
# Epoch 107/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0822 - binary_accuracy: 0.9643
# Epoch 108/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0855 - binary_accuracy: 0.9670
# Epoch 109/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0854 - binary_accuracy: 0.9645
# Epoch 110/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0910 - binary_accuracy: 0.9630
# Epoch 111/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0754 - binary_accuracy: 0.9700
# Epoch 112/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0830 - binary_accuracy: 0.9668
# Epoch 113/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0818 - binary_accuracy: 0.9653
# Epoch 114/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0760 - binary_accuracy: 0.9670
# Epoch 115/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0736 - binary_accuracy: 0.9712
# Epoch 116/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0720 - binary_accuracy: 0.9645
# Epoch 117/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0741 - binary_accuracy: 0.9675
# Epoch 118/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0750 - binary_accuracy: 0.9665
# Epoch 119/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0803 - binary_accuracy: 0.9663
# Epoch 120/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0698 - binary_accuracy: 0.9663
# Epoch 121/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0748 - binary_accuracy: 0.9695
# Epoch 122/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0726 - binary_accuracy: 0.9697
# Epoch 123/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0688 - binary_accuracy: 0.9707
# Epoch 124/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0703 - binary_accuracy: 0.9690
# Epoch 125/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0661 - binary_accuracy: 0.9710
# Epoch 126/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0675 - binary_accuracy: 0.9697
# Epoch 127/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0646 - binary_accuracy: 0.9678
# Epoch 128/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0620 - binary_accuracy: 0.9697
# Epoch 129/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0614 - binary_accuracy: 0.9712
# Epoch 130/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0717 - binary_accuracy: 0.9688
# Epoch 131/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0655 - binary_accuracy: 0.9692
# Epoch 132/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0662 - binary_accuracy: 0.9688
# Epoch 133/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0625 - binary_accuracy: 0.9722
# Epoch 134/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0688 - binary_accuracy: 0.9665
# Epoch 135/500
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0712 - binary_accuracy: 0.9665
# Epoch 136/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0619 - binary_accuracy: 0.9680
# Epoch 137/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0636 - binary_accuracy: 0.9678
# Epoch 138/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0662 - binary_accuracy: 0.9653
# Epoch 139/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0737 - binary_accuracy: 0.9630
# Epoch 140/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0660 - binary_accuracy: 0.9663
# Epoch 141/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0578 - binary_accuracy: 0.9722
# Epoch 142/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0574 - binary_accuracy: 0.9692
# Epoch 143/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0618 - binary_accuracy: 0.9678
# Epoch 144/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0565 - binary_accuracy: 0.9727
# Epoch 145/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0620 - binary_accuracy: 0.9690
# Epoch 146/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0662 - binary_accuracy: 0.9670
# Epoch 147/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0669 - binary_accuracy: 0.9665
# Epoch 148/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0688 - binary_accuracy: 0.9668
# Epoch 149/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0560 - binary_accuracy: 0.9712
# Epoch 150/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0646 - binary_accuracy: 0.9707
# Epoch 151/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0587 - binary_accuracy: 0.9717
# Epoch 152/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0688 - binary_accuracy: 0.9640
# Epoch 153/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0545 - binary_accuracy: 0.9742
# Epoch 154/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0568 - binary_accuracy: 0.9740
# Epoch 155/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0671 - binary_accuracy: 0.9665
# Epoch 156/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0540 - binary_accuracy: 0.9750
# Epoch 157/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0552 - binary_accuracy: 0.9730
# Epoch 158/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0616 - binary_accuracy: 0.9702
# Epoch 159/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0568 - binary_accuracy: 0.9732
# Epoch 160/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0609 - binary_accuracy: 0.9690
# Epoch 161/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0540 - binary_accuracy: 0.9737
# Epoch 162/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0650 - binary_accuracy: 0.9645
# Epoch 163/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0568 - binary_accuracy: 0.9717
# Epoch 164/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0640 - binary_accuracy: 0.9683
# Epoch 165/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0679 - binary_accuracy: 0.9660
# Epoch 166/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0652 - binary_accuracy: 0.9670
# Epoch 167/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0652 - binary_accuracy: 0.9653
# Epoch 168/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0640 - binary_accuracy: 0.9688
# Epoch 169/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0622 - binary_accuracy: 0.9688
# Epoch 170/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0583 - binary_accuracy: 0.9707
# Epoch 171/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0582 - binary_accuracy: 0.9720
# Epoch 172/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0544 - binary_accuracy: 0.9737
# Epoch 173/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0685 - binary_accuracy: 0.9653
# Epoch 174/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0542 - binary_accuracy: 0.9740
# Epoch 175/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0611 - binary_accuracy: 0.9683
# Epoch 176/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0511 - binary_accuracy: 0.9767
# Epoch 177/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0525 - binary_accuracy: 0.9740
# Epoch 178/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0551 - binary_accuracy: 0.9722
# Epoch 179/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0512 - binary_accuracy: 0.9752
# Epoch 180/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0503 - binary_accuracy: 0.9779
# Epoch 181/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0573 - binary_accuracy: 0.9707
# Epoch 182/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0535 - binary_accuracy: 0.9730
# Epoch 183/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0556 - binary_accuracy: 0.9710
# Epoch 184/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0592 - binary_accuracy: 0.9717
# Epoch 185/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0543 - binary_accuracy: 0.9737
# Epoch 186/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0617 - binary_accuracy: 0.9690
# Epoch 187/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0570 - binary_accuracy: 0.9720
# Epoch 188/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0571 - binary_accuracy: 0.9690
# Epoch 189/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0588 - binary_accuracy: 0.9702
# Epoch 190/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0622 - binary_accuracy: 0.9705
# Epoch 191/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0565 - binary_accuracy: 0.9732
# Epoch 192/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0535 - binary_accuracy: 0.9720
# Epoch 193/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0561 - binary_accuracy: 0.9690
# Epoch 194/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0605 - binary_accuracy: 0.9700
# Epoch 195/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0557 - binary_accuracy: 0.9715
# Epoch 196/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0649 - binary_accuracy: 0.9663
# Epoch 197/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0573 - binary_accuracy: 0.9697
# Epoch 198/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0606 - binary_accuracy: 0.9692
# Epoch 199/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0575 - binary_accuracy: 0.9707
# Epoch 200/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0651 - binary_accuracy: 0.9663
# Epoch 201/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0606 - binary_accuracy: 0.9683
# Epoch 202/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0550 - binary_accuracy: 0.9732
# Epoch 203/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0564 - binary_accuracy: 0.9710
# Epoch 204/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0576 - binary_accuracy: 0.9707
# Epoch 205/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0532 - binary_accuracy: 0.9735
# Epoch 206/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0586 - binary_accuracy: 0.9710
# Epoch 207/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0598 - binary_accuracy: 0.9680
# Epoch 208/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0622 - binary_accuracy: 0.9660
# Epoch 209/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0602 - binary_accuracy: 0.9700
# Epoch 210/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0566 - binary_accuracy: 0.9697
# Epoch 211/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0595 - binary_accuracy: 0.9690
# Epoch 212/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0497 - binary_accuracy: 0.9747
# Epoch 213/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0544 - binary_accuracy: 0.9720
# Epoch 214/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0532 - binary_accuracy: 0.9727
# Epoch 215/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0594 - binary_accuracy: 0.9692
# Epoch 216/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0578 - binary_accuracy: 0.9690
# Epoch 217/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0527 - binary_accuracy: 0.9730
# Epoch 218/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0485 - binary_accuracy: 0.9782
# Epoch 219/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0559 - binary_accuracy: 0.9700
# Epoch 220/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0539 - binary_accuracy: 0.9720
# Epoch 221/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0546 - binary_accuracy: 0.9745
# Epoch 222/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0557 - binary_accuracy: 0.9730
# Epoch 223/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0559 - binary_accuracy: 0.9707
# Epoch 224/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0607 - binary_accuracy: 0.9688
# Epoch 225/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0641 - binary_accuracy: 0.9670
# Epoch 226/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0553 - binary_accuracy: 0.9715
# Epoch 227/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0509 - binary_accuracy: 0.9752
# Epoch 228/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0606 - binary_accuracy: 0.9707
# Epoch 229/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0564 - binary_accuracy: 0.9715
# Epoch 230/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0548 - binary_accuracy: 0.9727
# Epoch 231/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0485 - binary_accuracy: 0.9735
# Epoch 232/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0492 - binary_accuracy: 0.9750
# Epoch 233/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0477 - binary_accuracy: 0.9759
# Epoch 234/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0594 - binary_accuracy: 0.9700
# Epoch 235/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0550 - binary_accuracy: 0.9720
# Epoch 236/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0512 - binary_accuracy: 0.9732
# Epoch 237/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0532 - binary_accuracy: 0.9742
# Epoch 238/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0605 - binary_accuracy: 0.9663
# Epoch 239/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0539 - binary_accuracy: 0.9737
# Epoch 240/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0601 - binary_accuracy: 0.9697
# Epoch 241/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0570 - binary_accuracy: 0.9725
# Epoch 242/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0523 - binary_accuracy: 0.9727
# Epoch 243/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0509 - binary_accuracy: 0.9747
# Epoch 244/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0557 - binary_accuracy: 0.9710
# Epoch 245/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0568 - binary_accuracy: 0.9705
# Epoch 246/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0521 - binary_accuracy: 0.9732
# Epoch 247/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0606 - binary_accuracy: 0.9678
# Epoch 248/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0556 - binary_accuracy: 0.9707
# Epoch 249/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0533 - binary_accuracy: 0.9745
# Epoch 250/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0506 - binary_accuracy: 0.9730
# Epoch 251/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0570 - binary_accuracy: 0.9692
# Epoch 252/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0541 - binary_accuracy: 0.9745
# Epoch 253/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0619 - binary_accuracy: 0.9678
# Epoch 254/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0532 - binary_accuracy: 0.9732
# Epoch 255/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0589 - binary_accuracy: 0.9688
# Epoch 256/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0521 - binary_accuracy: 0.9730
# Epoch 257/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0558 - binary_accuracy: 0.9707
# Epoch 258/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0505 - binary_accuracy: 0.9730
# Epoch 259/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0588 - binary_accuracy: 0.9702
# Epoch 260/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0532 - binary_accuracy: 0.9742
# Epoch 261/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0568 - binary_accuracy: 0.9717
# Epoch 262/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0524 - binary_accuracy: 0.9732
# Epoch 263/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0568 - binary_accuracy: 0.9697
# Epoch 264/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0525 - binary_accuracy: 0.9737
# Epoch 265/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0569 - binary_accuracy: 0.9695
# Epoch 266/500
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0502 - binary_accuracy: 0.9740
# Epoch 267/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0565 - binary_accuracy: 0.9690
# Epoch 268/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0591 - binary_accuracy: 0.9702
# Epoch 269/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0532 - binary_accuracy: 0.9707
# Epoch 270/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0555 - binary_accuracy: 0.9688
# Epoch 271/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0519 - binary_accuracy: 0.9745
# Epoch 272/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0592 - binary_accuracy: 0.9680
# Epoch 273/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0525 - binary_accuracy: 0.9720
# Epoch 274/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0522 - binary_accuracy: 0.9737
# Epoch 275/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0539 - binary_accuracy: 0.9737
# Epoch 276/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0559 - binary_accuracy: 0.9680
# Epoch 277/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0542 - binary_accuracy: 0.9720
# Epoch 278/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0560 - binary_accuracy: 0.9685
# Epoch 279/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0630 - binary_accuracy: 0.9665
# Epoch 280/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0607 - binary_accuracy: 0.9685
# Epoch 281/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0547 - binary_accuracy: 0.9712
# Epoch 282/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0594 - binary_accuracy: 0.9685
# Epoch 283/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0531 - binary_accuracy: 0.9717
# Epoch 284/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0571 - binary_accuracy: 0.9717
# Epoch 285/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0586 - binary_accuracy: 0.9668
# Epoch 286/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0512 - binary_accuracy: 0.9732
# Epoch 287/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0530 - binary_accuracy: 0.9702
# Epoch 288/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0605 - binary_accuracy: 0.9675
# Epoch 289/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0582 - binary_accuracy: 0.9683
# Epoch 290/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0484 - binary_accuracy: 0.9745
# Epoch 291/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0582 - binary_accuracy: 0.9712
# Epoch 292/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0549 - binary_accuracy: 0.9712
# Epoch 293/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0550 - binary_accuracy: 0.9712
# Epoch 294/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0560 - binary_accuracy: 0.9692
# Epoch 295/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0588 - binary_accuracy: 0.9680
# Epoch 296/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0534 - binary_accuracy: 0.9717
# Epoch 297/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0563 - binary_accuracy: 0.9725
# Epoch 298/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0487 - binary_accuracy: 0.9759
# Epoch 299/500
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0532 - binary_accuracy: 0.9702
# Epoch 300/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0576 - binary_accuracy: 0.9697
# Epoch 301/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0520 - binary_accuracy: 0.9705
# Epoch 302/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0557 - binary_accuracy: 0.9702
# Epoch 303/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0556 - binary_accuracy: 0.9707
# Epoch 304/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0535 - binary_accuracy: 0.9740
# Epoch 305/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0481 - binary_accuracy: 0.9745
# Epoch 306/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0571 - binary_accuracy: 0.9705
# Epoch 307/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0552 - binary_accuracy: 0.9712
# Epoch 308/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0543 - binary_accuracy: 0.9732
# Epoch 309/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0536 - binary_accuracy: 0.9720
# Epoch 310/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0545 - binary_accuracy: 0.9740
# Epoch 311/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0602 - binary_accuracy: 0.9697
# Epoch 312/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0593 - binary_accuracy: 0.9690
# Epoch 313/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0570 - binary_accuracy: 0.9720
# Epoch 314/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0510 - binary_accuracy: 0.9742
# Epoch 315/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0512 - binary_accuracy: 0.9732
# Epoch 316/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0520 - binary_accuracy: 0.9747
# Epoch 317/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0545 - binary_accuracy: 0.9712
# Epoch 318/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0581 - binary_accuracy: 0.9670
# Epoch 319/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0553 - binary_accuracy: 0.9697
# Epoch 320/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0528 - binary_accuracy: 0.9705
# Epoch 321/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0559 - binary_accuracy: 0.9700
# Epoch 322/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0488 - binary_accuracy: 0.9745
# Epoch 323/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0592 - binary_accuracy: 0.9653
# Epoch 324/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0575 - binary_accuracy: 0.9670
# Epoch 325/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0585 - binary_accuracy: 0.9678
# Epoch 326/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0578 - binary_accuracy: 0.9673
# Epoch 327/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0503 - binary_accuracy: 0.9737
# Epoch 328/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0507 - binary_accuracy: 0.9725
# Epoch 329/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0618 - binary_accuracy: 0.9680
# Epoch 330/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0579 - binary_accuracy: 0.9690
# Epoch 331/500
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0567 - binary_accuracy: 0.9697
# Epoch 332/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0555 - binary_accuracy: 0.9675
# Epoch 333/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0506 - binary_accuracy: 0.9717
# Epoch 334/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0538 - binary_accuracy: 0.9722
# Epoch 335/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0525 - binary_accuracy: 0.9722
# Epoch 336/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0544 - binary_accuracy: 0.9722
# Epoch 337/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0575 - binary_accuracy: 0.9688
# Epoch 338/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0547 - binary_accuracy: 0.9712
# Epoch 339/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0527 - binary_accuracy: 0.9722
# Epoch 340/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0589 - binary_accuracy: 0.9688
# Epoch 341/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0520 - binary_accuracy: 0.9722
# Epoch 342/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0555 - binary_accuracy: 0.9692
# Epoch 343/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0531 - binary_accuracy: 0.9737
# Epoch 344/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0537 - binary_accuracy: 0.9737
# Epoch 345/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0564 - binary_accuracy: 0.9720
# Epoch 346/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0491 - binary_accuracy: 0.9752
# Epoch 347/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0524 - binary_accuracy: 0.9750
# Epoch 348/500
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0537 - binary_accuracy: 0.9685
# Epoch 349/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0471 - binary_accuracy: 0.9789
# Epoch 350/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0590 - binary_accuracy: 0.9658
# Epoch 351/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0551 - binary_accuracy: 0.9705
# Epoch 352/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0640 - binary_accuracy: 0.9640
# Epoch 353/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0544 - binary_accuracy: 0.9722
# Epoch 354/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0543 - binary_accuracy: 0.9702
# Epoch 355/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0521 - binary_accuracy: 0.9702
# Epoch 356/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0596 - binary_accuracy: 0.9710
# Epoch 357/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0567 - binary_accuracy: 0.9692
# Epoch 358/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0583 - binary_accuracy: 0.9668
# Epoch 359/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0548 - binary_accuracy: 0.9707
# Epoch 360/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0560 - binary_accuracy: 0.9695
# Epoch 361/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0517 - binary_accuracy: 0.9715
# Epoch 362/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0531 - binary_accuracy: 0.9722
# Epoch 363/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0480 - binary_accuracy: 0.9759
# Epoch 364/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0509 - binary_accuracy: 0.9735
# Epoch 365/500
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0554 - binary_accuracy: 0.9710
# Epoch 366/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0522 - binary_accuracy: 0.9722
# Epoch 367/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0494 - binary_accuracy: 0.9740
# Epoch 368/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0527 - binary_accuracy: 0.9722
# Epoch 369/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0538 - binary_accuracy: 0.9722
# Epoch 370/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0489 - binary_accuracy: 0.9740
# Epoch 371/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0511 - binary_accuracy: 0.9750
# Epoch 372/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0532 - binary_accuracy: 0.9722
# Epoch 373/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0526 - binary_accuracy: 0.9722
# Epoch 374/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0569 - binary_accuracy: 0.9705
# Epoch 375/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0521 - binary_accuracy: 0.9720
# Epoch 376/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0557 - binary_accuracy: 0.9722
# Epoch 377/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0528 - binary_accuracy: 0.9747
# Epoch 378/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0485 - binary_accuracy: 0.9742
# Epoch 379/500
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0531 - binary_accuracy: 0.9720
# Epoch 380/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0420 - binary_accuracy: 0.9792
# Epoch 381/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0550 - binary_accuracy: 0.9722
# Epoch 382/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0506 - binary_accuracy: 0.9745
# Epoch 383/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0540 - binary_accuracy: 0.9720
# Epoch 384/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0529 - binary_accuracy: 0.9715
# Epoch 385/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0526 - binary_accuracy: 0.9700
# Epoch 386/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0546 - binary_accuracy: 0.9710
# Epoch 387/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0540 - binary_accuracy: 0.9722
# Epoch 388/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0487 - binary_accuracy: 0.9752
# Epoch 389/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0518 - binary_accuracy: 0.9722
# Epoch 390/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0561 - binary_accuracy: 0.9720
# Epoch 391/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0528 - binary_accuracy: 0.9735
# Epoch 392/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0566 - binary_accuracy: 0.9707
# Epoch 393/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0535 - binary_accuracy: 0.9730
# Epoch 394/500
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0479 - binary_accuracy: 0.9757
# Epoch 395/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0549 - binary_accuracy: 0.9720
# Epoch 396/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0577 - binary_accuracy: 0.9692
# Epoch 397/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0508 - binary_accuracy: 0.9747
# Epoch 398/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0559 - binary_accuracy: 0.9688
# Epoch 399/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0513 - binary_accuracy: 0.9752
# Epoch 400/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0544 - binary_accuracy: 0.9720
# Epoch 401/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0477 - binary_accuracy: 0.9752
# Epoch 402/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0546 - binary_accuracy: 0.9715
# Epoch 403/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0531 - binary_accuracy: 0.9727
# Epoch 404/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0555 - binary_accuracy: 0.9673
# Epoch 405/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0538 - binary_accuracy: 0.9690
# Epoch 406/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0510 - binary_accuracy: 0.9705
# Epoch 407/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0516 - binary_accuracy: 0.9730
# Epoch 408/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0498 - binary_accuracy: 0.9754
# Epoch 409/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0512 - binary_accuracy: 0.9730
# Epoch 410/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0571 - binary_accuracy: 0.9683
# Epoch 411/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0509 - binary_accuracy: 0.9712
# Epoch 412/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0597 - binary_accuracy: 0.9702
# Epoch 413/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0537 - binary_accuracy: 0.9725
# Epoch 414/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0564 - binary_accuracy: 0.9715
# Epoch 415/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0529 - binary_accuracy: 0.9732
# Epoch 416/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0517 - binary_accuracy: 0.9722
# Epoch 417/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0527 - binary_accuracy: 0.9702
# Epoch 418/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0606 - binary_accuracy: 0.9673
# Epoch 419/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0582 - binary_accuracy: 0.9678
# Epoch 420/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0500 - binary_accuracy: 0.9740
# Epoch 421/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0511 - binary_accuracy: 0.9747
# Epoch 422/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0533 - binary_accuracy: 0.9737
# Epoch 423/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0535 - binary_accuracy: 0.9717
# Epoch 424/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0529 - binary_accuracy: 0.9732
# Epoch 425/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0551 - binary_accuracy: 0.9705
# Epoch 426/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0528 - binary_accuracy: 0.9730
# Epoch 427/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0560 - binary_accuracy: 0.9710
# Epoch 428/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0562 - binary_accuracy: 0.9688
# Epoch 429/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0564 - binary_accuracy: 0.9702
# Epoch 430/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0472 - binary_accuracy: 0.9750
# Epoch 431/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0483 - binary_accuracy: 0.9745
# Epoch 432/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0576 - binary_accuracy: 0.9678
# Epoch 433/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0542 - binary_accuracy: 0.9710
# Epoch 434/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0538 - binary_accuracy: 0.9715
# Epoch 435/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0579 - binary_accuracy: 0.9710
# Epoch 436/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0578 - binary_accuracy: 0.9692
# Epoch 437/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0462 - binary_accuracy: 0.9764
# Epoch 438/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0473 - binary_accuracy: 0.9750
# Epoch 439/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0534 - binary_accuracy: 0.9707
# Epoch 440/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0535 - binary_accuracy: 0.9717
# Epoch 441/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0554 - binary_accuracy: 0.9690
# Epoch 442/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0529 - binary_accuracy: 0.9740
# Epoch 443/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0485 - binary_accuracy: 0.9769
# Epoch 444/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0520 - binary_accuracy: 0.9707
# Epoch 445/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0527 - binary_accuracy: 0.9722
# Epoch 446/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0535 - binary_accuracy: 0.9712
# Epoch 447/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0481 - binary_accuracy: 0.9750
# Epoch 448/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0563 - binary_accuracy: 0.9735
# Epoch 449/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0494 - binary_accuracy: 0.9740
# Epoch 450/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0595 - binary_accuracy: 0.9690
# Epoch 451/500
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0505 - binary_accuracy: 0.9752
# Epoch 452/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0585 - binary_accuracy: 0.9688
# Epoch 453/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0524 - binary_accuracy: 0.9732
# Epoch 454/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0538 - binary_accuracy: 0.9712
# Epoch 455/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0532 - binary_accuracy: 0.9712
# Epoch 456/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0508 - binary_accuracy: 0.9737
# Epoch 457/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0572 - binary_accuracy: 0.9700
# Epoch 458/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0592 - binary_accuracy: 0.9707
# Epoch 459/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0554 - binary_accuracy: 0.9692
# Epoch 460/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0553 - binary_accuracy: 0.9702
# Epoch 461/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0475 - binary_accuracy: 0.9774
# Epoch 462/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0519 - binary_accuracy: 0.9720
# Epoch 463/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0542 - binary_accuracy: 0.9725
# Epoch 464/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0577 - binary_accuracy: 0.9680
# Epoch 465/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0536 - binary_accuracy: 0.9720
# Epoch 466/500
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0496 - binary_accuracy: 0.9747
# Epoch 467/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0550 - binary_accuracy: 0.9712
# Epoch 468/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0508 - binary_accuracy: 0.9720
# Epoch 469/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0527 - binary_accuracy: 0.9737
# Epoch 470/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0510 - binary_accuracy: 0.9722
# Epoch 471/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0574 - binary_accuracy: 0.9660
# Epoch 472/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0529 - binary_accuracy: 0.9732
# Epoch 473/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0518 - binary_accuracy: 0.9707
# Epoch 474/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0541 - binary_accuracy: 0.9705
# Epoch 475/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0522 - binary_accuracy: 0.9700
# Epoch 476/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0586 - binary_accuracy: 0.9695
# Epoch 477/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0517 - binary_accuracy: 0.9705
# Epoch 478/500
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0477 - binary_accuracy: 0.9740
# Epoch 479/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0483 - binary_accuracy: 0.9732
# Epoch 480/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0522 - binary_accuracy: 0.9720
# Epoch 481/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0501 - binary_accuracy: 0.9750
# Epoch 482/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0539 - binary_accuracy: 0.9715
# Epoch 483/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0530 - binary_accuracy: 0.9712
# Epoch 484/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0576 - binary_accuracy: 0.9695
# Epoch 485/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0502 - binary_accuracy: 0.9725
# Epoch 486/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0591 - binary_accuracy: 0.9655
# Epoch 487/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0553 - binary_accuracy: 0.9690
# Epoch 488/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0550 - binary_accuracy: 0.9717
# Epoch 489/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0550 - binary_accuracy: 0.9707
# Epoch 490/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0522 - binary_accuracy: 0.9730
# Epoch 491/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0528 - binary_accuracy: 0.9727
# Epoch 492/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0505 - binary_accuracy: 0.9717
# Epoch 493/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0568 - binary_accuracy: 0.9680
# Epoch 494/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0509 - binary_accuracy: 0.9732
# Epoch 495/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0509 - binary_accuracy: 0.9742
# Epoch 496/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0550 - binary_accuracy: 0.9688
# Epoch 497/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0536 - binary_accuracy: 0.9707
# Epoch 498/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0502 - binary_accuracy: 0.9730
# Epoch 499/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0543 - binary_accuracy: 0.9737
# Epoch 500/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0533 - binary_accuracy: 0.9720

# %%
# extract relational cross-attention layer
relational_crossattention = model.abstractor.abstracter_layers[0].relational_crossattention.mha

# %%
# plot final model outputs for each pair of objects 
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        inputs = tf.one_hot(np.array([[i,j]]), num_objects)
        order_relation_matrix[i,j] = model(inputs)[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a pair of objects

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_pair = tf.one_hot(np.array([[i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_pair, key=object_pair, 
            value=object_pair, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[0][1]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a triplet of objects
# here, we fix the first object and vary second two, then we plot the relations of the other two objects
# with linear/sigmoid/tanh activation, adding objects does not affect the relations between existing objcets
# i.e.: this is exactly the same plot as the above (unlike with softmax activation)

conditional_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_triple = tf.one_hot(np.array([[16, i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_triple, key=object_triple, 
            value=object_triple, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[1][2]
        conditional_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(conditional_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T - conditional_relation_matrix.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 30
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(order_relation_matrix[i,:], label='pairs')
plt.plot(conditional_relation_matrix[i,:], label='triples')
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')
plt.legend()

# %%
objects = tf.expand_dims(tf.one_hot(np.arange(num_objects), num_objects), axis=0)

# %%
# now, compute the relations between all pairs directly 
# by passing all the objects to the relational cross-attention simultaneously
# the results are now interpretable, unlike with softmax!
# again, exact same plot as above; relation depends only on pair

attention_output, attention_scores = relational_crossattention(query=objects, key=objects, value=objects, return_attention_scores=True)
attention_scores = np.squeeze(attention_scores)
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(attention_scores.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 30
attention_scores_i = attention_scores[i,:]
plt.figure(figsize=(8,5))
plt.plot(range(len(attention_scores_i)), attention_scores_i)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores_i), ymax=np.max(attention_scores_i), linestyle='dotted', color='gray')
