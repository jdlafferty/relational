# %% [markdown]
# # Learning Order Relations

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import itertools
np.random.seed(42)

# %% [markdown]
# ## Order Relation Model
#
#
# **Task**: Given two objects $(o_1, o_2) \in \mathcal{O} \times \mathcal{O}$, predict the relation $o_1 \prec o_2$
#
# **Model**:
# 1) Embed each object: $o_1 \mapsto e_1, o_2 \mapsto e_2$
# 2) Project the first object via $W^1$ and the second object via $W^2$, then compute inner product: $\langle W^1 e_1, W^2 e_2 \rangle$.
# 3) Return relation as sigmoid function $\text{Sigmoid}\left( \langle W^1 e_1, W^2 e_2 \rangle \right)$
#
# *Note:* Here, the objects are tokens. (i.e.: integers. so the embedding layer maps $i \mapsto e_i$ for each $i \in \{1, ..., |\mathcal{O}| \}$)

# %%
class OrderRelation(tf.keras.Model):
    def __init__(self, num_objects, embedding_dim, proj_dim, name=None):
        super().__init__(name=name)
        self.num_objects = num_objects
        self.embedding_dim = embedding_dim
        self.proj_dim = proj_dim
    
    def build(self, input_shape):

        self.embedding = layers.Embedding(input_dim=self.num_objects, output_dim=self.embedding_dim)

        normal_initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=.1, seed=1)
        self.W1 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
        self.W2 = tf.Variable(normal_initializer(shape=(self.embedding_dim, self.proj_dim)), trainable=True)
    
    def compute_innerprod_rel(self, inputs):
        embeddings = self.embedding(inputs)
        
        o1 = embeddings[:, 0]
        o2 = embeddings[:, 1]
        e1 = tf.matmul(o1, self.W1)
        e2 = tf.matmul(o2, self.W2)

        innerprod_rel = tf.einsum('ij,ij->i', e1, e2) # compute inner product

        return innerprod_rel

    def call(self, inputs):

        innerprod_rel = self.compute_innerprod_rel(inputs)

        return innerprod_rel

# %% [markdown]
# ## Order Relation Dataset
#
# Model is fit on all pairs of objects and their associated relations.

# %%
# create data set for learning order relatios
num_objects = 64
object_pairs = np.array(list(itertools.permutations(range(num_objects), r=2)))
object_order_relations = (object_pairs[:,0] < object_pairs[:, 1]).astype(int)

# %%
sample = np.random.choice(len(object_pairs), 10)
for object_pair, relation in zip(object_pairs[sample], object_order_relations[sample]):
    print(f'object pair: {tuple(object_pair)}; relation: {relation}')
# Out:
# object pair: (50, 24); relation: 0
# object pair: (55, 42); relation: 0
# object pair: (13, 42); relation: 1
# object pair: (20, 35); relation: 1
# object pair: (17, 60); relation: 1
# object pair: (17, 25); relation: 1
# object pair: (59, 55); relation: 0
# object pair: (49, 5); relation: 0
# object pair: (26, 0); relation: 0
# object pair: (34, 27); relation: 0

# %% [markdown]
# ## Fit Relation Model

# %%
embedding_dim = 16
proj_dim = 8

order_relation = OrderRelation(num_objects, embedding_dim, proj_dim, name='order_relation')
order_relation(object_pairs); # build model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
order_relation.compile(loss='mse', optimizer=opt, metrics='binary_accuracy')

# %%
order_relation.fit(object_pairs, object_order_relations, epochs=200, batch_size=len(object_pairs))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 379ms/step - loss: 0.5000 - binary_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4943 - binary_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4361 - binary_accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2851 - binary_accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5887 - binary_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2586 - binary_accuracy: 0.5020
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2904 - binary_accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3581 - binary_accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3979 - binary_accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4173 - binary_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4241 - binary_accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4220 - binary_accuracy: 0.5000
# Epoch 13/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4116 - binary_accuracy: 0.5000
# Epoch 14/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3918 - binary_accuracy: 0.5000
# Epoch 15/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3597 - binary_accuracy: 0.5000
# Epoch 16/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3130 - binary_accuracy: 0.5000
# Epoch 17/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2569 - binary_accuracy: 0.5089
# Epoch 18/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2208 - binary_accuracy: 0.6937
# Epoch 19/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2519 - binary_accuracy: 0.5126
# Epoch 20/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2804 - binary_accuracy: 0.5025
# Epoch 21/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2087 - binary_accuracy: 0.5546
# Epoch 22/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1435 - binary_accuracy: 0.8787
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1280 - binary_accuracy: 0.8683
# Epoch 24/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1306 - binary_accuracy: 0.7939
# Epoch 25/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1340 - binary_accuracy: 0.7922
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1423 - binary_accuracy: 0.8194
# Epoch 27/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1579 - binary_accuracy: 0.8532
# Epoch 28/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1601 - binary_accuracy: 0.8752
# Epoch 29/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1364 - binary_accuracy: 0.8911
# Epoch 30/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1078 - binary_accuracy: 0.8911
# Epoch 31/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0939 - binary_accuracy: 0.8750
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0951 - binary_accuracy: 0.8636
# Epoch 33/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1028 - binary_accuracy: 0.8549
# Epoch 34/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1096 - binary_accuracy: 0.8584
# Epoch 35/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1121 - binary_accuracy: 0.8671
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1092 - binary_accuracy: 0.8792
# Epoch 37/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1017 - binary_accuracy: 0.8943
# Epoch 38/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0918 - binary_accuracy: 0.9152
# Epoch 39/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0830 - binary_accuracy: 0.9373
# Epoch 40/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0784 - binary_accuracy: 0.9516
# Epoch 41/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0790 - binary_accuracy: 0.9638
# Epoch 42/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0828 - binary_accuracy: 0.9695
# Epoch 43/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0858 - binary_accuracy: 0.9660
# Epoch 44/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0851 - binary_accuracy: 0.9588
# Epoch 45/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0811 - binary_accuracy: 0.9578
# Epoch 46/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0758 - binary_accuracy: 0.9578
# Epoch 47/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0721 - binary_accuracy: 0.9504
# Epoch 48/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0719 - binary_accuracy: 0.9360
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0749 - binary_accuracy: 0.9177
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0777 - binary_accuracy: 0.9070
# Epoch 51/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0771 - binary_accuracy: 0.9102
# Epoch 52/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0738 - binary_accuracy: 0.9226
# Epoch 53/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0701 - binary_accuracy: 0.9405
# Epoch 54/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0672 - binary_accuracy: 0.9561
# Epoch 55/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0653 - binary_accuracy: 0.9680
# Epoch 56/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0645 - binary_accuracy: 0.9757
# Epoch 57/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0648 - binary_accuracy: 0.9812
# Epoch 58/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0646 - binary_accuracy: 0.9836
# Epoch 59/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0625 - binary_accuracy: 0.9856
# Epoch 60/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0592 - binary_accuracy: 0.9871
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0563 - binary_accuracy: 0.9869
# Epoch 62/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0546 - binary_accuracy: 0.9851
# Epoch 63/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0535 - binary_accuracy: 0.9839
# Epoch 64/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0524 - binary_accuracy: 0.9821
# Epoch 65/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0511 - binary_accuracy: 0.9816
# Epoch 66/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0500 - binary_accuracy: 0.9836
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0493 - binary_accuracy: 0.9839
# Epoch 68/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0496 - binary_accuracy: 0.9794
# Epoch 69/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0507 - binary_accuracy: 0.9735
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0518 - binary_accuracy: 0.9680
# Epoch 71/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0517 - binary_accuracy: 0.9678
# Epoch 72/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0508 - binary_accuracy: 0.9720
# Epoch 73/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0500 - binary_accuracy: 0.9747
# Epoch 74/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0495 - binary_accuracy: 0.9774
# Epoch 75/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0491 - binary_accuracy: 0.9782
# Epoch 76/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0486 - binary_accuracy: 0.9802
# Epoch 77/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0479 - binary_accuracy: 0.9819
# Epoch 78/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0471 - binary_accuracy: 0.9831
# Epoch 79/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0466 - binary_accuracy: 0.9856
# Epoch 80/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0465 - binary_accuracy: 0.9871
# Epoch 81/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0465 - binary_accuracy: 0.9883
# Epoch 82/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0464 - binary_accuracy: 0.9888
# Epoch 83/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0460 - binary_accuracy: 0.9888
# Epoch 84/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0455 - binary_accuracy: 0.9883
# Epoch 85/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0450 - binary_accuracy: 0.9888
# Epoch 86/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0447 - binary_accuracy: 0.9876
# Epoch 87/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0442 - binary_accuracy: 0.9869
# Epoch 88/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0437 - binary_accuracy: 0.9856
# Epoch 89/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0431 - binary_accuracy: 0.9846
# Epoch 90/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0424 - binary_accuracy: 0.9856
# Epoch 91/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0418 - binary_accuracy: 0.9864
# Epoch 92/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0413 - binary_accuracy: 0.9866
# Epoch 93/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0409 - binary_accuracy: 0.9874
# Epoch 94/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0403 - binary_accuracy: 0.9881
# Epoch 95/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0397 - binary_accuracy: 0.9896
# Epoch 96/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0391 - binary_accuracy: 0.9896
# Epoch 97/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0386 - binary_accuracy: 0.9898
# Epoch 98/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0381 - binary_accuracy: 0.9898
# Epoch 99/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0376 - binary_accuracy: 0.9906
# Epoch 100/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0370 - binary_accuracy: 0.9911
# Epoch 101/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0365 - binary_accuracy: 0.9913
# Epoch 102/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0359 - binary_accuracy: 0.9913
# Epoch 103/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0354 - binary_accuracy: 0.9913
# Epoch 104/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0348 - binary_accuracy: 0.9906
# Epoch 105/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0342 - binary_accuracy: 0.9903
# Epoch 106/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0336 - binary_accuracy: 0.9906
# Epoch 107/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0330 - binary_accuracy: 0.9908
# Epoch 108/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0325 - binary_accuracy: 0.9903
# Epoch 109/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0320 - binary_accuracy: 0.9906
# Epoch 110/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0315 - binary_accuracy: 0.9903
# Epoch 111/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0312 - binary_accuracy: 0.9906
# Epoch 112/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0308 - binary_accuracy: 0.9913
# Epoch 113/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0306 - binary_accuracy: 0.9928
# Epoch 114/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0304 - binary_accuracy: 0.9928
# Epoch 115/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0302 - binary_accuracy: 0.9931
# Epoch 116/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0300 - binary_accuracy: 0.9926
# Epoch 117/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0299 - binary_accuracy: 0.9928
# Epoch 118/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0298 - binary_accuracy: 0.9931
# Epoch 119/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0297 - binary_accuracy: 0.9931
# Epoch 120/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0295 - binary_accuracy: 0.9933
# Epoch 121/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0294 - binary_accuracy: 0.9938
# Epoch 122/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0293 - binary_accuracy: 0.9938
# Epoch 123/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0291 - binary_accuracy: 0.9945
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0290 - binary_accuracy: 0.9950
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0289 - binary_accuracy: 0.9953
# Epoch 126/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0287 - binary_accuracy: 0.9958
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0286 - binary_accuracy: 0.9955
# Epoch 128/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0284 - binary_accuracy: 0.9955
# Epoch 129/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0283 - binary_accuracy: 0.9953
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0282 - binary_accuracy: 0.9950
# Epoch 131/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0280 - binary_accuracy: 0.9950
# Epoch 132/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0279 - binary_accuracy: 0.9953
# Epoch 133/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0277 - binary_accuracy: 0.9953
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0276 - binary_accuracy: 0.9953
# Epoch 135/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0274 - binary_accuracy: 0.9953
# Epoch 136/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0273 - binary_accuracy: 0.9955
# Epoch 137/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0271 - binary_accuracy: 0.9955
# Epoch 138/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0270 - binary_accuracy: 0.9958
# Epoch 139/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0268 - binary_accuracy: 0.9958
# Epoch 140/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0267 - binary_accuracy: 0.9958
# Epoch 141/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0266 - binary_accuracy: 0.9958
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - binary_accuracy: 0.9958
# Epoch 143/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0263 - binary_accuracy: 0.9958
# Epoch 144/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0261 - binary_accuracy: 0.9958
# Epoch 145/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0259 - binary_accuracy: 0.9963
# Epoch 146/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0258 - binary_accuracy: 0.9963
# Epoch 147/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0256 - binary_accuracy: 0.9963
# Epoch 148/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0254 - binary_accuracy: 0.9963
# Epoch 149/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0252 - binary_accuracy: 0.9963
# Epoch 150/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0250 - binary_accuracy: 0.9965
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - binary_accuracy: 0.9965
# Epoch 152/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0245 - binary_accuracy: 0.9970
# Epoch 153/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0243 - binary_accuracy: 0.9975
# Epoch 154/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0241 - binary_accuracy: 0.9980
# Epoch 155/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0239 - binary_accuracy: 0.9983
# Epoch 156/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0237 - binary_accuracy: 0.9985
# Epoch 157/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0235 - binary_accuracy: 0.9985
# Epoch 158/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0233 - binary_accuracy: 0.9985
# Epoch 159/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0231 - binary_accuracy: 0.9980
# Epoch 160/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0229 - binary_accuracy: 0.9980
# Epoch 161/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0228 - binary_accuracy: 0.9980
# Epoch 162/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0227 - binary_accuracy: 0.9978
# Epoch 163/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0226 - binary_accuracy: 0.9978
# Epoch 164/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0226 - binary_accuracy: 0.9978
# Epoch 165/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0225 - binary_accuracy: 0.9978
# Epoch 166/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0225 - binary_accuracy: 0.9978
# Epoch 167/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0225 - binary_accuracy: 0.9978
# Epoch 168/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 169/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 170/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 171/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 172/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0224 - binary_accuracy: 0.9973
# Epoch 173/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - binary_accuracy: 0.9973
# Epoch 174/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0223 - binary_accuracy: 0.9975
# Epoch 175/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - binary_accuracy: 0.9973
# Epoch 176/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0222 - binary_accuracy: 0.9973
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0222 - binary_accuracy: 0.9973
# Epoch 178/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0221 - binary_accuracy: 0.9973
# Epoch 179/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0221 - binary_accuracy: 0.9973
# Epoch 180/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0220 - binary_accuracy: 0.9978
# Epoch 181/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0219 - binary_accuracy: 0.9978
# Epoch 182/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0219 - binary_accuracy: 0.9978
# Epoch 183/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0218 - binary_accuracy: 0.9980
# Epoch 184/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0218 - binary_accuracy: 0.9980
# Epoch 185/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0217 - binary_accuracy: 0.9980
# Epoch 186/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0216 - binary_accuracy: 0.9980
# Epoch 187/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0216 - binary_accuracy: 0.9980
# Epoch 188/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0215 - binary_accuracy: 0.9980
# Epoch 189/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0215 - binary_accuracy: 0.9980
# Epoch 190/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0214 - binary_accuracy: 0.9980
# Epoch 191/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - binary_accuracy: 0.9980
# Epoch 192/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0212 - binary_accuracy: 0.9978
# Epoch 193/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0212 - binary_accuracy: 0.9978
# Epoch 194/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0211 - binary_accuracy: 0.9978
# Epoch 195/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0210 - binary_accuracy: 0.9978
# Epoch 196/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0209 - binary_accuracy: 0.9978
# Epoch 197/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0208 - binary_accuracy: 0.9978
# Epoch 198/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0207 - binary_accuracy: 0.9978
# Epoch 199/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0206 - binary_accuracy: 0.9978
# Epoch 200/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0205 - binary_accuracy: 0.9978

# %%
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        order_relation_matrix[i,j] = order_relation.compute_innerprod_rel(np.array([[i,j]]))[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\langle W_1 e_i, W_2 e_j \\rangle$');

# %%
fig, ax = plt.subplots(figsize=(6,6))
order_relation_matrix_softmax = tf.nn.softmax(order_relation_matrix, axis=1).numpy()
im = ax.imshow(order_relation_matrix_softmax.T)
ax.invert_yaxis()
fig.colorbar(im, ax=ax);
ax.set_title('$\\mathrm{softmax}(\\langle W_1 e_i, W_2 e_j \\rangle)$');

# %%
#x = tf.nn.softmax(order_relation_matrix, axis=1)
x = order_relation_matrix
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x[32, :])

# %% [markdown]
# # Learn Order Relation with `SimpleAbstractor`

# %%
import sys; sys.path.append('..'); sys.path.append('../..')

from abstracters import SimpleAbstractor

# %%
class AbstractorOrderRelation(tf.keras.Model):
    def __init__(self, name=None):
        super().__init__(name=name)
    
    def build(self, input_shape):
        # note: changed activation of MHA to tanh!
        self.abstractor = SimpleAbstractor(num_layers=1, num_heads=1, dff=32, use_pos_embedding=False, mha_activation_type='softmax')
        self.dense = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.abstractor(inputs)
        x = x[:, 0]
        x = self.dense(x)

        return x

# %%
object_pairs_onehot = tf.one_hot(object_pairs, num_objects)
object_pairs_onehot.shape
# Out:
# TensorShape([4032, 2, 64])

# %%
model = AbstractorOrderRelation()
model(object_pairs_onehot)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics='binary_accuracy')
model.summary()
# Out:
# Model: "abstractor_order_relation_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relational_abstracter (Simp  multiple                 21216
#  leAbstractor)
#
#  dense_15 (Dense)            multiple                  65
#
# =================================================================
# Total params: 21,281
# Trainable params: 21,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(object_pairs_onehot, object_order_relations, epochs=500, batch_size=len(object_pairs))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.7364 - binary_accuracy: 0.5047
# Epoch 2/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7141 - binary_accuracy: 0.5025
# Epoch 3/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7268 - binary_accuracy: 0.4958
# Epoch 4/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.7250 - binary_accuracy: 0.4943
# Epoch 5/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7143 - binary_accuracy: 0.4871
# Epoch 6/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7181 - binary_accuracy: 0.4797
# Epoch 7/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7152 - binary_accuracy: 0.5102
# Epoch 8/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.7122 - binary_accuracy: 0.5055
# Epoch 9/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7124 - binary_accuracy: 0.5027
# Epoch 10/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7063 - binary_accuracy: 0.5045
# Epoch 11/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7034 - binary_accuracy: 0.5052
# Epoch 12/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7120 - binary_accuracy: 0.4809
# Epoch 13/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7121 - binary_accuracy: 0.4965
# Epoch 14/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7101 - binary_accuracy: 0.4985
# Epoch 15/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7035 - binary_accuracy: 0.5050
# Epoch 16/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7071 - binary_accuracy: 0.4978
# Epoch 17/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7115 - binary_accuracy: 0.4752
# Epoch 18/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7036 - binary_accuracy: 0.5082
# Epoch 19/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7052 - binary_accuracy: 0.5032
# Epoch 20/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7104 - binary_accuracy: 0.4948
# Epoch 21/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7015 - binary_accuracy: 0.5074
# Epoch 22/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7057 - binary_accuracy: 0.4898
# Epoch 23/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7018 - binary_accuracy: 0.4993
# Epoch 24/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7040 - binary_accuracy: 0.5042
# Epoch 25/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7037 - binary_accuracy: 0.5012
# Epoch 26/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7037 - binary_accuracy: 0.5030
# Epoch 27/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6984 - binary_accuracy: 0.5097
# Epoch 28/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7057 - binary_accuracy: 0.4955
# Epoch 29/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7027 - binary_accuracy: 0.5067
# Epoch 30/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6999 - binary_accuracy: 0.5102
# Epoch 31/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7008 - binary_accuracy: 0.5010
# Epoch 32/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7026 - binary_accuracy: 0.5040
# Epoch 33/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7041 - binary_accuracy: 0.4896
# Epoch 34/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7014 - binary_accuracy: 0.4975
# Epoch 35/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7038 - binary_accuracy: 0.5027
# Epoch 36/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7009 - binary_accuracy: 0.5047
# Epoch 37/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7006 - binary_accuracy: 0.4908
# Epoch 38/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6961 - binary_accuracy: 0.5089
# Epoch 39/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6990 - binary_accuracy: 0.5072
# Epoch 40/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.7026 - binary_accuracy: 0.4851
# Epoch 41/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6976 - binary_accuracy: 0.5017
# Epoch 42/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7024 - binary_accuracy: 0.4854
# Epoch 43/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6991 - binary_accuracy: 0.4993
# Epoch 44/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7015 - binary_accuracy: 0.4896
# Epoch 45/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7012 - binary_accuracy: 0.4948
# Epoch 46/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6972 - binary_accuracy: 0.5218
# Epoch 47/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6980 - binary_accuracy: 0.5087
# Epoch 48/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6998 - binary_accuracy: 0.5047
# Epoch 49/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7002 - binary_accuracy: 0.4913
# Epoch 50/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6989 - binary_accuracy: 0.5144
# Epoch 51/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6984 - binary_accuracy: 0.4948
# Epoch 52/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6992 - binary_accuracy: 0.4903
# Epoch 53/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7005 - binary_accuracy: 0.4901
# Epoch 54/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7023 - binary_accuracy: 0.4816
# Epoch 55/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7007 - binary_accuracy: 0.4874
# Epoch 56/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6983 - binary_accuracy: 0.4970
# Epoch 57/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6981 - binary_accuracy: 0.5052
# Epoch 58/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6979 - binary_accuracy: 0.4973
# Epoch 59/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6949 - binary_accuracy: 0.5146
# Epoch 60/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6971 - binary_accuracy: 0.5114
# Epoch 61/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6980 - binary_accuracy: 0.5064
# Epoch 62/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6985 - binary_accuracy: 0.4960
# Epoch 63/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6978 - binary_accuracy: 0.5027
# Epoch 64/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6976 - binary_accuracy: 0.5092
# Epoch 65/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6995 - binary_accuracy: 0.4903
# Epoch 66/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6990 - binary_accuracy: 0.4973
# Epoch 67/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6970 - binary_accuracy: 0.5047
# Epoch 68/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6952 - binary_accuracy: 0.5040
# Epoch 69/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6958 - binary_accuracy: 0.5064
# Epoch 70/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6975 - binary_accuracy: 0.5037
# Epoch 71/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6948 - binary_accuracy: 0.5037
# Epoch 72/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6958 - binary_accuracy: 0.5005
# Epoch 73/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6974 - binary_accuracy: 0.4960
# Epoch 74/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6953 - binary_accuracy: 0.5062
# Epoch 75/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6968 - binary_accuracy: 0.5025
# Epoch 76/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6937 - binary_accuracy: 0.5156
# Epoch 77/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6958 - binary_accuracy: 0.5134
# Epoch 78/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6956 - binary_accuracy: 0.5082
# Epoch 79/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6945 - binary_accuracy: 0.5181
# Epoch 80/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6956 - binary_accuracy: 0.5089
# Epoch 81/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6924 - binary_accuracy: 0.5201
# Epoch 82/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6913 - binary_accuracy: 0.5327
# Epoch 83/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6948 - binary_accuracy: 0.5126
# Epoch 84/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6914 - binary_accuracy: 0.5345
# Epoch 85/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6897 - binary_accuracy: 0.5446
# Epoch 86/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6934 - binary_accuracy: 0.5305
# Epoch 87/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6911 - binary_accuracy: 0.5446
# Epoch 88/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6882 - binary_accuracy: 0.5526
# Epoch 89/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6891 - binary_accuracy: 0.5528
# Epoch 90/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6891 - binary_accuracy: 0.5692
# Epoch 91/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6831 - binary_accuracy: 0.5823
# Epoch 92/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6844 - binary_accuracy: 0.5942
# Epoch 93/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6788 - binary_accuracy: 0.6032
# Epoch 94/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6741 - binary_accuracy: 0.6302
# Epoch 95/500
# 1/1 [==============================] - 0s 123ms/step - loss: 0.6702 - binary_accuracy: 0.6538
# Epoch 96/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6746 - binary_accuracy: 0.6481
# Epoch 97/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6684 - binary_accuracy: 0.6672
# Epoch 98/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6626 - binary_accuracy: 0.6897
# Epoch 99/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6596 - binary_accuracy: 0.6952
# Epoch 100/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6641 - binary_accuracy: 0.6925
# Epoch 101/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6545 - binary_accuracy: 0.7081
# Epoch 102/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6424 - binary_accuracy: 0.7259
# Epoch 103/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6378 - binary_accuracy: 0.7264
# Epoch 104/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6246 - binary_accuracy: 0.7473
# Epoch 105/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6205 - binary_accuracy: 0.7408
# Epoch 106/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5996 - binary_accuracy: 0.7535
# Epoch 107/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5874 - binary_accuracy: 0.7582
# Epoch 108/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5723 - binary_accuracy: 0.7664
# Epoch 109/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5563 - binary_accuracy: 0.7656
# Epoch 110/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5527 - binary_accuracy: 0.7622
# Epoch 111/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5287 - binary_accuracy: 0.7681
# Epoch 112/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5260 - binary_accuracy: 0.7755
# Epoch 113/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5010 - binary_accuracy: 0.7793
# Epoch 114/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4931 - binary_accuracy: 0.7795
# Epoch 115/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4765 - binary_accuracy: 0.7872
# Epoch 116/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4658 - binary_accuracy: 0.7847
# Epoch 117/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4322 - binary_accuracy: 0.8023
# Epoch 118/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4280 - binary_accuracy: 0.8070
# Epoch 119/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4133 - binary_accuracy: 0.8048
# Epoch 120/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3993 - binary_accuracy: 0.8197
# Epoch 121/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3920 - binary_accuracy: 0.8219
# Epoch 122/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3890 - binary_accuracy: 0.8189
# Epoch 123/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3564 - binary_accuracy: 0.8323
# Epoch 124/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3539 - binary_accuracy: 0.8400
# Epoch 125/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3290 - binary_accuracy: 0.8485
# Epoch 126/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3310 - binary_accuracy: 0.8492
# Epoch 127/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3099 - binary_accuracy: 0.8547
# Epoch 128/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2967 - binary_accuracy: 0.8579
# Epoch 129/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2919 - binary_accuracy: 0.8566
# Epoch 130/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2730 - binary_accuracy: 0.8661
# Epoch 131/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2605 - binary_accuracy: 0.8733
# Epoch 132/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2588 - binary_accuracy: 0.8693
# Epoch 133/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2395 - binary_accuracy: 0.8896
# Epoch 134/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2294 - binary_accuracy: 0.9005
# Epoch 135/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2214 - binary_accuracy: 0.9107
# Epoch 136/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2183 - binary_accuracy: 0.9072
# Epoch 137/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2059 - binary_accuracy: 0.9167
# Epoch 138/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2031 - binary_accuracy: 0.9129
# Epoch 139/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1975 - binary_accuracy: 0.9182
# Epoch 140/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1838 - binary_accuracy: 0.9298
# Epoch 141/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1790 - binary_accuracy: 0.9283
# Epoch 142/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1746 - binary_accuracy: 0.9276
# Epoch 143/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1602 - binary_accuracy: 0.9375
# Epoch 144/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1652 - binary_accuracy: 0.9338
# Epoch 145/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1559 - binary_accuracy: 0.9395
# Epoch 146/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1587 - binary_accuracy: 0.9325
# Epoch 147/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1480 - binary_accuracy: 0.9427
# Epoch 148/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1463 - binary_accuracy: 0.9390
# Epoch 149/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1322 - binary_accuracy: 0.9489
# Epoch 150/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1317 - binary_accuracy: 0.9484
# Epoch 151/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1239 - binary_accuracy: 0.9462
# Epoch 152/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1246 - binary_accuracy: 0.9504
# Epoch 153/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1252 - binary_accuracy: 0.9454
# Epoch 154/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1250 - binary_accuracy: 0.9425
# Epoch 155/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1190 - binary_accuracy: 0.9531
# Epoch 156/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1170 - binary_accuracy: 0.9521
# Epoch 157/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1075 - binary_accuracy: 0.9526
# Epoch 158/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1033 - binary_accuracy: 0.9571
# Epoch 159/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1090 - binary_accuracy: 0.9544
# Epoch 160/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0991 - binary_accuracy: 0.9583
# Epoch 161/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1128 - binary_accuracy: 0.9487
# Epoch 162/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0973 - binary_accuracy: 0.9559
# Epoch 163/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1109 - binary_accuracy: 0.9536
# Epoch 164/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0866 - binary_accuracy: 0.9648
# Epoch 165/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1011 - binary_accuracy: 0.9563
# Epoch 166/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0840 - binary_accuracy: 0.9660
# Epoch 167/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0937 - binary_accuracy: 0.9601
# Epoch 168/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0965 - binary_accuracy: 0.9603
# Epoch 169/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0822 - binary_accuracy: 0.9663
# Epoch 170/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0923 - binary_accuracy: 0.9601
# Epoch 171/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0784 - binary_accuracy: 0.9688
# Epoch 172/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0891 - binary_accuracy: 0.9593
# Epoch 173/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0895 - binary_accuracy: 0.9613
# Epoch 174/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0740 - binary_accuracy: 0.9705
# Epoch 175/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0822 - binary_accuracy: 0.9638
# Epoch 176/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0824 - binary_accuracy: 0.9621
# Epoch 177/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0796 - binary_accuracy: 0.9675
# Epoch 178/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0863 - binary_accuracy: 0.9625
# Epoch 179/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0781 - binary_accuracy: 0.9668
# Epoch 180/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0768 - binary_accuracy: 0.9678
# Epoch 181/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0708 - binary_accuracy: 0.9715
# Epoch 182/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0681 - binary_accuracy: 0.9710
# Epoch 183/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0801 - binary_accuracy: 0.9635
# Epoch 184/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0712 - binary_accuracy: 0.9697
# Epoch 185/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0745 - binary_accuracy: 0.9697
# Epoch 186/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0729 - binary_accuracy: 0.9670
# Epoch 187/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0674 - binary_accuracy: 0.9707
# Epoch 188/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0691 - binary_accuracy: 0.9722
# Epoch 189/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0718 - binary_accuracy: 0.9680
# Epoch 190/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0682 - binary_accuracy: 0.9717
# Epoch 191/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0630 - binary_accuracy: 0.9747
# Epoch 192/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0616 - binary_accuracy: 0.9725
# Epoch 193/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0649 - binary_accuracy: 0.9717
# Epoch 194/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0654 - binary_accuracy: 0.9712
# Epoch 195/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0724 - binary_accuracy: 0.9685
# Epoch 196/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0686 - binary_accuracy: 0.9702
# Epoch 197/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0662 - binary_accuracy: 0.9732
# Epoch 198/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0711 - binary_accuracy: 0.9690
# Epoch 199/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0672 - binary_accuracy: 0.9692
# Epoch 200/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0649 - binary_accuracy: 0.9712
# Epoch 201/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0633 - binary_accuracy: 0.9715
# Epoch 202/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0566 - binary_accuracy: 0.9745
# Epoch 203/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0549 - binary_accuracy: 0.9754
# Epoch 204/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0577 - binary_accuracy: 0.9757
# Epoch 205/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0554 - binary_accuracy: 0.9777
# Epoch 206/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0549 - binary_accuracy: 0.9774
# Epoch 207/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0633 - binary_accuracy: 0.9725
# Epoch 208/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0639 - binary_accuracy: 0.9725
# Epoch 209/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0541 - binary_accuracy: 0.9750
# Epoch 210/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0505 - binary_accuracy: 0.9769
# Epoch 211/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0559 - binary_accuracy: 0.9759
# Epoch 212/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0619 - binary_accuracy: 0.9690
# Epoch 213/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0511 - binary_accuracy: 0.9779
# Epoch 214/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0551 - binary_accuracy: 0.9767
# Epoch 215/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0543 - binary_accuracy: 0.9747
# Epoch 216/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0528 - binary_accuracy: 0.9774
# Epoch 217/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0531 - binary_accuracy: 0.9759
# Epoch 218/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0564 - binary_accuracy: 0.9750
# Epoch 219/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0530 - binary_accuracy: 0.9772
# Epoch 220/500
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0515 - binary_accuracy: 0.9787
# Epoch 221/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0509 - binary_accuracy: 0.9787
# Epoch 222/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0486 - binary_accuracy: 0.9767
# Epoch 223/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0501 - binary_accuracy: 0.9769
# Epoch 224/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0434 - binary_accuracy: 0.9821
# Epoch 225/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0483 - binary_accuracy: 0.9799
# Epoch 226/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0510 - binary_accuracy: 0.9764
# Epoch 227/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0462 - binary_accuracy: 0.9779
# Epoch 228/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0507 - binary_accuracy: 0.9789
# Epoch 229/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0483 - binary_accuracy: 0.9772
# Epoch 230/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0428 - binary_accuracy: 0.9814
# Epoch 231/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0421 - binary_accuracy: 0.9831
# Epoch 232/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0479 - binary_accuracy: 0.9762
# Epoch 233/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0485 - binary_accuracy: 0.9767
# Epoch 234/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0412 - binary_accuracy: 0.9809
# Epoch 235/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0419 - binary_accuracy: 0.9814
# Epoch 236/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0504 - binary_accuracy: 0.9784
# Epoch 237/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0437 - binary_accuracy: 0.9799
# Epoch 238/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0433 - binary_accuracy: 0.9802
# Epoch 239/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0452 - binary_accuracy: 0.9784
# Epoch 240/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0438 - binary_accuracy: 0.9802
# Epoch 241/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0467 - binary_accuracy: 0.9819
# Epoch 242/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0415 - binary_accuracy: 0.9829
# Epoch 243/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0431 - binary_accuracy: 0.9829
# Epoch 244/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0387 - binary_accuracy: 0.9844
# Epoch 245/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0476 - binary_accuracy: 0.9774
# Epoch 246/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0410 - binary_accuracy: 0.9812
# Epoch 247/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0496 - binary_accuracy: 0.9767
# Epoch 248/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0432 - binary_accuracy: 0.9824
# Epoch 249/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0455 - binary_accuracy: 0.9782
# Epoch 250/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0501 - binary_accuracy: 0.9769
# Epoch 251/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0416 - binary_accuracy: 0.9812
# Epoch 252/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0417 - binary_accuracy: 0.9802
# Epoch 253/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0356 - binary_accuracy: 0.9851
# Epoch 254/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0374 - binary_accuracy: 0.9821
# Epoch 255/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0409 - binary_accuracy: 0.9829
# Epoch 256/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0447 - binary_accuracy: 0.9802
# Epoch 257/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0433 - binary_accuracy: 0.9814
# Epoch 258/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0420 - binary_accuracy: 0.9816
# Epoch 259/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0417 - binary_accuracy: 0.9809
# Epoch 260/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0387 - binary_accuracy: 0.9819
# Epoch 261/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0389 - binary_accuracy: 0.9824
# Epoch 262/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0427 - binary_accuracy: 0.9834
# Epoch 263/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0369 - binary_accuracy: 0.9821
# Epoch 264/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0388 - binary_accuracy: 0.9819
# Epoch 265/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0412 - binary_accuracy: 0.9789
# Epoch 266/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0481 - binary_accuracy: 0.9767
# Epoch 267/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0375 - binary_accuracy: 0.9836
# Epoch 268/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0396 - binary_accuracy: 0.9826
# Epoch 269/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0329 - binary_accuracy: 0.9866
# Epoch 270/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0355 - binary_accuracy: 0.9846
# Epoch 271/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0430 - binary_accuracy: 0.9824
# Epoch 272/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0368 - binary_accuracy: 0.9836
# Epoch 273/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0319 - binary_accuracy: 0.9854
# Epoch 274/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0363 - binary_accuracy: 0.9829
# Epoch 275/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0431 - binary_accuracy: 0.9816
# Epoch 276/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0381 - binary_accuracy: 0.9831
# Epoch 277/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0346 - binary_accuracy: 0.9841
# Epoch 278/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0360 - binary_accuracy: 0.9849
# Epoch 279/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0398 - binary_accuracy: 0.9819
# Epoch 280/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0343 - binary_accuracy: 0.9864
# Epoch 281/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0330 - binary_accuracy: 0.9849
# Epoch 282/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0385 - binary_accuracy: 0.9831
# Epoch 283/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0369 - binary_accuracy: 0.9851
# Epoch 284/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0318 - binary_accuracy: 0.9849
# Epoch 285/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0336 - binary_accuracy: 0.9851
# Epoch 286/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0339 - binary_accuracy: 0.9856
# Epoch 287/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0316 - binary_accuracy: 0.9864
# Epoch 288/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0329 - binary_accuracy: 0.9864
# Epoch 289/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0309 - binary_accuracy: 0.9861
# Epoch 290/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0356 - binary_accuracy: 0.9841
# Epoch 291/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0378 - binary_accuracy: 0.9824
# Epoch 292/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0342 - binary_accuracy: 0.9836
# Epoch 293/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0337 - binary_accuracy: 0.9856
# Epoch 294/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0343 - binary_accuracy: 0.9836
# Epoch 295/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0323 - binary_accuracy: 0.9866
# Epoch 296/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0320 - binary_accuracy: 0.9829
# Epoch 297/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0345 - binary_accuracy: 0.9866
# Epoch 298/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0331 - binary_accuracy: 0.9831
# Epoch 299/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0294 - binary_accuracy: 0.9861
# Epoch 300/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0351 - binary_accuracy: 0.9844
# Epoch 301/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0313 - binary_accuracy: 0.9846
# Epoch 302/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0316 - binary_accuracy: 0.9859
# Epoch 303/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0338 - binary_accuracy: 0.9839
# Epoch 304/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0330 - binary_accuracy: 0.9851
# Epoch 305/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0282 - binary_accuracy: 0.9886
# Epoch 306/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0312 - binary_accuracy: 0.9856
# Epoch 307/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0332 - binary_accuracy: 0.9849
# Epoch 308/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0307 - binary_accuracy: 0.9876
# Epoch 309/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0260 - binary_accuracy: 0.9886
# Epoch 310/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0340 - binary_accuracy: 0.9831
# Epoch 311/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0327 - binary_accuracy: 0.9849
# Epoch 312/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0288 - binary_accuracy: 0.9878
# Epoch 313/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0412 - binary_accuracy: 0.9804
# Epoch 314/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0301 - binary_accuracy: 0.9871
# Epoch 315/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0310 - binary_accuracy: 0.9859
# Epoch 316/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0351 - binary_accuracy: 0.9834
# Epoch 317/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0281 - binary_accuracy: 0.9878
# Epoch 318/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0282 - binary_accuracy: 0.9871
# Epoch 319/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0312 - binary_accuracy: 0.9859
# Epoch 320/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0336 - binary_accuracy: 0.9846
# Epoch 321/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0295 - binary_accuracy: 0.9861
# Epoch 322/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0332 - binary_accuracy: 0.9846
# Epoch 323/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0328 - binary_accuracy: 0.9871
# Epoch 324/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0298 - binary_accuracy: 0.9859
# Epoch 325/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0307 - binary_accuracy: 0.9836
# Epoch 326/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0326 - binary_accuracy: 0.9859
# Epoch 327/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0295 - binary_accuracy: 0.9859
# Epoch 328/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0291 - binary_accuracy: 0.9866
# Epoch 329/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0271 - binary_accuracy: 0.9874
# Epoch 330/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0304 - binary_accuracy: 0.9851
# Epoch 331/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0257 - binary_accuracy: 0.9898
# Epoch 332/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0277 - binary_accuracy: 0.9881
# Epoch 333/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0272 - binary_accuracy: 0.9881
# Epoch 334/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0317 - binary_accuracy: 0.9849
# Epoch 335/500
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0277 - binary_accuracy: 0.9883
# Epoch 336/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0282 - binary_accuracy: 0.9881
# Epoch 337/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0274 - binary_accuracy: 0.9874
# Epoch 338/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0238 - binary_accuracy: 0.9883
# Epoch 339/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0312 - binary_accuracy: 0.9869
# Epoch 340/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0286 - binary_accuracy: 0.9874
# Epoch 341/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0245 - binary_accuracy: 0.9896
# Epoch 342/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0270 - binary_accuracy: 0.9876
# Epoch 343/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0278 - binary_accuracy: 0.9874
# Epoch 344/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0259 - binary_accuracy: 0.9874
# Epoch 345/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0317 - binary_accuracy: 0.9854
# Epoch 346/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0231 - binary_accuracy: 0.9896
# Epoch 347/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0291 - binary_accuracy: 0.9874
# Epoch 348/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0311 - binary_accuracy: 0.9859
# Epoch 349/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0271 - binary_accuracy: 0.9874
# Epoch 350/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0252 - binary_accuracy: 0.9886
# Epoch 351/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0251 - binary_accuracy: 0.9883
# Epoch 352/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0280 - binary_accuracy: 0.9871
# Epoch 353/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0278 - binary_accuracy: 0.9864
# Epoch 354/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0267 - binary_accuracy: 0.9876
# Epoch 355/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0277 - binary_accuracy: 0.9886
# Epoch 356/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0229 - binary_accuracy: 0.9893
# Epoch 357/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0257 - binary_accuracy: 0.9898
# Epoch 358/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0307 - binary_accuracy: 0.9841
# Epoch 359/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0276 - binary_accuracy: 0.9883
# Epoch 360/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0236 - binary_accuracy: 0.9893
# Epoch 361/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0269 - binary_accuracy: 0.9881
# Epoch 362/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0250 - binary_accuracy: 0.9886
# Epoch 363/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0280 - binary_accuracy: 0.9866
# Epoch 364/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0215 - binary_accuracy: 0.9903
# Epoch 365/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0306 - binary_accuracy: 0.9861
# Epoch 366/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0262 - binary_accuracy: 0.9864
# Epoch 367/500
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0199 - binary_accuracy: 0.9913
# Epoch 368/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0279 - binary_accuracy: 0.9878
# Epoch 369/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0271 - binary_accuracy: 0.9866
# Epoch 370/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0243 - binary_accuracy: 0.9861
# Epoch 371/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0226 - binary_accuracy: 0.9891
# Epoch 372/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0320 - binary_accuracy: 0.9846
# Epoch 373/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0263 - binary_accuracy: 0.9878
# Epoch 374/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0192 - binary_accuracy: 0.9918
# Epoch 375/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0260 - binary_accuracy: 0.9886
# Epoch 376/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0259 - binary_accuracy: 0.9864
# Epoch 377/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0229 - binary_accuracy: 0.9901
# Epoch 378/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0243 - binary_accuracy: 0.9898
# Epoch 379/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0278 - binary_accuracy: 0.9871
# Epoch 380/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0225 - binary_accuracy: 0.9911
# Epoch 381/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0269 - binary_accuracy: 0.9878
# Epoch 382/500
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0226 - binary_accuracy: 0.9893
# Epoch 383/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0245 - binary_accuracy: 0.9883
# Epoch 384/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0193 - binary_accuracy: 0.9923
# Epoch 385/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0224 - binary_accuracy: 0.9893
# Epoch 386/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0212 - binary_accuracy: 0.9903
# Epoch 387/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0249 - binary_accuracy: 0.9893
# Epoch 388/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0205 - binary_accuracy: 0.9903
# Epoch 389/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0232 - binary_accuracy: 0.9898
# Epoch 390/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0224 - binary_accuracy: 0.9898
# Epoch 391/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0212 - binary_accuracy: 0.9908
# Epoch 392/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0274 - binary_accuracy: 0.9876
# Epoch 393/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0245 - binary_accuracy: 0.9883
# Epoch 394/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0250 - binary_accuracy: 0.9874
# Epoch 395/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0195 - binary_accuracy: 0.9926
# Epoch 396/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0196 - binary_accuracy: 0.9916
# Epoch 397/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0191 - binary_accuracy: 0.9908
# Epoch 398/500
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0223 - binary_accuracy: 0.9911
# Epoch 399/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0186 - binary_accuracy: 0.9903
# Epoch 400/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0233 - binary_accuracy: 0.9878
# Epoch 401/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0205 - binary_accuracy: 0.9901
# Epoch 402/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0193 - binary_accuracy: 0.9923
# Epoch 403/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0226 - binary_accuracy: 0.9896
# Epoch 404/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0221 - binary_accuracy: 0.9898
# Epoch 405/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0209 - binary_accuracy: 0.9913
# Epoch 406/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0260 - binary_accuracy: 0.9864
# Epoch 407/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0189 - binary_accuracy: 0.9913
# Epoch 408/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0215 - binary_accuracy: 0.9901
# Epoch 409/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0212 - binary_accuracy: 0.9888
# Epoch 410/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0255 - binary_accuracy: 0.9886
# Epoch 411/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0244 - binary_accuracy: 0.9888
# Epoch 412/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0260 - binary_accuracy: 0.9878
# Epoch 413/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0184 - binary_accuracy: 0.9918
# Epoch 414/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0194 - binary_accuracy: 0.9921
# Epoch 415/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0203 - binary_accuracy: 0.9903
# Epoch 416/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0242 - binary_accuracy: 0.9876
# Epoch 417/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0202 - binary_accuracy: 0.9896
# Epoch 418/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0177 - binary_accuracy: 0.9908
# Epoch 419/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0234 - binary_accuracy: 0.9883
# Epoch 420/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0198 - binary_accuracy: 0.9898
# Epoch 421/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0190 - binary_accuracy: 0.9911
# Epoch 422/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0213 - binary_accuracy: 0.9903
# Epoch 423/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0163 - binary_accuracy: 0.9926
# Epoch 424/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0219 - binary_accuracy: 0.9886
# Epoch 425/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0201 - binary_accuracy: 0.9913
# Epoch 426/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0231 - binary_accuracy: 0.9896
# Epoch 427/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0252 - binary_accuracy: 0.9891
# Epoch 428/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0217 - binary_accuracy: 0.9906
# Epoch 429/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0188 - binary_accuracy: 0.9906
# Epoch 430/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0202 - binary_accuracy: 0.9916
# Epoch 431/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0181 - binary_accuracy: 0.9928
# Epoch 432/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0218 - binary_accuracy: 0.9893
# Epoch 433/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0215 - binary_accuracy: 0.9896
# Epoch 434/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0161 - binary_accuracy: 0.9918
# Epoch 435/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0182 - binary_accuracy: 0.9911
# Epoch 436/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0190 - binary_accuracy: 0.9891
# Epoch 437/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0183 - binary_accuracy: 0.9906
# Epoch 438/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0199 - binary_accuracy: 0.9908
# Epoch 439/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0204 - binary_accuracy: 0.9896
# Epoch 440/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0181 - binary_accuracy: 0.9913
# Epoch 441/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0199 - binary_accuracy: 0.9921
# Epoch 442/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0161 - binary_accuracy: 0.9918
# Epoch 443/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0241 - binary_accuracy: 0.9878
# Epoch 444/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0203 - binary_accuracy: 0.9908
# Epoch 445/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0183 - binary_accuracy: 0.9918
# Epoch 446/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0208 - binary_accuracy: 0.9881
# Epoch 447/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0201 - binary_accuracy: 0.9906
# Epoch 448/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0235 - binary_accuracy: 0.9891
# Epoch 449/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0223 - binary_accuracy: 0.9893
# Epoch 450/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0184 - binary_accuracy: 0.9913
# Epoch 451/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0229 - binary_accuracy: 0.9896
# Epoch 452/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0213 - binary_accuracy: 0.9896
# Epoch 453/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0207 - binary_accuracy: 0.9906
# Epoch 454/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0196 - binary_accuracy: 0.9911
# Epoch 455/500
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0171 - binary_accuracy: 0.9908
# Epoch 456/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0156 - binary_accuracy: 0.9926
# Epoch 457/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0204 - binary_accuracy: 0.9881
# Epoch 458/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0212 - binary_accuracy: 0.9888
# Epoch 459/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0239 - binary_accuracy: 0.9886
# Epoch 460/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0197 - binary_accuracy: 0.9893
# Epoch 461/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0199 - binary_accuracy: 0.9893
# Epoch 462/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0234 - binary_accuracy: 0.9886
# Epoch 463/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0191 - binary_accuracy: 0.9901
# Epoch 464/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0161 - binary_accuracy: 0.9933
# Epoch 465/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0215 - binary_accuracy: 0.9881
# Epoch 466/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0190 - binary_accuracy: 0.9903
# Epoch 467/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0198 - binary_accuracy: 0.9911
# Epoch 468/500
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0160 - binary_accuracy: 0.9923
# Epoch 469/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0212 - binary_accuracy: 0.9883
# Epoch 470/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0196 - binary_accuracy: 0.9901
# Epoch 471/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0204 - binary_accuracy: 0.9901
# Epoch 472/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0189 - binary_accuracy: 0.9908
# Epoch 473/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0193 - binary_accuracy: 0.9903
# Epoch 474/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0204 - binary_accuracy: 0.9908
# Epoch 475/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0213 - binary_accuracy: 0.9901
# Epoch 476/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0181 - binary_accuracy: 0.9903
# Epoch 477/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0193 - binary_accuracy: 0.9886
# Epoch 478/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0206 - binary_accuracy: 0.9901
# Epoch 479/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0185 - binary_accuracy: 0.9908
# Epoch 480/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0241 - binary_accuracy: 0.9876
# Epoch 481/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0196 - binary_accuracy: 0.9888
# Epoch 482/500
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0149 - binary_accuracy: 0.9938
# Epoch 483/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0165 - binary_accuracy: 0.9928
# Epoch 484/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0169 - binary_accuracy: 0.9918
# Epoch 485/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0164 - binary_accuracy: 0.9921
# Epoch 486/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0262 - binary_accuracy: 0.9874
# Epoch 487/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0205 - binary_accuracy: 0.9901
# Epoch 488/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0164 - binary_accuracy: 0.9921
# Epoch 489/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0204 - binary_accuracy: 0.9903
# Epoch 490/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0199 - binary_accuracy: 0.9883
# Epoch 491/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0175 - binary_accuracy: 0.9913
# Epoch 492/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0174 - binary_accuracy: 0.9923
# Epoch 493/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0179 - binary_accuracy: 0.9913
# Epoch 494/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0159 - binary_accuracy: 0.9913
# Epoch 495/500
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0189 - binary_accuracy: 0.9911
# Epoch 496/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0206 - binary_accuracy: 0.9906
# Epoch 497/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0144 - binary_accuracy: 0.9938
# Epoch 498/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0179 - binary_accuracy: 0.9903
# Epoch 499/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0132 - binary_accuracy: 0.9945
# Epoch 500/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0173 - binary_accuracy: 0.9918

# %%
# extract relational cross-attention layer
relational_crossattention = model.abstractor.abstracter_layers[0].relational_crossattention.mha

# %%
# plot final model outputs for each pair of objects 
order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        inputs = tf.one_hot(np.array([[i,j]]), num_objects)
        order_relation_matrix[i,j] = model(inputs)[0].numpy()

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a pair of objects

order_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_pair = tf.one_hot(np.array([[i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_pair, key=object_pair, 
            value=object_pair, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[0][1]
        order_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
# plot relational cross-attention attention score when input is a triplet of objects
# here, we fix the first object and vary second two, then we plot the relations of the other two objects
# with linear/sigmoid/tanh activation, adding objects does not affect the relations between existing objcets
# i.e.: this is exactly the same plot as the above (unlike with softmax activation)

conditional_relation_matrix = np.zeros(shape=(num_objects, num_objects))

for i in range(num_objects):
    for j in range(num_objects):
        object_triple = tf.one_hot(np.array([[16, i, j]]), num_objects)
        attention_output, attention_scores = relational_crossattention(query=object_triple, key=object_triple, 
            value=object_triple, return_attention_scores=True)
        attention_score = np.squeeze(attention_scores)[1][2]
        conditional_relation_matrix[i,j] = attention_score

fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(conditional_relation_matrix.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(order_relation_matrix.T - conditional_relation_matrix.T)# cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 20
attention_scores = order_relation_matrix[i,:]
plt.figure(figsize=(8,5))
plt.plot(order_relation_matrix[i,:], label='pairs')
plt.plot(conditional_relation_matrix[i,:], label='triples')
plt.hlines(0.5, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores), ymax=np.max(attention_scores), linestyle='dotted', color='gray')
plt.legend()

# %%
objects = tf.expand_dims(tf.one_hot(np.arange(num_objects), num_objects), axis=0)

# %%
# now, compute the relations between all pairs directly 
# by passing all the objects to the relational cross-attention simultaneously
# the results are now interpretable, unlike with softmax!
# again, exact same plot as above; relation depends only on pair

attention_output, attention_scores = relational_crossattention(query=objects, key=objects, value=objects, return_attention_scores=True)
attention_scores = np.squeeze(attention_scores)
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(attention_scores.T, cmap='gray')
ax.invert_yaxis()
fig.colorbar(im, ax=ax);

# %%
i = 32
attention_scores_i = attention_scores[i,:]
plt.figure(figsize=(8,5))
plt.plot(range(len(attention_scores_i)), attention_scores_i)
plt.hlines(0, xmin=0, xmax=64, linestyle='dotted', color='gray')
plt.vlines(i, ymin=np.min(attention_scores_i), ymax=np.max(attention_scores_i), linestyle='dotted', color='gray')
